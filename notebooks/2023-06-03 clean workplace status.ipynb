# %%
from pandas import json_normalize  
import pandas as pd
import sys
sys.path.append(r"C:\Users\silvh\OneDrive\lighthouse\custom_python")
from silvhua import *
# from datetime import datetime

# %%
from wrangling import *

# %% [markdown]
# # Display Settings

# %%
# set the option to wrap text within cells
pd.set_option('display.max_colwidth', 100)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 30)
pd.set_option('display.width', None)

# %% [markdown]
# # Load objects from previous notebook

# %%
pickle_path = r'C:\Users\silvh\OneDrive\lighthouse\portfolio-projects\BC-Covid-workplace-closures\data\interim\pickles'
df_filename = 'pdfs_parsed_2023-04-02_cleaned_2023-05-31_1013.sav'
df = loadpickle(df_filename, pickle_path)
df
# Out:
# Time completed: 2023-06-03 23:20:34.205043
# Dataframe shape:  (13298, 27)
# DataFrame columns: ['index', 'HA', 'workplace_name', 'workplace_address', 'city', 'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active', 'earliest_reported_cases', 'latest_reported_cases', 'workplace_classification', 'cases_when_cluster_confirmed', 'total_cases', 'workplace_status', 'closure_y_n', 'closed_by_order', 'voluntary_closure', 'closure_date', 'partially_closed', 'unknown_closure_type', 'open', 'days_since_last_case', 'active_clusters', 'cluster_confirmed_epidate', 'doc_page_number', 'cluster_closed_epidate', 'file', 'flag']
#        index   HA workplace_name workplace_address        city  \
# 9094     1.0  FHA           None              None      surrey
# 9095     2.0  FHA           None              None     langley
# 9096     3.0  FHA           None              None      surrey
# 9097     4.0  FHA           None              None     burnaby
# ...

# %% [markdown]
# # workplace_status

# %%
sorted(df['workplace_status'].unique().astype(str))
# Out:
# ['Closed',
#  'Closed by order',
#  'Closed byorder',
#  'Closed:voluntarily June 12-16, 2021.Monitoringfor additionalcases fromsecondexposuredates.',
#  'Closed:voluntarilyJune 12-16, 2021.Monitoring foradditional casesfrom secondexposure dates.',
#  'Closed:voluntarilyJune 12-16, 2021.Monitoring foradditionalcasesfromsecondexposuredates.',
#  'Essential function (not closed)',
#  'Essential function(not closed',
#  'Essential function(not closed)',
#  'Essentialfunction (notclosed',
#  'Essentialfunction (notclosed)',
#  'Essentialfunction(not closed)',
#  'Essentialfunction(notclosed)',
#  'Follow-uppending',
#  'Managed without closure (not closed)',
#  'Managed withoutclosure (not closed)',
#  'Managed withoutclosure (notclosed)',
#  'Managedwithoutclosure (notclosed)',
#  'Managedwithoutclosure(notclosed)',
#  'None',
#  'Not a worksite',
#  'Not aworksite',
#  'Not closed',
#  'Not closed: Alternate control measures',
#  'Not closed: Public interest in remaining open',
# ...

# %% [markdown]
# ## 'Closed:voluntarily June 12-16, 2021.Monitoringfor additionalcases fromsecondexposuredates.'

# %%
filters = {
    'workplace_status': [
        'Closed:voluntarily June 12-16, 2021.Monitoringfor additionalcases fromsecondexposuredates.',
        'Closed:voluntarilyJune 12-16, 2021.Monitoring foradditional casesfrom secondexposure dates.',
        'Closed:voluntarilyJune 12-16, 2021.Monitoring foradditionalcasesfromsecondexposuredates.',
        ]
}
filter_df_any_condition(df, filters)[['index', 'HA', 'workplace_classification', 'workplace_status', 'file', 'doc_page_number']]
# Out:
# Filtered on workplace_status in ['closed:voluntarily june 12-16, 2021.monitoringfor additionalcases fromsecondexposuredates.', 'closed:voluntarilyjune 12-16, 2021.monitoring foradditional casesfrom secondexposure dates.', 'closed:voluntarilyjune 12-16, 2021.monitoring foradditionalcasesfromsecondexposuredates.']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207
# ...

# %%
filters = {
    'workplace_status': ['Follow-uppending',]
}
filter_df_any_condition(df, filters)[['index', 'HA', 'workplace_classification', 'workplace_status', 'file', 'doc_page_number']]
# Out:
# Filtered on workplace_status in ['follow-uppending']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9
# ...

# %% [markdown]
# ## None

# %%
filters = {
    'workplace_status': ['None']
}
filter_df_any_condition(df, filters)[['index', 'HA', 'workplace_classification', 'workplace_status', 'file', 'doc_page_number']]
# Out:
# Filtered on workplace_status in ['none']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 9252, 9
# ...

# %% [markdown]
# ## Open but EHOinvestigationunderway  todeterminetransmission

# %%
filters = {
    'workplace_status': ['Open but EHOinvestigationunderway  todeterminetransmission']
}
filter_df_any_condition(df, filters)[['index', 'HA', 'workplace_classification', 'workplace_status', 'file', 'doc_page_number']]
# Out:
# Filtered on workplace_status in ['open but ehoinvestigationunderway  todeterminetransmission']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9
# ...

# %% [markdown]
# ## PH

# %%
filters = {
    'workplace_status': ['PH']
}
filter_df_any_condition(df, filters)[['index', 'HA', 'workplace_classification', 'workplace_status', 'file', 'doc_page_number']]
# Out:
# Filtered on workplace_status in ['ph']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 9252, 925
# ...

# %%
df.loc[filter_df_any_condition(df, filters).index, 'workplace_status'] = 'Ordered closed by PH'
df.loc[[174, 246, 3819, 8353], 'workplace_status'] = 'Partially closed or widespread isolation by PH'
# Out:
# Filtered on workplace_status in ['ph']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 9252, 925
# ...

# %% [markdown]
# ## by PH

# %%
filters = {
    'workplace_status': ['by PH']
}
filter_df_any_condition(df, filters)[['index', 'HA', 'workplace_classification', 'workplace_status', 'file', 'doc_page_number']]
# Out:
# Filtered on workplace_status in ['by ph']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 9252, 
# ...

# %%
df.loc[filter_df_any_condition(df, filters).index, 'workplace_status'] = 'Partially closed or widespread isolation by PH'
# Out:
# Filtered on workplace_status in ['by ph']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 9252, 
# ...

# %% [markdown]
# ## 'closed'

# %%
df[df['workplace_status'].str.endswith('closed', na=False)]['workplace_status'].value_counts()
# Out:
# Not closed                       772
# Notclosed                        151
# Partiallyclosed                   12
# Partially closed                   4
# Essentialfunction (notclosed       2
# Essential function(not closed      1
# closed                             1
# Name: workplace_status, dtype: int64

# %%
filters = {
    'workplace_status': ['closed']
}
filter_df_any_condition(df, filters)[['index', 'HA', 'workplace_classification', 'workplace_status', 'file', 'doc_page_number']]
# Out:
# Filtered on workplace_status in ['closed']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 9252,
# ...

# %%
df[df['workplace_status'] == 'closed'][['index', 'HA', 'workplace_classification', 'workplace_status', 'file', 'doc_page_number']]
# Out:
#       index   HA workplace_classification workplace_status  \
# 5615  479.0  IHA                   Retail           closed
#
#                             file  doc_page_number
# 5615  F22-1445 Records_Part5.pdf               76

# %%
df.loc[5615, 'workplace_status'] = 'Not closed'

# %% [markdown]
# # closed by PH

# %%
df[df['workplace_status'].str.endswith('closed by PH', na=False)]['workplace_status'].value_counts()
# Out:
# Orderedclosed by PH     41
# Ordered closed by PH     4
# closed by PH             1
# Name: workplace_status, dtype: int64

# %% [markdown]
# ## closed)

# %%
filters = {
    'workplace_status': ['closed)']
}
filter_df_any_condition(df, filters)[['index', 'HA', 'workplace_classification', 'workplace_status', 'file', 'doc_page_number']]
# Out:
# Filtered on workplace_status in ['closed)']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 9252
# ...

# %%
df.loc[[48, 255, 5571, 6122, 6218, 6310, 6340, 6346, 6927, 8434, 10680, 11492, 11880, 11886, 12080, 12152], 'workplace_status'] = 'Managed without closure (not closed)'
df.loc[[254, 5570, 8433, 9012], 'workplace_status'] = 'Essential function (not closed)'

# %% [markdown]
# ## closure

# %%
df[df['workplace_status'].str.endswith('closure', na=False)]['workplace_status'].value_counts()
# Out:
# Voluntaryclosure     109
# Voluntary closure     41
# closure                8
# Name: workplace_status, dtype: int64

# %%
filters = {
    'workplace_status': ['closure']
}
filter_df_any_condition(df, filters)[['index', 'HA', 'workplace_classification', 'workplace_status', 'file', 'doc_page_number']]
# Out:
# Filtered on workplace_status in ['closure']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 9252
# ...

# %% [markdown]
# ## closure)

# %%
df[df['workplace_status'].str.endswith('closure)', na=False)]['workplace_status'].value_counts()
# Out:
# Open (ifopen,reason fornon-closure)       225
# Open (if open,reason for non-closure)      91
# Open (ifopen, reasonfor non-closure)       78
# Open (if open,reason fornon-closure)       26
# closure)                                   17
# Open (if open, reason for non-closure)      3
# Open (if open, reasno for non-closure)      3
# non-closure)                                3
# Name: workplace_status, dtype: int64

# %%
filters = {
    'workplace_status': ['closure)']
}
filter_df_any_condition(df, filters)[['index', 'HA', 'workplace_classification', 'workplace_status', 'file', 'doc_page_number']]
# Out:
# Filtered on workplace_status in ['closure)']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 925
# ...

# %%
df[df['workplace_status'].str.endswith('dates.', na=False)]['workplace_status'].value_counts()
# Out:
# Closed:voluntarily June 12-16, 2021.Monitoringfor additionalcases fromsecondexposuredates.     2
# Closed:voluntarilyJune 12-16, 2021.Monitoring foradditional casesfrom secondexposure dates.    1
# Closed:voluntarilyJune 12-16, 2021.Monitoring foradditionalcasesfromsecondexposuredates.       1
# dates.                                                                                         1
# Name: workplace_status, dtype: int64

# %%
df[df['workplace_status'].str.endswith('measures', na=False)]['workplace_status'].value_counts()
# Out:
# [3] Notclosed:Alternatecontrolmeasures      658
# Not closed:Alternatecontrolmeasures         286
# [3] Not closed:Alternate controlmeasures    197
# measures                                    128
# Not closed:Alternate controlmeasures         74
# Not closed: Alternate control measures       70
# Name: workplace_status, dtype: int64

# %%
filters = {
    'workplace_status': ['n']
}
filter_df_any_condition(df, filters)[['index', 'HA', 'workplace_classification', 'workplace_status', 'file', 'doc_page_number']]
# Out:
# Filtered on workplace_status in ['n']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 9252, 9253
# ...

# %%
df[df['workplace_status'].str.endswith('non-closure)', na=False)]['workplace_status'].value_counts()
# Out:
# Open (ifopen,reason fornon-closure)       225
# Open (if open,reason for non-closure)      91
# Open (ifopen, reasonfor non-closure)       78
# Open (if open,reason fornon-closure)       26
# Open (if open, reason for non-closure)      3
# Open (if open, reasno for non-closure)      3
# non-closure)                                3
# Name: workplace_status, dtype: int64

# %%
df[df['workplace_status'].str.endswith('on', na=False)]['workplace_status'].value_counts()
# Out:
# Not closed:Insufficientevidence ofrecenttransmission          177
# [2] Notclosed:Insufficientevidence ofrecenttransmission       138
# [2] Notclosed:Insufficient evidenceof recenttransmission       86
# [2] Not closed:Insufficientevidence of recenttransmission      76
# Not closed: insufficient evidence of recent transmission       54
# transmission                                                   50
# Not closed:Insufficientevidence of recenttransmission          36
# on                                                             25
# Not closed:Insufficient evidenceof recenttransmission          23
# Open but EHOinvestigationunderway  todeterminetransmission      1
# Name: workplace_status, dtype: int64

# %%
df[df['workplace_status'].str.endswith('open', na=False)]['workplace_status'].value_counts()
# Out:
# Not closed:Publicinterest inremainingopen          108
# [4] Notclosed:Publicinterest inremainingopen        88
# open                                                49
# [4] Not closed:Public interest inremaining open     44
# [4] Notclosed: Publicinterest inremainingopen       40
# Not closed: Public interest in remaining open       39
# Not closed: Publicinterest inremaining open         22
# Not closed: Publicinterest in remainingopen         15
# Name: workplace_status, dtype: int64

# %%
df[df['workplace_status'].str.endswith('operator', na=False)]['workplace_status'].value_counts()
# Out:
# Voluntarilyclosed byoperator      114
# Voluntarily closedbyoperator       34
# Voluntarily closedby operator      28
# operator                           12
# Voluntarily closed by operator      6
# Voluntarily closed byoperator       1
# Name: workplace_status, dtype: int64

# %%
df[df['workplace_status'].str.endswith('order', na=False)]['workplace_status'].value_counts()
# Out:
# Closed byorder     10
# Closed by order     8
# order               1
# Name: workplace_status, dtype: int64

# %% [markdown]
# ## mapping

# %%
mapping = {
    '[1] Closed': 'Closed',
    '[2] Not closed:Insufficientevidence of recenttransmission': 'Not closed: insufficient evidence of recent transmission',
    '[2] Notclosed:Insufficient evidenceof recenttransmission': 'Not closed: insufficient evidence of recent transmission',
    '[2] Notclosed:Insufficientevidence ofrecenttransmission': 'Not closed: insufficient evidence of recent transmission',
    '[3] Not closed:Alternate controlmeasures': 'Not closed: Alternate control measures',
    '[3] Notclosed:Alternatecontrolmeasures': 'Not closed: Alternate control measures',
    '[4] Not closed:Public interest inremaining open': 'Not closed: Public interest in remaining open',
    '[4] Notclosed: Publicinterest inremainingopen': 'Not closed: Public interest in remaining open',
    '[4] Notclosed:Publicinterest inremainingopen': 'Not closed: Public interest in remaining open',
    '(not closed)': 'Essential function (not closed)',
    'closed)': 'Essential function (not closed)',
    'Closed': 'Closed',
    'closed': 'Not closed',
    'Closed by order': 'Closed by order',
    'Closed byorder': 'Closed by order',
    'Closed:voluntarily June 12-16, 2021.Monitoringfor additionalcases fromsecondexposuredates.': \
        'Closed voluntarily June 12-16, 2021. Monitoring for additional cases from second exposure dates.',
    'Closed:voluntarilyJune 12-16, 2021.Monitoring foradditional casesfrom secondexposure dates.': \
        'Closed voluntarily June 12-16, 2021. Monitoring for additional cases from second exposure dates.',
    'Closed:voluntarilyJune 12-16, 2021.Monitoring foradditionalcasesfromsecondexposuredates.': \
        'Closed voluntarily June 12-16, 2021. Monitoring for additional cases from second exposure dates.',
    'closure': 'Voluntary closure',
    'closure)': 'Open (if open, reason for non-closure)',
    'n': 'Not closed: insufficient evidence of recent transmission',
    'non-closure)': 'Open (if open, reason for non-closure)',
    'on': 'Not closed: insufficient evidence of recent transmission',
    'open': 'Not closed: Public interest in remaining open',
    'Open': 'Open',
    'operator': 'Voluntarily closed by operator',
    'order': 'Closed by order',
    'PH': 'Partially closed or widespread isolation by PH',
    'transmission': 'Not closed: insufficient evidence of recent transmission',
    'Unknown': 'Unknown',
    'worksite': 'Not a worksite',
    'Essential function (not closed)': "Essential function (not closed)",
    'Essential function(not closed': "Essential function (not closed)",
    'Essential function(not closed)': "Essential function (not closed)",
    'Essentialfunction (notclosed': "Essential function (not closed)",
    'Essentialfunction (notclosed)': "Essential function (not closed)",
    'Essentialfunction(not closed)': "Essential function (not closed)",
    'Essentialfunction(notclosed)': "Essential function (not closed)",
    'Follow-uppending': 'Follow-up pending',
    'Managed without closure (not closed)': 'Managed without closure (not closed)',
    'Managed withoutclosure (not closed)': 'Managed without closure (not closed)',
    'Managed withoutclosure (notclosed)': 'Managed without closure (not closed)',
    'Managedwithoutclosure (notclosed)': 'Managed without closure (not closed)',
    'Managedwithoutclosure(notclosed)': 'Managed without closure (not closed)',
    'Not a worksite': 'Not a worksite',
    'Not aworksite': 'Not a worksite',
    'Not closed': 'Not closed',
    'Notclosed': 'Not closed',
    'Not closed: Alternate control measures': 'Not closed: Alternate control measures',
    'Not closed:Alternate controlmeasures': 'Not closed: Alternate control measures',
    'Not closed:Alternatecontrolmeasures': 'Not closed: Alternate control measures',
    'Not closed: Public interest in remaining open': 'Not closed: Public interest in remaining open',
    'Not closed: Publicinterest in remainingopen': 'Not closed: Public interest in remaining open',
    'Not closed: Publicinterest inremaining open': 'Not closed: Public interest in remaining open',
    'Not closed:Publicinterest inremainingopen': 'Not closed: Public interest in remaining open',
    'Not closed:Insufficient evidenceof recenttransmission': 'Not closed: insufficient evidence of recent transmission',
    'Not closed:Insufficientevidence of recenttransmission': 'Not closed: insufficient evidence of recent transmission',
    'Not closed:Insufficientevidence ofrecenttransmission': 'Not closed: insufficient evidence of recent transmission',
    'Not closed: insufficient evidence of recent transmission': 'Not closed: insufficient evidence of recent transmission',
    'Open (if open, reasno for non-closure)': 'Open (if open, reason for non-closure)',
    'Open (if open, reason for non-closure)': 'Open (if open, reason for non-closure)',
    'Open (if open,reason for non-closure)': 'Open (if open, reason for non-closure)',
    'Open (if open,reason fornon-closure)': 'Open (if open, reason for non-closure)',
    'Open (ifopen, reasonfor non-closure)': 'Open (if open, reason for non-closure)',
    'Open (ifopen,reason fornon-closure)': 'Open (if open, reason for non-closure)',
    'Open but EHOinvestigationunderway  todeterminetransmission': 'Open but EHO investigation underway to determine transmission',
    'Ordered closed by PH': 'Ordered closed by PH',
    'Ordered closed byPH': 'Ordered closed by PH',
    'Orderedclosed by PH': 'Ordered closed by PH',
    'Orderedclosed byPH': 'Ordered closed by PH',
    'Partially closed': 'Partially closed',
    'Partiallyclosed': 'Partially closed',
    'Partially closed or widespread isolation by PH': 'Partially closed or widespread isolation by PH',
    'Partially closed orwidespread isolationby PH': 'Partially closed or widespread isolation by PH',
    'Partially closed orwidespreadisolation by PH': 'Partially closed or widespread isolation by PH',
    'Partiallyclosed orwidespread isolationby PH': 'Partially closed or widespread isolation by PH',
    'Partiallyclosed orwidespreadisolation byPH': 'Partially closed or widespread isolation by PH',
    'Voluntarily closed by operator': 'Voluntarily closed by operator',
    'Voluntarily closed byoperator': 'Voluntarily closed by operator',
    'Voluntarily closedby operator': 'Voluntarily closed by operator',
    'Voluntarily closedbyoperator': 'Voluntarily closed by operator',
    'Voluntarilyclosed byoperator': 'Voluntarily closed by operator',
    'Voluntary closure': 'Voluntary closure',
    'Voluntaryclosure': 'Voluntary closure',
    'closed by PH': 'Ordered closed by PH',
    'closure)': 'Open (if open, reason for non-closure)',
    'dates.': \
        'Closed voluntarily June 12-16, 2021. Monitoring for additional cases from second exposure dates.',
    'measures': 'Not closed: Alternate control measures',
}

corrected_df = pd.DataFrame()
corrected_df['workplace_status'] = df['workplace_status'].map(mapping)
print(len(sorted(corrected_df['workplace_status'].astype(str).unique())))
sorted(corrected_df['workplace_status'].astype(str).unique())
# Out:
# 21
# ['Closed',
#  'Closed by order',
#  'Closed voluntarily June 12-16, 2021. Monitoring for additional cases from second exposure dates.',
#  'Essential function (not closed)',
#  'Follow-up pending',
#  'Managed without closure (not closed)',
#  'Not a worksite',
#  'Not closed',
#  'Not closed: Alternate control measures',
#  'Not closed: Public interest in remaining open',
#  'Not closed: insufficient evidence of recent transmission',
#  'Open',
#  'Open (if open, reason for non-closure)',
#  'Open but EHO investigation underway to determine transmission',
#  'Ordered closed by PH',
#  'Partially closed',
#  'Partially closed or widespread isolation by PH',
#  'Unknown',
#  'Voluntarily closed by operator',
#  'Voluntary closure',
#  'nan']

# %%
corrected_df['workplace_status'].value_counts()
# Out:
# Closed                                                                                              4336
# Not closed: Alternate control measures                                                              1413
# Not closed                                                                                           924
# Open                                                                                                 884
# Not closed: insufficient evidence of recent transmission                                             682
# Open (if open, reason for non-closure)                                                               446
# Not closed: Public interest in remaining open                                                        405
# Unknown                                                                                              319
# Managed without closure (not closed)                                                                 297
# ...

# %%
df.loc[corrected_df[corrected_df['workplace_status'].astype(str) == 'nan'].index][['index', 'HA', 'workplace_classification', 'workplace_status', 'file', 'doc_page_number']]
# Out:
#        index   HA          workplace_classification workplace_status  \
# 9094     1.0  FHA             Restaurant/Bar/Lounge              NaN
# 9095     2.0  FHA                             Other              NaN
# 9099     6.0  FHA   Maintenance/Trades/Construction              NaN
# 9100     7.0  FHA                            Office              NaN
# 9101     8.0  FHA                    Transportation              NaN
# ...      ...  ...                               ...              ...
# 9074  1075.0  NHA  Health Care Facility (Acute/LTC)              NaN
# 9075  1076.0  NHA    Shelter/SRO/Congregate Housing              NaN
# 9078  1079.0  NHA  Health Care Facility (Acute/LTC)              NaN
# 9079  1080.0  NHA  Health Care Facility (Acute/LTC)              NaN
# 9084  1085.0  NHA  Health Care Facility (Acute/LTC)              NaN
#
#                             file  doc_page_number
# 9094  F22-1445 Records_Part1.pdf                1
# ...

# %%
df[df['workplace_status'].isna()]
# Out:
#        index   HA workplace_name workplace_address        city  \
# 9094     1.0  FHA           None              None      surrey
# 9095     2.0  FHA           None              None     langley
# 9099     6.0  FHA           None              None  chilliwack
# 9100     7.0  FHA           None              None   coquitlam
# 9101     8.0  FHA           None              None       delta
# ...      ...  ...            ...               ...         ...
# 9074  1075.0  NHA           None              None     unknown
# 9075  1076.0  NHA           None              None     unknown
# 9078  1079.0  NHA           None              None     unknown
# 9079  1080.0  NHA           None              None     unknown
# 9084  1085.0  NHA           None              None     unknown
#
#      date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 9094                           2021-04-01                    2021-04-17
# ...

# %%
set([value for value in df['workplace_status'] if type(value) == str]) - set(mapping.keys())
# Out:
# set()

# %% [markdown]
# # Save output

# %%
df['workplace_status'] = corrected_df['workplace_status']
print(len(sorted(df['workplace_status'].astype(str).unique())))
df['workplace_status'].value_counts()
# Out:
# 21
# Closed                                                                                              4336
# Not closed: Alternate control measures                                                              1413
# Not closed                                                                                           924
# Open                                                                                                 884
# Not closed: insufficient evidence of recent transmission                                             682
# Open (if open, reason for non-closure)                                                               446
# Not closed: Public interest in remaining open                                                        405
# Unknown                                                                                              319
# Managed without closure (not closed)                                                                 297
# ...

# %%
description = 'pdfs_parsed_2023-04-02_cleaned'
pickle_path = r'C:\Users\silvh\OneDrive\lighthouse\portfolio-projects\BC-Covid-workplace-closures\data\interim\pickles'
csv_path = None
save_output(df, description=description, csv_path=csv_path, pickle_path=pickle_path)
# Out:
# File saved:  C:/Users/silvh/OneDrive/lighthouse/portfolio-projects/BC-Covid-workplace-closures/data/interim/pickles/pdfs_parsed_2023-04-02_cleaned_2023-06-03_1622.sav
# Time completed: 2023-06-03 16:22:46.055219
# 	Object saved as pickle

# %% [markdown]
# # voluntary_closure

# %%
df['voluntary_closure'].value_counts()
# Out:
# Unknown          7978
# No               4052
# Yes              1249
# 4/21/2021 No        4
# 4/20/2021 No        4
# 4/21/2021 Yes       3
# 4/22/2021 No        2
# 5/20/2021 No        2
# 5/21/2021 No        2
# 5/19/2021 No        1
# 5/20/2021 Yes       1
# Name: voluntary_closure, dtype: int64

# %%
df['voluntary_closure'].str.replace(r'(?:.*\s)?([a-zA-Z]*)', r'\1', regex=True).unique()
# Out:
# array(['Unknown', 'No', 'Yes'], dtype=object)

# %%
corrected_df['voluntary_closure'] = df['voluntary_closure'].str.replace(r'(?:.*\s)?([a-zA-Z]*)', r'\1', regex=True)
df['voluntary_closure'].value_counts()
# Out:
# Unknown          7978
# No               4052
# Yes              1249
# 4/21/2021 No        4
# 4/20/2021 No        4
# 4/21/2021 Yes       3
# 4/22/2021 No        2
# 5/20/2021 No        2
# 5/21/2021 No        2
# 5/19/2021 No        1
# 5/20/2021 Yes       1
# Name: voluntary_closure, dtype: int64

# %%
df['voluntary_closure'] = corrected_df['voluntary_closure']

# %% [markdown]
# # partially_closed

# %%
df['partially_closed'].value_counts()
# Out:
# No           10035
# Unknown       2527
# Yes            692
# n               42
# 1/17/2022        1
# 1/31/2022        1
# Name: partially_closed, dtype: int64

# %%
filters = {
    'partially_closed': ['n']
}
filter_df_any_condition(df, filters)[['index', 'HA', 'workplace_classification', 'partially_closed', 'file', 'doc_page_number']]
# Out:
# Filtered on partially_closed in ['n']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 9252, 9253
# ...

# %%
corrected_df['partially_closed'] = df['partially_closed'].str.replace(r'^n$', r'Unknown', regex=True)
corrected_df['partially_closed'].value_counts()
# Out:
# No           10035
# Unknown       2569
# Yes            692
# 1/17/2022        1
# 1/31/2022        1
# Name: partially_closed, dtype: int64

# %%
filters = {
    'partially_closed': ['1/17/2022', '1/31/2022']
}
filter_df_any_condition(df, filters)[['index', 'HA', 'workplace_classification', 'partially_closed', 'file', 'doc_page_number']]
# Out:
# Filtered on partially_closed in ['1/17/2022', '1/31/2022']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9
# ...

# %%
corrected_df.loc[filter_df_any_condition(df, filters).index, 'partially_closed'] = 'No'
# Out:
# Filtered on partially_closed in ['1/17/2022', '1/31/2022']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9
# ...

# %%
corrected_df['partially_closed'].value_counts()
# Out:
# No         10037
# Unknown     2569
# Yes          692
# Name: partially_closed, dtype: int64

# %% [markdown]
# # open

# %%
df['open'].value_counts()
# Out:
# No           6711
# Yes          6485
# Unknown        36
# Unknow\rn      32
# Unknow          1
# 77 No           1
# Unkno           1
# Name: open, dtype: int64

# %%
corrected_df['open'] = df['open'].str.replace(
    '\r', '').str.replace(r'^Unkno$', r'Unknown', regex=True, n=1).str.replace(r'^Unknow$', r'Unknown', regex=True, n=1).str.replace('77 No', 'No')
corrected_df['open'].value_counts()
# Out:
# No         6712
# Yes        6485
# Unknown      70
# Name: open, dtype: int64

# %% [markdown]
# # active_clusters

# %%
df['active_clusters'].value_counts()
# Out:
# No         12061
# Yes          515
# 16-2021       41
# 14-2021       27
# 17-2021       23
# 29-2021       16
# 13-2021       14
# 18-2021       12
# 20-2021       12
# 22-2021        9
# 30-2021        9
# 21-2021        5
# 25-2021        4
# 26-2021        4
# 15-2021        4
# 28-2021        3
# 27-2021        2
# Name: active_clusters, dtype: int64

# %%
df['active_clusters'].unique()
# Out:
# array([nan, 'No', 'Yes', None, '18-2021', '21-2021', '16-2021', '20-2021',
#        '13-2021', '14-2021', '15-2021', '17-2021', '22-2021', '25-2021',
#        '26-2021', '27-2021', '28-2021', '29-2021', '30-2021'],
#       dtype=object)

# %%
corrected_df['active_clusters'] = df['active_clusters']
corrected_df['active_clusters'] = ['Yes' if value == 'Yes' else 'No' for value in corrected_df['active_clusters']]
corrected_df['active_clusters'].value_counts()
# Out:
# No     12783
# Yes      515
# Name: active_clusters, dtype: int64

# %%
filters = {
    'active_clusters': ['16-2021']
}
filter_df_all_conditions(df, filters)[['index', 'HA', 'workplace_classification', 'active_clusters', 'file', 'doc_page_number']]
# Out:
# Filtered on active_clusters in ['16-2021']
# Results where ALL conditions are met:
# 	DataFrame indices: [6220, 6221, 6222, 6223, 6224, 6225, 6226, 6227, 6228, 6229, 11476, 11477, 11478, 11479, 11480, 11481, 11482, 11483, 11484, 11485, 11486, 11487, 11488, 11489, 11490, 11491, 11492, 11493, 11494, 11495, 11496, 11497, 11498, 11499, 11500, 11501, 11502, 11503, 11504, 11505, 11506]
# 	DataFrame shape: (41, 27)
#        index   HA         workplace_classification active_clusters  \
# 6220   203.0  FHA                      Gym/Fitness         16-2021
# 6221   204.0  FHA                           Retail         16-2021
# 6222   205.0  FHA                      Gym/Fitness         16-2021
# 6223   206.0  FHA                            Other         16-2021
# 6224   207.0  VCH                   School/Daycare         16-2021
# ...      ...  ...                              ...             ...
# 11502  237.0  FHA                    Personal Care         16-2021
# ...

# %%
filter_df_all_conditions(df, filters)['file'].unique()
# Out:
# Filtered on active_clusters in ['16-2021']
# Results where ALL conditions are met:
# 	DataFrame indices: [6220, 6221, 6222, 6223, 6224, 6225, 6226, 6227, 6228, 6229, 11476, 11477, 11478, 11479, 11480, 11481, 11482, 11483, 11484, 11485, 11486, 11487, 11488, 11489, 11490, 11491, 11492, 11493, 11494, 11495, 11496, 11497, 11498, 11499, 11500, 11501, 11502, 11503, 11504, 11505, 11506]
# 	DataFrame shape: (41, 27)
# array(['F22-1445 Records_Part6.pdf', 'F22-1445 Records_Part3.pdf'],
#       dtype=object)

# %% [markdown]
# ### part6

# %%
filters = {
    'active_clusters': ['18-2021', '21-2021', '16-2021', '20-2021',
       '13-2021', '14-2021', '15-2021', '17-2021', '22-2021', '25-2021',
       '26-2021', '27-2021', '28-2021', '29-2021', '30-2021'],
    'file': ['F22-1445 Records_Part6.pdf']
}
filter_df_all_conditions(df, filters)[['index', 'HA', 'workplace_classification', 'active_clusters', 'file', 'doc_page_number']]
# Out:
# Filtered on active_clusters in ['18-2021', '21-2021', '16-2021', '20-2021', '13-2021', '14-2021', '15-2021', '17-2021', '22-2021', '25-2021', '26-2021', '27-2021', '28-2021', '29-2021', '30-2021']
# Filtered on file in ['f22-1445 records_part6.pdf']
# Results where ALL conditions are met:
# ...

# %%
filter_df_all_conditions(df, filters)['doc_page_number'].unique()
# Out:
# Filtered on active_clusters in ['18-2021', '21-2021', '16-2021', '20-2021', '13-2021', '14-2021', '15-2021', '17-2021', '22-2021', '25-2021', '26-2021', '27-2021', '28-2021', '29-2021', '30-2021']
# Filtered on file in ['f22-1445 records_part6.pdf']
# Results where ALL conditions are met:
# ...

# %%
filters = {
    'active_clusters': ['18-2021', '21-2021', '16-2021', '20-2021',
       '13-2021', '14-2021', '15-2021', '17-2021', '22-2021', '25-2021',
       '26-2021', '27-2021', '28-2021', '29-2021', '30-2021'],
    'file': ['F22-1445 Records_Part6.pdf'],
    'doc_page_number': "== 23"
}
filter_df_all_conditions(df, filters)[['index', 'HA', 'workplace_classification', 'active_clusters', 'file', 'doc_page_number']]
# Out:
# Filtered on active_clusters in ['18-2021', '21-2021', '16-2021', '20-2021', '13-2021', '14-2021', '15-2021', '17-2021', '22-2021', '25-2021', '26-2021', '27-2021', '28-2021', '29-2021', '30-2021']
# Filtered on file in ['f22-1445 records_part6.pdf']
# Results where ALL conditions are met:
# 	DataFrame indices: [6333, 6334, 6335, 6336, 6337, 6338, 6339, 6340, 6341, 6342]
# 	DataFrame shape: (10, 27)
#       index   HA         workplace_classification active_clusters  \
# 6333  323.0  IHA                 Farm/Agriculture         17-2021
# 6334  324.0  FHA                   Transportation         17-2021
# 6335  325.0  FHA                  Food Processing         17-2021
# 6336  326.0  FHA                        Warehouse         17-2021
# 6337  327.0  FHA            Restaurant/Bar/Lounge         17-2021
# 6338  328.0  FHA  Maintenance/Trades/Construction         17-2021
# 6339  329.0  FHA                   Transportation         17-2021
# ...

# %%
filters = {
    'active_clusters': ['yes'],
}
print(f"\n{filter_df_all_conditions(df, filters)['date_cluster_no_longer_active'].value_counts()}\n")
filter_df_all_conditions(df, filters).sort_values(['date_cluster_no_longer_active', 'file'])[['index', 'HA', 'workplace_classification', 'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active', 'active_clusters', 'file', 'doc_page_number']]
# Out:
# Filtered on active_clusters in ['yes']
# Results where ALL conditions are met:
# ...

# %% [markdown]
# `active_clusters` column should only be 'yes' if `date_cluser_no_konger_active` is blank

# %%
corrected_df.loc[[11741, 11738, 11748, 11740, 11739], 'active_clusters'] = 'No'

# %%
corrected_df['active_clusters'].value_counts()
# Out:
# No     12788
# Yes      510
# Name: active_clusters, dtype: int64

# %%
filters = {
    'active_clusters': ['no'],
}
print(f"\n{filter_df_all_conditions(df, filters)['date_cluster_no_longer_active'].value_counts()}\n")
filter_df_all_conditions(df, filters)[df['active_clusters'].isna()]
# Out:
# Filtered on active_clusters in ['no']
# Results where ALL conditions are met:
# ...

# %% [markdown]
# # closed_by_order

# %%
df['closed_by_order'].value_counts()
# Out:
# No             10112
# Yes             3099
# Unkno             24
# No Unknown        24
# Yes Unknown       15
# No No              3
# No Yes             1
# Name: closed_by_order, dtype: int64

# %%
filters = {
    'closed_by_order': ['No Unknown']
}
filter_df_any_condition(df, filters)[['index', 'HA', 'workplace_classification', 'workplace_status', 'closed_by_order', 'file', 'doc_page_number']]
# Out:
# Filtered on closed_by_order in ['no unknown']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 92
# ...

# %%
corrected_df.loc[filter_df_any_condition(df, filters).index, 'closed_by_order'] = 'No'
# Out:
# Filtered on closed_by_order in ['no unknown']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 92
# ...

# %%
filters = {
    'closed_by_order': ['Yes Unknown']
}
filter_df_any_condition(df, filters)[['index', 'HA', 'workplace_classification', 'workplace_status', 'closed_by_order', 'file', 'doc_page_number']]
# Out:
# Filtered on closed_by_order in ['yes unknown']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 9
# ...

# %%
corrected_df.loc[filter_df_any_condition(df, filters).index, 'closed_by_order'] = 'Yes'
# Out:
# Filtered on closed_by_order in ['yes unknown']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 9
# ...

# %% [markdown]
# ## Unkno

# %%
filters = {
    'closed_by_order': ['Unkno']
}
filter_df_any_condition(df, filters)[['index', 'HA', 'workplace_classification', 'workplace_status', 'closed_by_order', 'file', 'doc_page_number']]
# Out:
# Filtered on closed_by_order in ['unkno']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 9252, 9
# ...

# %%
corrected_df.loc[9239, 'closed_by_order'] = 'Unknown'
corrected_df['closed_by_order'].value_counts()
# Out:
# No         24
# Yes        15
# Unknown     1
# Name: closed_by_order, dtype: int64

# %% [markdown]
# ## No No

# %%
filters = {
    'closed_by_order': ['No No']
}
filter_df_any_condition(df, filters)[['index', 'HA', 'workplace_classification', 'workplace_status', 'closed_by_order', 'file', 'doc_page_number']]
corrected_df.loc[filter_df_any_condition(df, filters).index, 'closed_by_order'] = 'No'
# Out:
# Filtered on closed_by_order in ['no no']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 9252, 9
# ...

# %% [markdown]
# ## No Yes

# %%
filters = {
    'closed_by_order': ['No Yes']
}
filter_df_any_condition(df, filters)[['index', 'HA', 'workplace_classification', 'workplace_status', 'closed_by_order', 'file', 'doc_page_number']]
# Out:
# Filtered on closed_by_order in ['no yes']: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 9252, 
# ...

# %%
corrected_df.loc[11734, 'closed_by_order'] = 'No'
corrected_df['closed_by_order'].value_counts()
# Out:
# No         28
# Yes        15
# Unknown     1
# Name: closed_by_order, dtype: int64

# %% [markdown]
# # Consolidate `workplace_status`

# %%
corrected_df['workplace_status'].value_counts().sort_index()
# Out:
# Closed                                                                                              4336
# Closed by order                                                                                       19
# Closed voluntarily June 12-16, 2021. Monitoring for additional cases from second exposure dates.       5
# Essential function (not closed)                                                                       99
# Follow-up pending                                                                                      1
# Managed without closure (not closed)                                                                 297
# Not a worksite                                                                                       160
# Not closed                                                                                           924
# Not closed: Alternate control measures                                                              1413
# ...

# %% [markdown]
# ## compare with closure_y_n

# %%
df[df['workplace_status'] == 'Open']['closure_y_n'].value_counts()
# Out:
# No    884
# Name: closure_y_n, dtype: int64

# %%
df[df['workplace_status'] == 'Partially closed or widespread isolation by PH']['closure_y_n'].value_counts()
# Out:
# Yes    262
# Name: closure_y_n, dtype: int64

# %%
corrected_df.columns
# Out:
# Index(['workplace_status', 'voluntary_closure', 'partially_closed', 'open',
#        'active_clusters', 'closed_by_order'],
#       dtype='object')

# %% [markdown]
# ## compare with voluntary_closure

# %%
filters = {
    'workplace_status': ['Closed'],
    'voluntary_closure': ['Yes']
}
filter_df_all_conditions(df, filters)['voluntary_closure'].value_counts()
# Out:
# Filtered on workplace_status in ['closed']
# Filtered on voluntary_closure in ['yes']
# Results where ALL conditions are met:
# ...

# %%
corrected_df['workplace_status'].value_counts()
# Out:
# Closed                                                                                              4336
# Not closed: Alternate control measures                                                              1413
# Not closed                                                                                           924
# Open                                                                                                 884
# Not closed: insufficient evidence of recent transmission                                             682
# Open (if open, reason for non-closure)                                                               446
# Not closed: Public interest in remaining open                                                        405
# Unknown                                                                                              319
# Managed without closure (not closed)                                                                 297
# ...

# %%
corrected_df[corrected_df['workplace_status'] == 'Closed by order']['voluntary_closure'].value_counts()
# Out:
# No    19
# Name: voluntary_closure, dtype: int64

# %%
corrected_df[corrected_df['workplace_status'] == 'Closed by order']['closed_by_order'].value_counts()
# Out:
# Series([], Name: closed_by_order, dtype: int64)

# %%
corrected_df[corrected_df['workplace_status'] == 'Ordered closed by PH']['closed_by_order'].value_counts()
# Out:
# Series([], Name: closed_by_order, dtype: int64)

# %%
corrected_df['consolidated_status'] = corrected_df['workplace_status'].str.replace(
    r'Closed .*', r'Closed', regex=True
).str.replace(
    r'Not closed.*', r'Not closed', regex=True
).str.replace(
    r'^Open.*', r'Not closed', regex=True
).str.replace(
    r'^Partially closed$', r'Partially closed or widespread isolation by PH', regex=True
).str.replace(
    r'Voluntarily closed by operator', r'Closed', regex=True
).str.replace(
    r'Voluntary closure', r'Closed', regex=True
).str.replace(
    r'Follow-up pending', r'Unknown', regex=True
).str.replace(
    r'Managed without closure \(not closed\)\s*?', r'Not closed', regex=True
).str.replace(
    r'Voluntarily closed', r'Closed', regex=True
).str.replace(
    r'Ordered closed by PH', r'Closed', regex=True
).str.replace(
    r'Follow-up pending', r'Unknown', regex=True
)
corrected_df['consolidated_status'].value_counts()
# Out:
# Not closed                                        5052
# Closed                                            4807
# Unknown                                            320
# Partially closed or widespread isolation by PH     278
# Not a worksite                                     160
# Essential function (not closed)                     99
# Name: consolidated_status, dtype: int64

# %%
corrected_df.values
# Out:
# array([[nan, 'Unknown', 'No', ..., 'No', nan, nan],
#        [nan, 'Unknown', 'No', ..., 'No', nan, nan],
#        ['Closed', 'Unknown', 'No', ..., 'No', nan, 'Closed'],
#        ...,
#        ['Closed', 'Yes', 'No', ..., 'No', nan, 'Closed'],
#        ['Closed', 'Yes', 'No', ..., 'No', nan, 'Closed'],
#        ['Closed', 'Yes', 'No', ..., 'No', nan, 'Closed']], dtype=object)

# %% [markdown]
# # Transfer corrections to `df`

# %%
df[corrected_df.columns] = corrected_df.values
print(df['workplace_status'].value_counts())
print()

print(df['consolidated_status'].value_counts())
df
# Out:
# Closed                                                                                              4336
# Not closed: Alternate control measures                                                              1413
# Not closed                                                                                           924
# Open                                                                                                 884
# Not closed: insufficient evidence of recent transmission                                             682
# Open (if open, reason for non-closure)                                                               446
# Not closed: Public interest in remaining open                                                        405
# Unknown                                                                                              319
# Managed without closure (not closed)                                                                 297
# ...

# %%
filter = {
    'workplace_status': 'null'
}
filter_df_any_condition(df, filter)
# Out:
# Filtered on workplace_status in null: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 9252, 9253,
# ...

# %%
filter_df_any_condition(df, filter)['closure_y_n'].value_counts()
# Out:
# Filtered on workplace_status in null: [9094, 9095, 9096, 9097, 9098, 9099, 9100, 9101, 9102, 9103, 9104, 9105, 9106, 9107, 9108, 9109, 9110, 9111, 9112, 9113, 9114, 9115, 9116, 9117, 9118, 9119, 9120, 9121, 9122, 9123, 9124, 9125, 9126, 9127, 9128, 9129, 9130, 9131, 9132, 9133, 9134, 9135, 9136, 9137, 9138, 9139, 9140, 9141, 9142, 9143, 9144, 9145, 9146, 9147, 9148, 9149, 9150, 9151, 9152, 9153, 9154, 9155, 9156, 9157, 9158, 9159, 9160, 9161, 9162, 9163, 9164, 9165, 9166, 9167, 9168, 9169, 9170, 9171, 9172, 9173, 9174, 9175, 9176, 9177, 9178, 9179, 9180, 9181, 9182, 9183, 9184, 9185, 9186, 9187, 9188, 9189, 9190, 9191, 9192, 9193, 9194, 9195, 9196, 9197, 9198, 9199, 9200, 9201, 9202, 9203, 9204, 9205, 9206, 9207, 9208, 9209, 9210, 9211, 9212, 9213, 9214, 9215, 9216, 9217, 9218, 9219, 9220, 9221, 9222, 9223, 9224, 9225, 9226, 9227, 9228, 9229, 9230, 9231, 9232, 9233, 9234, 9235, 9236, 9237, 9238, 9239, 9240, 9241, 9242, 9243, 9244, 9245, 9246, 9247, 9248, 9249, 9250, 9251, 9252, 9253,
# ...

# %%
filter = {
    'workplace_status': 'null',
    'closed_by_order': ['No']
}
filter_df_all_conditions(df, filter)['voluntary_closure'].value_counts()
# Out:
# Filtered on closed_by_order in ['no']
# Results where ALL conditions are met:
# 	DataFrame indices: [11476, 11477, 11478, 11479, 11480, 11481, 11482, 11483, 11484, 11493, 11494, 11495, 11496, 11497, 11498, 11499, 11500]
# 	DataFrame shape: (17, 28)
# No    17
# Name: voluntary_closure, dtype: int64

# %%
filter = {
    'workplace_status': 'null',
    'closure_y_n': ['No']
}
filter_df_all_conditions(df, filter)['voluntary_closure'].value_counts()
# Out:
# Filtered on closure_y_n in ['no']
# Results where ALL conditions are met:
# ...

# %% [markdown]
# Missing workplace_status values can be inferred from these columns:
# * closure_y_n
# * closed_by_order
# * voluntary_closure
# * partially_closed
# * open

# %% [markdown]
# ## confirm if 'open' and 'closure_y_n' match or not. They do not.

# %%
df[df['open'] == 'Yes']['closure_y_n'].value_counts()
# Out:
# No     4806
# Yes    1671
# Name: closure_y_n, dtype: int64

# %%
df[df['open'] == 'No']['closure_y_n'].value_counts()
# Out:
# Yes        3388
# No         2988
# Unknown     319
# Name: closure_y_n, dtype: int64

# %%
filters = {
    'open': ['No'],
    'closure_y_n': ['No']
}
filter_df_all_conditions(df, filters, view_columns=['index', 'open', 'closure_y_n', 'file', 'doc_page_number'])
# Out:
# Filtered on open in ['no']
# Filtered on closure_y_n in ['no']
# Results where ALL conditions are met:
# ...

# %% [markdown]
# # Save outputs

# %%
description = 'pdfs_parsed_2023-04-02_cleaned'
pickle_path = r'C:\Users\silvh\OneDrive\lighthouse\portfolio-projects\BC-Covid-workplace-closures\data\interim\pickles'
csv_path = None
save_output(df, description=description, csv_path=csv_path, pickle_path=pickle_path)
# Out:
# File saved:  C:/Users/silvh/OneDrive/lighthouse/portfolio-projects/BC-Covid-workplace-closures/data/interim/pickles/pdfs_parsed_2023-04-02_cleaned_2023-06-03_2327.sav
# Time completed: 2023-06-03 23:27:11.571662
# 	Object saved as pickle

# %%
sorted(df['city'].astype(str).unique())
# Out:
# ['70 mile',
#  'None',
#  'abbotsford',
#  'agassiz',
#  'alberni',
#  'armstrong',
#  'blue river',
#  'brentwood bay',
#  'burnaby',
#  'campbell river',
#  'canal flats',
#  'castlegar',
#  'cawston',
#  'cawston/keremeos',
#  'chase',
#  'chilliwack',
#  'clearwater',
#  'cobble hill',
#  'coldstream',
#  'comox',
#  'comox strathcona',
#  'coquitlam',
#  'courtenay',
#  'cowichan',
#  'cowichan bay',
#  'cranbrook',
#  'crescent valley',
#  'creston',
#  'crofton',
#  'cumberland',
#  'deep bay',
#  'delta',
#  'denman island',
#  'duncan',
#  'elk valley',
#  'elkford',
#  'esquimalt',
#  'fernie',
#  'gold river',
#  'golden',
#  'grand forks',
#  'hope',
#  'hornby island',
#  'invermere',
#  'kamloops',
#  'kelowna',
#  'kimberley',
#  'ladysmith',
#  'lake country',
#  'lake cowichan',
#  'langford',
#  'langley',
#  'lee creek',
#  'logan lake',
#  'lumby',
#  'maple ridge',
#  'mcleese lake',
#  'mill bay',
#  'mission',
#  'mount currie',
#  'nanaimo',
#  'nanoose bay',
# ...

# %% [markdown]
# # convert city to title case

# %%
df['city'].str.title().astype(str).unique()
# Out:
# array(['Surrey', 'Langley', 'Burnaby', 'Chilliwack', 'Coquitlam', 'Delta',
#        'Maple Ridge', 'Mission', 'Abbotsford', 'Port Coquitlam',
#        'Pitt Meadows', 'Unknown', 'New Westminster', 'Port Moody',
#        'Agassiz', 'Victoria', 'Duncan', 'Nanaimo', 'Langford',
#        'West Vancouver', 'North Vancouver', 'Vancouver',
#        'Cawston/Keremeos', 'Richmond', 'Kelowna', 'Summerland',
#        'Ladysmith', 'Nelson', 'Winfield', 'Golden', 'Penticton', 'Trail',
#        'Chase', 'Vernon', 'Deep Bay', 'Elk Valley', 'Oak Bay', 'Osoyoos',
#        'Victoria/Saanich', 'Oliver', 'Parsons', 'Kamloops',
#        'Brentwood Bay', 'Powell River', 'Sidney', 'Saanich',
#        'West Kelowna', 'Coldstream', 'Armstrong', 'Robson',
#        'Lake Country', 'Castlegar', 'Cranbrook', 'Elkford', 'Creston',
#        'Revelstoke', 'Salmon Arm', 'Hope', 'Nanoose Bay', 'Tofino',
#        'Port Renfrew', 'Courtenay', 'Lumby', 'Denman Island',
# ...

# %%
df['city'] = df['city'].str.title()
df
# Out:
#        index   HA workplace_name workplace_address        city  \
# 9094     1.0  FHA           None              None      Surrey
# 9095     2.0  FHA           None              None     Langley
# 9096     3.0  FHA           None              None      Surrey
# 9097     4.0  FHA           None              None     Burnaby
# 9098     5.0  FHA           None              None     Burnaby
# ...      ...  ...            ...               ...         ...
# 9089  1090.0  IHA           None              None    Kamloops
# 9090  1091.0  IHA           None              None    Kamloops
# 9091  1092.0  IHA           None              None  Revelstoke
# 9092  1093.0  IHA           None              None        None
# 9093  1094.0  IHA           None              None        None
#
#      date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 9094                           2021-04-01                    2021-04-17
# ...

# %% [markdown]
# # Save outputs including CSV

# %%
description = 'pdfs_parsed_2023-04-02_cleaned'
pickle_path = r'C:\Users\silvh\OneDrive\lighthouse\portfolio-projects\BC-Covid-workplace-closures\data\interim\pickles'
csv_path = r'C:\Users\silvh\OneDrive\lighthouse\portfolio-projects\BC-Covid-workplace-closures\data\interim'
save_output(df, description=description, csv_path=csv_path, pickle_path=pickle_path)
# Out:
# File saved:  C:/Users/silvh/OneDrive/lighthouse/portfolio-projects/BC-Covid-workplace-closures/data/interim/pickles/pdfs_parsed_2023-04-02_cleaned_2023-06-03_2335.sav
# Time completed: 2023-06-03 23:35:45.082141
# 	Object saved as pickle
# File saved:  C:/Users/silvh/OneDrive/lighthouse/portfolio-projects/BC-Covid-workplace-closures/data/interim/pdfs_parsed_2023-04-02_cleaned_2023-06-03_2335.csv
# Time completed: 2023-06-03 23:35:45.495508
# 	DataFrame saved as CSV

# %% [markdown]
# # *End of Page*
