# %%
from pandas import json_normalize  
import pandas as pd
import sys
sys.path.append(r"C:\Users\silvh\OneDrive\lighthouse\custom_python")
sys.path.append(r"C:\Users\silvh\OneDrive\lighthouse\portfolio-projects\online-PT-social-media-NLP\src")
from silvhua import *
from datetime import datetime
# import json
# from plotly.subplots import make_subplots
# import requests

# %% [markdown]
# # Display Settings

# %%
# set the option to wrap text within cells
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)

# %% [markdown]
# # Load objects from previous notebook

# %% [markdown]
# ## fixed_df_dict

# %%
fixed_df_dict_filename = 'fixed_df_dict_2023-04-23_2230.sav'
pickle_path = r"C:\Users\silvh\OneDrive\lighthouse\portfolio-projects\BC-Covid-workplace-closures\data\interim"
fixed_df_dict = loadpickle(fixed_df_dict_filename, pickle_path)
fixed_df_dict.keys()
# Out:
# Time completed: 2023-04-25 18:49:03.791087
# dict_keys(['Part2_page10', 'Part2_page19', 'Part2_page42', 'Part2_page44', 'Part2_page45', 'Part2_page48'])

# %% [markdown]
# ## Okay rows

# %%
df_filename = 'pdfs_parsed_2023-04-02_okay_rows_2023-04-22_1513.sav'
df = loadpickle(df_filename, pickle_path)
df
# Out:
# Time completed: 2023-04-25 18:49:04.324916
# Dataframe shape:  (12820, 27)
# DataFrame columns: ['index', 'HA', 'workplace_name', 'workplace_address', 'city', 'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active', 'earliest_reported_cases', 'latest_reported_cases', 'workplace_classification', 'cases_when_cluster_confirmed', 'total_cases', 'workplace_status', 'closure_y_n', 'closed_by_order', 'voluntary_closure', 'closure_date', 'partially_closed', 'unknown_closure_type', 'open', 'days_since_last_case', 'active_clusters', 'cluster_confirmed_epidate', 'doc_page_number', 'cluster_closed_epidate', 'file', 'flag']
#        index   HA workplace_name workplace_address             city  \
# 0      179.0  FHA            NaN              None       ABBOTSFORD
# 1      180.0  FHA            NaN              None            DELTA
# 2      181.0  FHA            NaN              None  PORT\rCOQUITLAM
# 3      182.0  VCH            NaN              None        Vancouver
# 4      183.0  NHA            NaN              None          Unknown
# ...      ...  ...            ...               ...              ...
# 13294  113.0  FHA           None              None           SURREY
# 13295  114.0  FHA           None              None           SURREY
# 13296  115.0  FHA           None              None           SURREY
# 13297  116.0  FHA           None              None           SURREY
# 13298  117.0  VCH           None              None        Vancouver
#
#       date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 0                      2021-04-14 00:00:00           2021-05-03 00:00:00
# 1                      2021-04-14 00:00:00           2021-05-09 00:00:00
# 2                      2021-04-14 00:00:00           2021-05-06 00:00:00
# 3                      2021-04-14 00:00:00                           NaT
# 4                      2021-04-14 00:00:00           2021-04-29 00:00:00
# ...                                    ...                           ...
# 13294                  2021-04-09 00:00:00           2021-04-26 00:00:00
# 13295                  2021-04-09 00:00:00           2021-04-21 00:00:00
# 13296                  2021-04-09 00:00:00           2021-04-23 00:00:00
# 13297                  2021-04-09 00:00:00           2021-05-29 00:00:00
# 13298                  2021-04-09 00:00:00                           NaT
#
#       earliest_reported_cases latest_reported_cases  \
# 0                         NaT                   NaT
# 1                         NaT                   NaT
# 2                         NaT                   NaT
# 3         2021-04-14 00:00:00   2021-05-05 00:00:00
# 4                         NaT                   NaT
# ...                       ...                   ...
# 13294                     NaT                   NaT
# 13295                     NaT                   NaT
# 13296                     NaT                   NaT
# 13297                     NaT                   NaT
# 13298     2021-04-09 00:00:00   2021-04-30 00:00:00
#
#                   workplace_classification cases_when_cluster_confirmed  \
# 0                       Farm/Agricultu\rre                            3
# 1                                   Retail                           11
# 2      Maintenance/T\rrades/Construc\rtion                            5
# 3                 Manufacturing\r/Industry                          NaN
# 4      Maintenance/T\rrades/Construc\rtion                            3
# ...                                    ...                          ...
# 13294                               Retail                            4
# 13295                               Office                            4
# 13296                               Office                            6
# 13297                      Food Processing                           11
# 13298                                Other                          NaN
#
#       total_cases                                    workplace_status  \
# 0               3                                              Closed
# 1              11                                                 NaN
# 2               5                                              Closed
# 3               4  Partially\rclosed or\rwidespread\risolation by\rPH
# 4               4                                  Voluntary\rclosure
# ...           ...                                                 ...
# 13294           4                                                 NaN
# 13295           4                                                 NaN
# 13296           6                                          [1] Closed
# 13297          11                                                 NaN
# 13298           5                                     Not a\rworksite
#
#       closure_y_n closed_by_order voluntary_closure         closure_date  \
# 0             Yes             Yes           Unknown  2021-04-15 00:00:00
# 1              No              No           Unknown                  NaT
# 2             Yes             Yes           Unknown  2021-04-14 00:00:00
# 3             Yes              No                No                  NaT
# 4             Yes              No               Yes                  NaT
# ...           ...             ...               ...                  ...
# 13294          No              No           Unknown                  NaT
# 13295          No              No           Unknown                  NaT
# 13296         Yes             Yes           Unknown  2021-04-12 00:00:00
# 13297          No              No           Unknown                  NaT
# 13298          No              No                No                  NaT
#
#       partially_closed unknown_closure_type open days_since_last_case  \
# 0                   No                  NaN   No                  NaN
# 1                   No                  NaN   No                  NaN
# 2                   No                  NaN   No                  NaN
# 3                  Yes                  NaN   No                  NaN
# 4              Unknown                  NaN   No                  NaN
# ...                ...                  ...  ...                  ...
# 13294               No                   No   No                  NaN
# 13295               No                   No   No                  NaN
# 13296               No                   No  Yes                  NaN
# 13297               No                   No   No                  NaN
# 13298               No                   No  Yes                  NaN
#
#       active_clusters cluster_confirmed_epidate doc_page_number  \
# 0                  No                   15-2021               1
# 1                  No                   15-2021               1
# 2                  No                   15-2021               1
# 3                  No                   15-2021               1
# 4                  No                   15-2021               1
# ...               ...                       ...             ...
# 13294              No                   14-2021             143
# 13295              No                   14-2021             143
# 13296              No                   14-2021             143
# 13297              No                   14-2021             143
# 13298              No                   14-2021             143
#
#       cluster_closed_epidate                        file flag
# 0                        NaN  F22-1445 Records_Part2.pdf
# 1                        NaN  F22-1445 Records_Part2.pdf
# 2                        NaN  F22-1445 Records_Part2.pdf
# 3                        NaN  F22-1445 Records_Part2.pdf
# 4                        NaN  F22-1445 Records_Part2.pdf
# ...                      ...                         ...  ...
# 13294                    NaN  F22-1445 Records_Part3.pdf
# 13295                    NaN  F22-1445 Records_Part3.pdf
# 13296                    NaN  F22-1445 Records_Part3.pdf
# 13297                    NaN  F22-1445 Records_Part3.pdf
# 13298                    NaN  F22-1445 Records_Part3.pdf
#
# [12820 rows x 27 columns]

# %% [markdown]
# ## problem_pages

# %%
problem_pages = loadpickle('pdfs_parsed_2023-04-02_problem_pages_2023-04-22_1513.sav', pickle_path)
problem_pages
# Out:
# Time completed: 2023-04-25 18:49:04.481843
# Dataframe shape:  (51, 2)
# DataFrame columns: ['file', 'doc_page_number']
#                              file doc_page_number
# 175    F22-1445 Records_Part2.pdf              10
# 318    F22-1445 Records_Part2.pdf              19
# 689    F22-1445 Records_Part2.pdf              42
# 717    F22-1445 Records_Part2.pdf              44
# 729    F22-1445 Records_Part2.pdf              45
# ...                           ...             ...
# 11763  F22-1445 Records_Part3.pdf              39
# 11778  F22-1445 Records_Part3.pdf              40
# 11804  F22-1445 Records_Part3.pdf              42
# 12208  F22-1445 Records_Part3.pdf              66
# 12351  F22-1445 Records_Part3.pdf              76
#
# [51 rows x 2 columns]

# %% [markdown]
# ## problem_rows

# %%
problem_rows = loadpickle('pdfs_parsed_2023-04-02_bad_rows_2023-04-22_1513.sav', pickle_path)
problem_rows
# Out:
# Time completed: 2023-04-25 18:49:04.776308
# Dataframe shape:  (479, 27)
# DataFrame columns: ['index', 'HA', 'workplace_name', 'workplace_address', 'city', 'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active', 'earliest_reported_cases', 'latest_reported_cases', 'workplace_classification', 'cases_when_cluster_confirmed', 'total_cases', 'workplace_status', 'closure_y_n', 'closed_by_order', 'voluntary_closure', 'closure_date', 'partially_closed', 'unknown_closure_type', 'open', 'days_since_last_case', 'active_clusters', 'cluster_confirmed_epidate', 'doc_page_number', 'cluster_closed_epidate', 'file', 'flag']
#        index   HA workplace_name workplace_address       city  \
# 175    354.0  NHA            NaN              None    Unknown
# 318    497.0  NHA            NaN              None    Unknown
# 689    318.0  FHA            NaN              None     SURREY
# 690    319.0  FHA            NaN              None     SURREY
# 691    320.0  FHA            NaN              None     SURREY
# ...      ...  ...            ...               ...        ...
# 11816  551.0  FHA           None              None      DELTA
# 11817  552.0  IHA           None              None    Kelowna
# 11818  553.0  IHA           None              None  Armstrong
# 12208  355.0  NHA           None              None     nknown
# 12351  498.0  NHA           None              None     nknown
#
#       date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 175                               5/3/2021                     6/15/2021
# 318                              5/25/2021                      6/7/2021
# 689                              4/28/2021                      5/6/2021
# 690                              4/28/2021                     5/29/2021
# 691                              4/28/2021                     5/14/2021
# ...                                    ...                           ...
# 11816                            6/27/2021                     7/20/2021
# 11817                            6/29/2021                          None
# 11818                            6/30/2021                          None
# 12208                             5/3/2021                     6/15/2021
# 12351                            5/25/2021                      6/7/2021
#
#       earliest_reported_cases latest_reported_cases  workplace_classification  \
# 175                      None                  None                        re
# 318                      None                  None                 /Industry
# 689                      None                 Other                      None
# 690                      None                Retail                      None
# 691                      None            nstruction                      None
# ...                       ...                   ...                       ...
# 11816                    None           ng/Industry                      None
# 11817               6/29/2021  7/7/2021 ng/Industry                      None
# 11818               6/30/2021  7/4/2021 ng/Industry                      None
# 12208                     NaN                   NaN        Farm/Agricultur\re
# 12351                     NaN                   NaN  Manufacturing/\rIndustry
#
#       cases_when_cluster_confirmed     total_cases    workplace_status  \
# 175                              1              10               order
# 318                              3               6             closure
# 689                              3  3 transmission                None
# 690                              4        4 Closed                None
# 691                              6          6 open                None
# ...                            ...             ...                 ...
# 11816                            3               3            measures
# 11817                            3               3          Not closed
# 11818                            3               3          Not closed
# 12208                          1.0              10    Closed by\rorder
# 12351                            3               6  Voluntary\rclosure
#
#       closure_y_n closed_by_order voluntary_closure closure_date  \
# 175           Yes             Yes                No    #########
# 318           Yes              No               Yes    #########
# 689            No              No           Unknown         None
# 690           Yes             Yes           Unknown    4/29/2021
# 691            No              No           Unknown         None
# ...           ...             ...               ...          ...
# 11816          No      No Unknown                No         None
# 11817          No           No No           Unknown         None
# 11818          No           No No           Unknown         None
# 12208         Yes             Yes                No    #########
# 12351         Yes              No               Yes    #########
#
#       partially_closed unknown_closure_type open days_since_last_case  \
# 175            Unknown                  NaN   No                 None
# 318            Unknown                  NaN   No                 None
# 689                 No                  NaN  Yes                 None
# 690                 No                  NaN   No                 None
# 691                 No                  NaN  Yes                 None
# ...                ...                  ...  ...                  ...
# 11816              Yes                  NaN   No                 None
# 11817              Yes                  NaN   No                 None
# 11818              Yes                  NaN   No                 None
# 12208        Unknow\rn                  NaN   No                  NaN
# 12351        Unknow\rn                  NaN   No                  NaN
#
#       active_clusters cluster_confirmed_epidate doc_page_number  \
# 175                No                   18-2021              10
# 318                No                   21-2021              19
# 689                No                   17-2021              42
# 690                No                   17-2021              42
# 691                No                   17-2021              42
# ...               ...                       ...             ...
# 11816         26-2021                      None              42
# 11817         26-2021                      None              42
# 11818         26-2021                      None              42
# 12208              No                   18-2021              66
# 12351              No                   21-2021              76
#
#       cluster_closed_epidate                        file flag
# 175                  4438965  F22-1445 Records_Part2.pdf    1
# 318                  4441094  F22-1445 Records_Part2.pdf    1
# 689                     None  F22-1445 Records_Part2.pdf    1
# 690                  17-2021  F22-1445 Records_Part2.pdf    1
# 691                     None  F22-1445 Records_Part2.pdf    1
# ...                      ...                         ...  ...
# 11816                    NaN  F22-1445 Records_Part3.pdf    1
# 11817                    NaN  F22-1445 Records_Part3.pdf    1
# 11818                    NaN  F22-1445 Records_Part3.pdf    1
# 12208           13-\r4438965  F22-1445 Records_Part3.pdf    1
# 12351                    NaN  F22-1445 Records_Part3.pdf    1
#
# [479 rows x 27 columns]

# %% [markdown]
# ## problem_pages

# %%
problem_pages = loadpickle('pdfs_parsed_2023-04-02_problem_pages_2023-04-22_1513.sav', pickle_path)
problem_pages
# Out:
# Time completed: 2023-04-25 18:49:05.051423
# Dataframe shape:  (51, 2)
# DataFrame columns: ['file', 'doc_page_number']
#                              file doc_page_number
# 175    F22-1445 Records_Part2.pdf              10
# 318    F22-1445 Records_Part2.pdf              19
# 689    F22-1445 Records_Part2.pdf              42
# 717    F22-1445 Records_Part2.pdf              44
# 729    F22-1445 Records_Part2.pdf              45
# ...                           ...             ...
# 11763  F22-1445 Records_Part3.pdf              39
# 11778  F22-1445 Records_Part3.pdf              40
# 11804  F22-1445 Records_Part3.pdf              42
# 12208  F22-1445 Records_Part3.pdf              66
# 12351  F22-1445 Records_Part3.pdf              76
#
# [51 rows x 2 columns]

# %% [markdown]
# # Functions from previous notebook

# %% [markdown]
# ## `view_problem_page` function

# %%
def view_problem_page(index, problem_pages_df=problem_pages, problem_rows_df=problem_rows, 
    part_num_column = 'file', page_num_column = 'doc_page_number'):
    date_columns = [
        'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active',
        'earliest_reported_cases', 'latest_reported_cases', 
        'closure_date',
    ]
    integer_columns = [
        'cases_when_cluster_confirmed', 
        'total_cases', 'days_since_last_case',
    ]
    file = problem_pages_df.iloc[index][part_num_column]
    page_num = problem_pages_df.iloc[index][page_num_column]
    print(f'Implicit index {index}: {file} page {page_num}')
    filter = (problem_rows_df[part_num_column] == file) & (problem_rows_df[page_num_column] == page_num)
    page = problem_rows_df[filter]
    page_copy = page.copy()
    problem_date_columns = []
    problem_integer_columns = []
    for column in date_columns:
        try:
            page_copy[column] = page_copy[column].apply(pd.to_datetime, format='%m/%d/%Y')
        except:
            problem_date_columns.append(column)
    for column in integer_columns:
        try:
            page_copy[column] = page_copy[column].apply(pd.to_numeric)
        except:
            problem_integer_columns.append(column)
    print(f'Could not convert to datetime: {[column for column in problem_date_columns]}')
    print(f'Could not convert to integer: {[column for column in problem_integer_columns]}')
    print(f'Page columns: {[column for column in page.columns]}')
    return page.drop(columns=['file', 'doc_page_number', 'flag'])#, 'cluster_confirmed_epidate', 'cluster_closed_epidate'])

# %% [markdown]
# ### `view_page` function

# %%
def view_page(df, part_num, page_num,
    filter_column1 = 'file', filter_column2 = 'doc_page_number'):
    date_columns = [
        'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active',
        'earliest_reported_cases', 'latest_reported_cases', 
        'closure_date',
    ]
    integer_columns = [
        'cases_when_cluster_confirmed', 
        'total_cases', 'days_since_last_case',
    ]
    filter = (df[filter_column1].str.contains(f'Part{part_num}')) & (df[filter_column2] == page_num)
    page_copy = df[filter].copy()
    problem_date_columns = []
    problem_integer_columns = []
    for column in date_columns:
        try:
            page_copy[column] = page_copy[column].apply(pd.to_datetime, format='%m/%d/%Y')
        except:
            problem_date_columns.append(column)
    for column in integer_columns:
        try:
            page_copy[column] = page_copy[column].apply(pd.to_numeric)
        except:
            problem_integer_columns.append(column)
    print(f'Could not convert to datetime: {[column for column in problem_date_columns]}')
    print(f'Could not convert to integer: {[column for column in problem_integer_columns]}')
    print(f'Page columns: {[column for column in page_copy.columns]}')
    return page_copy

# part_num = 2
# page_num = 4

# view_page(df, part_num, page_num)

# %% [markdown]
# ## `process_by_page` (and city mapping)

# %%
import re
import traceback
def convert_date_string_to_datetime_bycolumn(df):
    date_columns = [
        'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active',
        'earliest_reported_cases', 'latest_reported_cases', 
        'closure_date',
    ]
    for column in date_columns:
        try:
            df[column] = pd.to_datetime(df[column], format='%m/%d/%Y')
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            df[column] = datetime(1900, 1, 1, 0, 0)
            print(f'\tProblem with {df["file"]} page {df["doc_page_number"]} column {column} (row {df.name}: {error})')
    return df

def split_column(df, 
        column_to_split='latest_reported_cases', 
        column1='latest_reported_cases', column2='workplace_classification'):
    split_text = df[column_to_split].split(' ')
    if split_text[0] == split_text[-1]:
        df[column1] = None
        df[column2] = split_text[-1] 
    else:
        df[column1] = split_text[0]
        df[column2] = split_text[-1]

    print(f'Column "{column_to_split}" split to {df[column1]} and {df[column2]} for columns "{column1}" and "{column2}"')
    return df

def map_values(df, column, mapping):
    df[column] = df[column].str.upper().map(mapping, na_action=None)
    return df

def process_by_page(
        df, index, function, args=None, fixed_df_dict=fixed_df_dict,
        problem_pages_df=problem_pages, 
        part_num_column = 'file', page_num_column = 'doc_page_number',
        save=False,
        ):
    file = problem_pages_df.iloc[index][part_num_column]
    page_num = problem_pages_df.iloc[index][page_num_column]
    part_num = re.search(r'Part(\d+)', file).group(0)
    print(f'Problem pages implicit index {index}: {file} page {page_num}')
    # print(f'\tDataFrame columns: {df.columns}')
    filter = (df[part_num_column] == file) & (df[page_num_column] == page_num)
    page = df[filter].copy()
    print(f'Applying function {function} to {file} page {page_num}')
    print(f'\tFunction arguments: {args}')
    args = [args] if type(args) == str else args
    if function == map_values:
        column = args[0]
        if (args[1] == True) & (type(args[1]) != dict):
        # if (type(args[1]) != dict):
            if args[0] == 'city':
                mapping = {
                    'D': 'ABBOTSFORD',
                    'URNABY': 'BURNABY',
                    'BURNABY': 'BURNABY',
                    'CHILLIWACK': 'CHILLIWACK',
                    'COQUITLAM': 'COQUITLAM',
                    'EMEOS': 'CAWSTON/KEREMEOS',
                    'DELTA': 'DELTA',
                    'DUNCAN': 'DUNCAN',
                    'KELOWNA': 'KELOWNA',
                    'KAMLOOPS': 'KAMLOOPS',
                    'ANGLEY': 'LANGLEY',
                    'LANGLEY': 'LANGLEY',
                    'MAPLE RIDGE': 'MAPLE RIDGE',
                    'RIDGE': 'MAPLE RIDGE',
                    'NANAIMO': 'NANAIMO',
                    'RIDGE': 'MAPLE RIDGE',
                    'OLIVER': 'OLIVER',
                    'PARSONS': 'PARSONS',
                    'PORT COQUITLAM': 'PORT COQUITLAM',
                    'MOODY': 'PORT MOODY',
                    'VANCOUVER': 'VANCOUVER',
                    'URREY': 'SURREY',
                    'SURREY': 'SURREY',
                    'UNKNOWN': 'UNKNOWN',
                    'SAANICH': 'VICTORIA/SAANICH',
                    'VERNON': 'VERNON',
                }
            elif args[0] == 'workplace_classification':
                mapping = {
                    'Other': 'Other',
                    'Retail': 'Retail',
                    'nstruction': 'Maintainance/Trades/Construction',
                    'Office': 'Office',
                    'ture': 'Farm/Agriculture',
                    'Processing': 'Food Processing',
                    'on': 'Transportaton',
                    'Bar/Lounge': 'Restaurant/Bar/Lounge',
                    'Warehouse': 'Warehouse',
                    'Other': 'Other',
                    'ng/Industry': 'Manufacturing/Industry',
                }
            elif args[0] == 'workplace_status':
                mapping = {
                    'transmission': 'Not closed: insufficient evidence of recent transmission',
                    'Closed': 'Closed',
                    'open': 'Not closed: Public interest in remaining open',
                    'Open': 'Open',
                    'closed': 'Not closed',
                    'measures': 'Not closed: Alternate control measures',
                    'closed)': 'Managed without closure (not closed)',
                    'PH': 'Partially closed or widespread isolation by PH',
                    'order': 'Closed by order',
                    'closure': 'Voluntary closure',
                }
                print(f'mapping: {mapping}')
            print('Using default mapping...')
        else:
            mapping = args[1]
        page[column] = page[column].str.upper() if args[0] == 'city' else page[column]
        page[column] = page[column].map(mapping, na_action=None)
        processed_page = page
    elif function == 'replace':
        column = args[0]
        page[column] = page[column].replace(args[1], args[2])
        processed_page = page
    else:
        processed_page = page.apply(function, args=args, axis=1)
        if function == split_column:
            if args[0] == 'total_cases':
                map_column = 'workplace_status'
                mapping = {
                    'transmission': 'Not closed: insufficient evidence of recent transmission',
                    'Closed': 'Closed',
                    'open': 'Not closed: Public interest in remaining open',
                    'Open': 'Open',
                    'closed': 'Not closed',
                    'measures': 'Not closed: Alternate control measures',
                    'closed)': 'Managed without closure (not closed)',
                    'PH': 'Partially closed or widespread isolation by PH',
                    'order': 'Closed by order',
                    'non-closure)': 'Open (if open, reason for non-closure)',
                    'closure': 'Voluntary closure',
                    }
            elif args[0] == 'latest_reported_cases':
                map_column = 'workplace_classification'
                mapping = {
                    'Other': 'Other',
                    'Retail': 'Retail',
                    'nstruction': 'Maintainance/Trades/Construction',
                    'Office': 'Office',
                    'ture': 'Farm/Agriculture',
                    'Processing': 'Food Processing',
                    'on': 'Transportaton',
                    'Bar/Lounge': 'Restaurant/Bar/Lounge',
                    'Warehouse': 'Warehouse',
                    'Other': 'Other',
                    'ng/Industry': 'Manufacturing/Industry',
                    'Gym/Fitness': 'Gym/Fitness',
                    'Care': 'Personal Care',
                    'Responder': 'First Responder',
                    '(Acute/LTC)': 'Health Care Facility (Acute/LTC)',
                }
            if args[0]!= 'days_since_last_case':
                print(f'Map_column: {[value for value in processed_page[map_column]]}')
                processed_page[map_column] = processed_page[map_column].map(mapping, na_action=None)
                print(f'Values in {map_column} mapped to {mapping}')
    if save:
        fixed_df_dict[f'{part_num}_page{page_num}'] = processed_page
        print(f'Updated fixed_df_dict keys: {list(fixed_df_dict.keys())}')
        print(f'Date and time completed: {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}\n\n')
        return fixed_df_dict
    else:
        print('DataFrame columns: ',[f'{column}: {dtype}' for column, dtype in processed_page.dtypes.items()], '\n\n')
        return processed_page

# %% [markdown]
# ## `processing_chain`

# %%
def processing_chain(
    index, steps_dict_list, problem_rows_df=problem_rows, 
    fixed_df_dict=fixed_df_dict, problem_pages_df=problem_pages,
    save_to_dict=False
    ):
    df = problem_rows_df.copy()
    for iteration, steps_dict in enumerate(steps_dict_list):
        if iteration == len(steps_dict_list) - 1:
            save = save_to_dict 
        else: 
            save = False
        function = steps_dict[0]
        args = steps_dict[1]
        print(f'({iteration}) Function: {function}. Arguments: {args}. Save: {save}')
        if function == 'split_column':
            fixed_page = process_by_page(
                df, index, split_column, args=args, 
                save=save
                )
        elif function == 'map_values':
            fixed_page = process_by_page(
                df, index, map_values, args=args, 
                fixed_df_dict=fixed_df_dict, problem_pages_df=problem_pages_df,
                save=save
                )
        elif function == 'convert_date_string_to_datetime_bycolumn':
            fixed_page = process_by_page(
                df, index, convert_date_string_to_datetime_bycolumn, 
                fixed_df_dict=fixed_df_dict, problem_pages_df=problem_pages_df,
                args=args, save=save
                )
        elif function == 'replace':
            fixed_page = process_by_page(
                df, index, 'replace', 
                fixed_df_dict=fixed_df_dict, problem_pages_df=problem_pages_df,
                args=args, save=save
                )
        if iteration < len(steps_dict_list) - 1:
            df = fixed_page
    view_problem_page(index, problem_rows_df=df)
    print(f'fixed_df_dict keys: {[key for key in list(fixed_df_dict.keys())]}')
    return fixed_page

# index = 6
steps_dict_list = [
    ('split_column', ('latest_reported_cases', 'latest_reported_cases', 'workplace_classification')),
    ('split_column', ('total_cases', 'total_cases', 'workplace_status')),
    ('convert_date_string_to_datetime_bycolumn', None),
    ('split_column', ('days_since_last_case', 'days_since_last_case', 'active_clusters')),
    ('replace', ('city', 'COQUITLAM', 'PORT COQUITLAM')),
]

# %% [markdown]
# # Start fixing

# %% [markdown]
# ## Index 6

# %%
index = 6
view_problem_page(index) # PDF p. 53
# Out:
# Implicit index 6: F22-1445 Records_Part2.pdf page 50
# Could not convert to datetime: ['latest_reported_cases']
# Could not convert to integer: ['total_cases']
# Page columns: ['index', 'HA', 'workplace_name', 'workplace_address', 'city', 'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active', 'earliest_reported_cases', 'latest_reported_cases', 'workplace_classification', 'cases_when_cluster_confirmed', 'total_cases', 'workplace_status', 'closure_y_n', 'closed_by_order', 'voluntary_closure', 'closure_date', 'partially_closed', 'unknown_closure_type', 'open', 'days_since_last_case', 'active_clusters', 'cluster_confirmed_epidate', 'doc_page_number', 'cluster_closed_epidate', 'file', 'flag']
#      index   HA workplace_name workplace_address       city  \
# 801  430.0  FHA            NaN              None      DELTA
# 802  431.0  FHA            NaN              None    LANGLEY
# 803  432.0  FHA            NaN              None    BURNABY
# 804  433.0  VCH            NaN              None  Vancouver
# 805  434.0  VCH            NaN              None  Vancouver
# 806  435.0  FHA            NaN              None     SURREY
# 807  436.0  FHA            NaN              None      MOODY
# 808  437.0  FHA            NaN              None     SURREY
# 809  438.0  FHA            NaN              None      DELTA
# 810  439.0  FHA            NaN              None          D
# 811  440.0  FHA            NaN              None     SURREY
# 812  441.0  FHA            NaN              None      DELTA
#
#     date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 801                            5/12/2021                     5/22/2021
# 802                            5/12/2021                     5/25/2021
# 803                            5/12/2021                     5/28/2021
# 804                            5/12/2021                          None
# 805                            5/12/2021                          None
# 806                            5/13/2021                     5/29/2021
# 807                            5/13/2021                     5/28/2021
# 808                            5/13/2021                     5/28/2021
# 809                            5/13/2021                     5/27/2021
# 810                            5/13/2021                     6/23/2021
# 811                            5/13/2021                      6/9/2021
# 812                            5/14/2021                      6/5/2021
#
#     earliest_reported_cases latest_reported_cases workplace_classification  \
# 801                    None            Processing                     None
# 802                    None            Processing                     None
# 803                    None           ng/Industry                     None
# 804               5/12/2021      6/4/2021 Housing                     None
# 805               5/12/2021        6/4/2021 Other                     None
# 806                    None           Gym/Fitness                     None
# 807                    None            nstruction                     None
# 808                    None                    on                     None
# 809                    None                Office                     None
# 810                    None                  ture                     None
# 811                    None                Retail                     None
# 812                    None             Warehouse                     None
#
#     cases_when_cluster_confirmed     total_cases workplace_status closure_y_n  \
# 801                            9      9 measures             None          No
# 802                            3  3 transmission             None          No
# 803                            5  5 transmission             None          No
# 804                         None  7 (not closed)             None          No
# 805                         None       4 closed)             None          No
# 806                            9      9 measures             None          No
# 807                            4        4 Closed             None         Yes
# 808                            3          3 open             None          No
# 809                            3        3 Closed             None         Yes
# 810                           31     31 measures             None          No
# 811                            6          6 open             None          No
# 812                            3      3 measures             None          No
#
#     closed_by_order voluntary_closure closure_date partially_closed  \
# 801              No           Unknown         None               No
# 802              No           Unknown         None               No
# 803              No           Unknown         None               No
# 804              No                No         None               No
# 805              No                No         None               No
# 806              No           Unknown         None               No
# 807              No           Unknown    5/15/2021              Yes
# 808              No           Unknown         None               No
# 809             Yes           Unknown    5/14/2021               No
# 810              No           Unknown         None               No
# 811              No           Unknown         None               No
# 812              No           Unknown         None               No
#
#     unknown_closure_type open days_since_last_case active_clusters  \
# 801                  NaN  Yes                 None              No
# 802                  NaN  Yes                 None              No
# 803                  NaN  Yes                 None              No
# 804                  NaN  Yes                 None              No
# 805                  NaN  Yes                 None              No
# 806                  NaN  Yes                 None              No
# 807                  NaN   No                 None              No
# 808                  NaN  Yes                 None              No
# 809                  NaN   No                 None              No
# 810                  NaN  Yes                 None              No
# 811                  NaN  Yes                 None              No
# 812                  NaN  Yes                 None              No
#
#     cluster_confirmed_epidate cluster_closed_epidate
# 801                   19-2021                   None
# 802                   19-2021                   None
# 803                   19-2021                   None
# 804                   19-2021                   None
# 805                   19-2021                   None
# 806                   19-2021                   None
# 807                   19-2021                19-2021
# 808                   19-2021                   None
# 809                   19-2021                19-2021
# 810                   19-2021                   None
# 811                   19-2021                   None
# 812                   19-2021                   None

# %%
steps_dict_list = [
    ('split_column', ('latest_reported_cases', 'latest_reported_cases', 'workplace_classification')),
    ('split_column', ('total_cases', 'total_cases', 'workplace_status')),
    ('convert_date_string_to_datetime_bycolumn', None),
    ('map_values', ('city', 1))
    # ('split_column', ('days_since_last_case', 'days_since_last_case', 'active_clusters')),
    # ('replace', ('city', 'COQUITLAM', 'PORT COQUITLAM')),
]

# save = False
save = True
fixed_page = processing_chain(index, steps_dict_list, save_to_dict=save)
# Out:
# (0) Function: split_column. Arguments: ('latest_reported_cases', 'latest_reported_cases', 'workplace_classification'). Save: False
# Problem pages implicit index 6: F22-1445 Records_Part2.pdf page 50
# Applying function <function split_column at 0x000002803A7E0550> to F22-1445 Records_Part2.pdf page 50
# 	Function arguments: ('latest_reported_cases', 'latest_reported_cases', 'workplace_classification')
# Column "latest_reported_cases" split to None and Processing for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Processing for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and ng/Industry for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 6/4/2021 and Housing for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 6/4/2021 and Other for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Gym/Fitness for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and nstruction for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and on for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Office for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and ture for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Retail for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Warehouse for columns "latest_reported_cases" and "workplace_classification"
# Map_column: ['Processing', 'Processing', 'ng/Industry', 'Housing', 'Other', 'Gym/Fitness', 'nstruction', 'on', 'Office', 'ture', 'Retail', 'Warehouse']
# Values in workplace_classification mapped to {'Other': 'Other', 'Retail': 'Retail', 'nstruction': 'Maintainance/Trades/Construction', 'Office': 'Office', 'ture': 'Farm/Agriculture', 'Processing': 'Food Processing', 'on': 'Transportaton', 'Bar/Lounge': 'Restaurant/Bar/Lounge', 'Warehouse': 'Warehouse', 'ng/Industry': 'Manufacturing/Industry', 'Gym/Fitness': 'Gym/Fitness', 'Care': 'Personal Care', 'Responder': 'First Responder', '(Acute/LTC)': 'Health Care Facility (Acute/LTC)'}
# DataFrame columns:  ['index: float64', 'HA: object', 'workplace_name: float64', 'workplace_address: object', 'city: object', 'date_cluster_confirmed_public_health: object', 'date_cluster_no_longer_active: object', 'earliest_reported_cases: object', 'latest_reported_cases: object', 'workplace_classification: object', 'cases_when_cluster_confirmed: object', 'total_cases: object', 'workplace_status: object', 'closure_y_n: object', 'closed_by_order: object', 'voluntary_closure: object', 'closure_date: object', 'partially_closed: object', 'unknown_closure_type: float64', 'open: object', 'days_since_last_case: object', 'active_clusters: object', 'cluster_confirmed_epidate: object', 'doc_page_number: int64', 'cluster_closed_epidate: object', 'file: object', 'flag: int64']
#
#
# (1) Function: split_column. Arguments: ('total_cases', 'total_cases', 'workplace_status'). Save: False
# Problem pages implicit index 6: F22-1445 Records_Part2.pdf page 50
# Applying function <function split_column at 0x000002803A7E0550> to F22-1445 Records_Part2.pdf page 50
# 	Function arguments: ('total_cases', 'total_cases', 'workplace_status')
# Column "total_cases" split to 9 and measures for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and transmission for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 5 and transmission for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 7 and closed) for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 4 and closed) for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 9 and measures for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 4 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and open for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 31 and measures for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 6 and open for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and measures for columns "total_cases" and "workplace_status"
# Map_column: ['measures', 'transmission', 'transmission', 'closed)', 'closed)', 'measures', 'Closed', 'open', 'Closed', 'measures', 'open', 'measures']
# Values in workplace_status mapped to {'transmission': 'Not closed: insufficient evidence of recent transmission', 'Closed': 'Closed', 'open': 'Not closed: Public interest in remaining open', 'closed': 'Not closed', 'measures': 'Not closed: Alternate control measures', 'closed)': 'Managed without closure (not closed)', 'PH': 'Partially closed or widespread isolation by PH', 'order': 'Closed by order', 'non-closure)': 'Open (if open, reason for non-closure)'}
# DataFrame columns:  ['index: float64', 'HA: object', 'workplace_name: float64', 'workplace_address: object', 'city: object', 'date_cluster_confirmed_public_health: object', 'date_cluster_no_longer_active: object', 'earliest_reported_cases: object', 'latest_reported_cases: object', 'workplace_classification: object', 'cases_when_cluster_confirmed: object', 'total_cases: object', 'workplace_status: object', 'closure_y_n: object', 'closed_by_order: object', 'voluntary_closure: object', 'closure_date: object', 'partially_closed: object', 'unknown_closure_type: float64', 'open: object', 'days_since_last_case: object', 'active_clusters: object', 'cluster_confirmed_epidate: object', 'doc_page_number: int64', 'cluster_closed_epidate: object', 'file: object', 'flag: int64']
#
#
# (2) Function: convert_date_string_to_datetime_bycolumn. Arguments: None. Save: False
# Problem pages implicit index 6: F22-1445 Records_Part2.pdf page 50
# Applying function <function convert_date_string_to_datetime_bycolumn at 0x000002803D04FCA0> to F22-1445 Records_Part2.pdf page 50
# 	Function arguments: None
# DataFrame columns:  ['index: float64', 'HA: object', 'workplace_name: float64', 'workplace_address: object', 'city: object', 'date_cluster_confirmed_public_health: datetime64[ns]', 'date_cluster_no_longer_active: datetime64[ns]', 'earliest_reported_cases: datetime64[ns]', 'latest_reported_cases: datetime64[ns]', 'workplace_classification: object', 'cases_when_cluster_confirmed: object', 'total_cases: object', 'workplace_status: object', 'closure_y_n: object', 'closed_by_order: object', 'voluntary_closure: object', 'closure_date: datetime64[ns]', 'partially_closed: object', 'unknown_closure_type: float64', 'open: object', 'days_since_last_case: object', 'active_clusters: object', 'cluster_confirmed_epidate: object', 'doc_page_number: int64', 'cluster_closed_epidate: object', 'file: object', 'flag: int64']
#
#
# (3) Function: map_values. Arguments: ('city', 1). Save: True
# Problem pages implicit index 6: F22-1445 Records_Part2.pdf page 50
# Applying function <function map_values at 0x000002803B241D30> to F22-1445 Records_Part2.pdf page 50
# 	Function arguments: ('city', 1)
# Using default mapping...
# Updated fixed_df_dict keys: ['Part2_page10', 'Part2_page19', 'Part2_page42', 'Part2_page44', 'Part2_page45', 'Part2_page48', 'Part2_page50']
# Date and time completed: 2023-04-25 19:09:41
#
#
# Implicit index 6: F22-1445 Records_Part2.pdf page 50
# Could not convert to datetime: []
# Could not convert to integer: []
# Page columns: ['index', 'HA', 'workplace_name', 'workplace_address', 'city', 'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active', 'earliest_reported_cases', 'latest_reported_cases', 'workplace_classification', 'cases_when_cluster_confirmed', 'total_cases', 'workplace_status', 'closure_y_n', 'closed_by_order', 'voluntary_closure', 'closure_date', 'partially_closed', 'unknown_closure_type', 'open', 'days_since_last_case', 'active_clusters', 'cluster_confirmed_epidate', 'doc_page_number', 'cluster_closed_epidate', 'file', 'flag']

# %%
fixed_df_dict['Part2_page50']
# Out:
#      index   HA  workplace_name workplace_address        city  \
# 801  430.0  FHA             NaN              None       DELTA
# 802  431.0  FHA             NaN              None     LANGLEY
# 803  432.0  FHA             NaN              None     BURNABY
# 804  433.0  VCH             NaN              None   VANCOUVER
# 805  434.0  VCH             NaN              None   VANCOUVER
# 806  435.0  FHA             NaN              None      SURREY
# 807  436.0  FHA             NaN              None  PORT MOODY
# 808  437.0  FHA             NaN              None      SURREY
# 809  438.0  FHA             NaN              None       DELTA
# 810  439.0  FHA             NaN              None  ABBOTSFORD
# 811  440.0  FHA             NaN              None      SURREY
# 812  441.0  FHA             NaN              None       DELTA
#
#     date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 801                           2021-05-12                    2021-05-22
# 802                           2021-05-12                    2021-05-25
# 803                           2021-05-12                    2021-05-28
# 804                           2021-05-12                           NaT
# 805                           2021-05-12                           NaT
# 806                           2021-05-13                    2021-05-29
# 807                           2021-05-13                    2021-05-28
# 808                           2021-05-13                    2021-05-28
# 809                           2021-05-13                    2021-05-27
# 810                           2021-05-13                    2021-06-23
# 811                           2021-05-13                    2021-06-09
# 812                           2021-05-14                    2021-06-05
#
#     earliest_reported_cases latest_reported_cases  \
# 801                     NaT                   NaT
# 802                     NaT                   NaT
# 803                     NaT                   NaT
# 804              2021-05-12            2021-06-04
# 805              2021-05-12            2021-06-04
# 806                     NaT                   NaT
# 807                     NaT                   NaT
# 808                     NaT                   NaT
# 809                     NaT                   NaT
# 810                     NaT                   NaT
# 811                     NaT                   NaT
# 812                     NaT                   NaT
#
#              workplace_classification cases_when_cluster_confirmed  \
# 801                   Food Processing                            9
# 802                   Food Processing                            3
# 803            Manufacturing/Industry                            5
# 804                               NaN                         None
# 805                             Other                         None
# 806                       Gym/Fitness                            9
# 807  Maintainance/Trades/Construction                            4
# 808                     Transportaton                            3
# 809                            Office                            3
# 810                  Farm/Agriculture                           31
# 811                            Retail                            6
# 812                         Warehouse                            3
#
#     total_cases                                          workplace_status  \
# 801           9                    Not closed: Alternate control measures
# 802           3  Not closed: insufficient evidence of recent transmission
# 803           5  Not closed: insufficient evidence of recent transmission
# 804           7                      Managed without closure (not closed)
# 805           4                      Managed without closure (not closed)
# 806           9                    Not closed: Alternate control measures
# 807           4                                                    Closed
# 808           3             Not closed: Public interest in remaining open
# 809           3                                                    Closed
# 810          31                    Not closed: Alternate control measures
# 811           6             Not closed: Public interest in remaining open
# 812           3                    Not closed: Alternate control measures
#
#     closure_y_n closed_by_order voluntary_closure closure_date  \
# 801          No              No           Unknown          NaT
# 802          No              No           Unknown          NaT
# 803          No              No           Unknown          NaT
# 804          No              No                No          NaT
# 805          No              No                No          NaT
# 806          No              No           Unknown          NaT
# 807         Yes              No           Unknown   2021-05-15
# 808          No              No           Unknown          NaT
# 809         Yes             Yes           Unknown   2021-05-14
# 810          No              No           Unknown          NaT
# 811          No              No           Unknown          NaT
# 812          No              No           Unknown          NaT
#
#     partially_closed  unknown_closure_type open days_since_last_case  \
# 801               No                   NaN  Yes                 None
# 802               No                   NaN  Yes                 None
# 803               No                   NaN  Yes                 None
# 804               No                   NaN  Yes                 None
# 805               No                   NaN  Yes                 None
# 806               No                   NaN  Yes                 None
# 807              Yes                   NaN   No                 None
# 808               No                   NaN  Yes                 None
# 809               No                   NaN   No                 None
# 810               No                   NaN  Yes                 None
# 811               No                   NaN  Yes                 None
# 812               No                   NaN  Yes                 None
#
#     active_clusters cluster_confirmed_epidate  doc_page_number  \
# 801              No                   19-2021               50
# 802              No                   19-2021               50
# 803              No                   19-2021               50
# 804              No                   19-2021               50
# 805              No                   19-2021               50
# 806              No                   19-2021               50
# 807              No                   19-2021               50
# 808              No                   19-2021               50
# 809              No                   19-2021               50
# 810              No                   19-2021               50
# 811              No                   19-2021               50
# 812              No                   19-2021               50
#
#     cluster_closed_epidate                        file  flag
# 801                   None  F22-1445 Records_Part2.pdf     1
# 802                   None  F22-1445 Records_Part2.pdf     1
# 803                   None  F22-1445 Records_Part2.pdf     1
# 804                   None  F22-1445 Records_Part2.pdf     1
# 805                   None  F22-1445 Records_Part2.pdf     1
# 806                   None  F22-1445 Records_Part2.pdf     1
# 807                19-2021  F22-1445 Records_Part2.pdf     1
# 808                   None  F22-1445 Records_Part2.pdf     1
# 809                19-2021  F22-1445 Records_Part2.pdf     1
# 810                   None  F22-1445 Records_Part2.pdf     1
# 811                   None  F22-1445 Records_Part2.pdf     1
# 812                   None  F22-1445 Records_Part2.pdf     1

# %% [markdown]
# ## Index 7

# %%
view_problem_page(7) # Pdf p. 54
# Out:
# Implicit index 7: F22-1445 Records_Part2.pdf page 51
# Could not convert to datetime: ['latest_reported_cases']
# Could not convert to integer: ['total_cases']
# Page columns: ['index', 'HA', 'workplace_name', 'workplace_address', 'city', 'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active', 'earliest_reported_cases', 'latest_reported_cases', 'workplace_classification', 'cases_when_cluster_confirmed', 'total_cases', 'workplace_status', 'closure_y_n', 'closed_by_order', 'voluntary_closure', 'closure_date', 'partially_closed', 'unknown_closure_type', 'open', 'days_since_last_case', 'active_clusters', 'cluster_confirmed_epidate', 'doc_page_number', 'cluster_closed_epidate', 'file', 'flag']
#      index    HA workplace_name workplace_address     city  \
# 813  442.0   FHA            NaN              None    DELTA
# 814  443.0   FHA            NaN              None  BURNABY
# 815  444.0   NHA            NaN              None  Unknown
# 816  445.0   FHA            NaN              None   ANGLEY
# 817  446.0   FHA            NaN              None   SURREY
# 818  447.0   FHA            NaN              None        D
# 819  448.0   FHA            NaN              None   SURREY
# 820  449.0  VIHA            NaN              None   Duncan
# 821  450.0   FHA            NaN              None  BURNABY
# 822  451.0   FHA            NaN              None  BURNABY
# 823  452.0   FHA            NaN              None        D
# 824  453.0   FHA            NaN              None   SURREY
# 825  454.0   FHA            NaN              None   SURREY
#
#     date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 813                            5/14/2021                     6/11/2021
# 814                            5/14/2021                     5/26/2021
# 815                            5/14/2021                     5/31/2021
# 816                            5/15/2021                      6/7/2021
# 817                            5/15/2021                      6/4/2021
# 818                            5/15/2021                      6/3/2021
# 819                            5/15/2021                     5/27/2021
# 820                            5/15/2021                          None
# 821                            5/16/2021                      6/2/2021
# 822                            5/17/2021                     5/27/2021
# 823                            5/17/2021                     5/29/2021
# 824                            5/17/2021                      6/3/2021
# 825                            5/17/2021                      6/7/2021
#
#     earliest_reported_cases latest_reported_cases workplace_classification  \
# 813                    None                    on                     None
# 814                    None                Office                     None
# 815                    None           ng/Industry                     None
# 816                    None           Gym/Fitness                     None
# 817                    None           Gym/Fitness                     None
# 818                    None           Gym/Fitness                     None
# 819                    None           Gym/Fitness                     None
# 820               5/14/2021       5/18/2021 Other                     None
# 821                    None            nstruction                     None
# 822                    None            nstruction                     None
# 823                    None           ng/Industry                     None
# 824                    None                    on                     None
# 825                    None            nstruction                     None
#
#     cases_when_cluster_confirmed     total_cases workplace_status closure_y_n  \
# 813                            7  7 transmission             None          No
# 814                            4        4 Closed             None         Yes
# 815                            3  3 non-closure)             None          No
# 816                            4        4 Closed             None         Yes
# 817                            5        5 Closed             None         Yes
# 818                           14       14 Closed             None         Yes
# 819                            3  3 transmission             None          No
# 820                            0          5 Open             None          No
# 821                            8          8 open             None          No
# 822                            6      6 measures             None          No
# 823                            4        4 Closed             None         Yes
# 824                            4  4 transmission             None          No
# 825                            5      5 measures             None          No
#
#     closed_by_order voluntary_closure closure_date partially_closed  \
# 813              No           Unknown         None               No
# 814             Yes           Unknown    5/14/2021               No
# 815              No                No         None          Unknown
# 816             Yes           Unknown    5/25/2021               No
# 817             Yes           Unknown    5/16/2021               No
# 818             Yes           Unknown    5/17/2021               No
# 819              No           Unknown         None               No
# 820              No                No         None          Unknown
# 821              No           Unknown         None               No
# 822              No           Unknown         None               No
# 823             Yes           Unknown    5/17/2021               No
# 824              No           Unknown         None               No
# 825              No           Unknown         None               No
#
#     unknown_closure_type open days_since_last_case active_clusters  \
# 813                  NaN  Yes                 None              No
# 814                  NaN   No                 None              No
# 815                  NaN   No                 None              No
# 816                  NaN   No                 None              No
# 817                  NaN   No                 None              No
# 818                  NaN   No                 None              No
# 819                  NaN  Yes                 None              No
# 820                  NaN  Yes                   49              No
# 821                  NaN  Yes                 None              No
# 822                  NaN  Yes                 None              No
# 823                  NaN   No                 None              No
# 824                  NaN  Yes                 None              No
# 825                  NaN  Yes                 None              No
#
#     cluster_confirmed_epidate cluster_closed_epidate
# 813                   19-2021                   None
# 814                   19-2021                19-2021
# 815                   19-2021                   None
# 816                   19-2021                21-2021
# 817                   19-2021                20-2021
# 818                   19-2021                20-2021
# 819                   19-2021                   None
# 820                   19-2021                   None
# 821                   20-2021                   None
# 822                   20-2021                   None
# 823                   20-2021                20-2021
# 824                   20-2021                   None
# 825                   20-2021                   None

# %%
steps_dict_list = [
    ('split_column', ('latest_reported_cases', 'latest_reported_cases', 'workplace_classification')),
    ('split_column', ('total_cases', 'total_cases', 'workplace_status')),
    ('convert_date_string_to_datetime_bycolumn', None),
    ('map_values', ('city', 1))
    # ('split_column', ('days_since_last_case', 'days_since_last_case', 'active_clusters')),
    # ('replace', ('city', 'COQUITLAM', 'PORT COQUITLAM')),
]

index = 7
# save = False
save = True
fixed_page = processing_chain(index, steps_dict_list, save_to_dict=save)
# Out:
# (0) Function: split_column. Arguments: ('latest_reported_cases', 'latest_reported_cases', 'workplace_classification'). Save: False
# Problem pages implicit index 7: F22-1445 Records_Part2.pdf page 51
# Applying function <function split_column at 0x000002803C5A2820> to F22-1445 Records_Part2.pdf page 51
# 	Function arguments: ('latest_reported_cases', 'latest_reported_cases', 'workplace_classification')
# Column "latest_reported_cases" split to None and on for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Office for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and ng/Industry for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Gym/Fitness for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Gym/Fitness for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Gym/Fitness for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Gym/Fitness for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 5/18/2021 and Other for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and nstruction for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and nstruction for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and ng/Industry for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and on for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and nstruction for columns "latest_reported_cases" and "workplace_classification"
# Map_column: ['on', 'Office', 'ng/Industry', 'Gym/Fitness', 'Gym/Fitness', 'Gym/Fitness', 'Gym/Fitness', 'Other', 'nstruction', 'nstruction', 'ng/Industry', 'on', 'nstruction']
# Values in workplace_classification mapped to {'Other': 'Other', 'Retail': 'Retail', 'nstruction': 'Maintainance/Trades/Construction', 'Office': 'Office', 'ture': 'Farm/Agriculture', 'Processing': 'Food Processing', 'on': 'Transportaton', 'Bar/Lounge': 'Restaurant/Bar/Lounge', 'Warehouse': 'Warehouse', 'ng/Industry': 'Manufacturing/Industry', 'Gym/Fitness': 'Gym/Fitness', 'Care': 'Personal Care', 'Responder': 'First Responder', '(Acute/LTC)': 'Health Care Facility (Acute/LTC)'}
# DataFrame columns:  ['index: float64', 'HA: object', 'workplace_name: float64', 'workplace_address: object', 'city: object', 'date_cluster_confirmed_public_health: object', 'date_cluster_no_longer_active: object', 'earliest_reported_cases: object', 'latest_reported_cases: object', 'workplace_classification: object', 'cases_when_cluster_confirmed: object', 'total_cases: object', 'workplace_status: object', 'closure_y_n: object', 'closed_by_order: object', 'voluntary_closure: object', 'closure_date: object', 'partially_closed: object', 'unknown_closure_type: float64', 'open: object', 'days_since_last_case: object', 'active_clusters: object', 'cluster_confirmed_epidate: object', 'doc_page_number: int64', 'cluster_closed_epidate: object', 'file: object', 'flag: int64']
#
#
# (1) Function: split_column. Arguments: ('total_cases', 'total_cases', 'workplace_status'). Save: False
# Problem pages implicit index 7: F22-1445 Records_Part2.pdf page 51
# Applying function <function split_column at 0x000002803C5A2820> to F22-1445 Records_Part2.pdf page 51
# 	Function arguments: ('total_cases', 'total_cases', 'workplace_status')
# Column "total_cases" split to 7 and transmission for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 4 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and non-closure) for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 4 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 5 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 14 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and transmission for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 5 and Open for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 8 and open for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 6 and measures for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 4 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 4 and transmission for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 5 and measures for columns "total_cases" and "workplace_status"
# Map_column: ['transmission', 'Closed', 'non-closure)', 'Closed', 'Closed', 'Closed', 'transmission', 'Open', 'open', 'measures', 'Closed', 'transmission', 'measures']
# Values in workplace_status mapped to {'transmission': 'Not closed: insufficient evidence of recent transmission', 'Closed': 'Closed', 'open': 'Not closed: Public interest in remaining open', 'Open': 'Open', 'closed': 'Not closed', 'measures': 'Not closed: Alternate control measures', 'closed)': 'Managed without closure (not closed)', 'PH': 'Partially closed or widespread isolation by PH', 'order': 'Closed by order', 'non-closure)': 'Open (if open, reason for non-closure)'}
# DataFrame columns:  ['index: float64', 'HA: object', 'workplace_name: float64', 'workplace_address: object', 'city: object', 'date_cluster_confirmed_public_health: object', 'date_cluster_no_longer_active: object', 'earliest_reported_cases: object', 'latest_reported_cases: object', 'workplace_classification: object', 'cases_when_cluster_confirmed: object', 'total_cases: object', 'workplace_status: object', 'closure_y_n: object', 'closed_by_order: object', 'voluntary_closure: object', 'closure_date: object', 'partially_closed: object', 'unknown_closure_type: float64', 'open: object', 'days_since_last_case: object', 'active_clusters: object', 'cluster_confirmed_epidate: object', 'doc_page_number: int64', 'cluster_closed_epidate: object', 'file: object', 'flag: int64']
#
#
# (2) Function: convert_date_string_to_datetime_bycolumn. Arguments: None. Save: False
# Problem pages implicit index 7: F22-1445 Records_Part2.pdf page 51
# Applying function <function convert_date_string_to_datetime_bycolumn at 0x000002803C5A2CA0> to F22-1445 Records_Part2.pdf page 51
# 	Function arguments: None
# DataFrame columns:  ['index: float64', 'HA: object', 'workplace_name: float64', 'workplace_address: object', 'city: object', 'date_cluster_confirmed_public_health: datetime64[ns]', 'date_cluster_no_longer_active: datetime64[ns]', 'earliest_reported_cases: datetime64[ns]', 'latest_reported_cases: datetime64[ns]', 'workplace_classification: object', 'cases_when_cluster_confirmed: object', 'total_cases: object', 'workplace_status: object', 'closure_y_n: object', 'closed_by_order: object', 'voluntary_closure: object', 'closure_date: datetime64[ns]', 'partially_closed: object', 'unknown_closure_type: float64', 'open: object', 'days_since_last_case: object', 'active_clusters: object', 'cluster_confirmed_epidate: object', 'doc_page_number: int64', 'cluster_closed_epidate: object', 'file: object', 'flag: int64']
#
#
# (3) Function: map_values. Arguments: ('city', 1). Save: True
# Problem pages implicit index 7: F22-1445 Records_Part2.pdf page 51
# Applying function <function map_values at 0x000002803C5A2280> to F22-1445 Records_Part2.pdf page 51
# 	Function arguments: ('city', 1)
# Using default mapping...
# Updated fixed_df_dict keys: ['Part2_page10', 'Part2_page19', 'Part2_page42', 'Part2_page44', 'Part2_page45', 'Part2_page48', 'Part2_page50', 'Part2_page51']
# Date and time completed: 2023-04-25 19:20:49
#
#
# Implicit index 7: F22-1445 Records_Part2.pdf page 51
# Could not convert to datetime: []
# Could not convert to integer: []
# Page columns: ['index', 'HA', 'workplace_name', 'workplace_address', 'city', 'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active', 'earliest_reported_cases', 'latest_reported_cases', 'workplace_classification', 'cases_when_cluster_confirmed', 'total_cases', 'workplace_status', 'closure_y_n', 'closed_by_order', 'voluntary_closure', 'closure_date', 'partially_closed', 'unknown_closure_type', 'open', 'days_since_last_case', 'active_clusters', 'cluster_confirmed_epidate', 'doc_page_number', 'cluster_closed_epidate', 'file', 'flag']

# %%
fixed_page
# Out:
#      index    HA  workplace_name workplace_address        city  \
# 813  442.0   FHA             NaN              None       DELTA
# 814  443.0   FHA             NaN              None     BURNABY
# 815  444.0   NHA             NaN              None     UNKNOWN
# 816  445.0   FHA             NaN              None     LANGLEY
# 817  446.0   FHA             NaN              None      SURREY
# 818  447.0   FHA             NaN              None  ABBOTSFORD
# 819  448.0   FHA             NaN              None      SURREY
# 820  449.0  VIHA             NaN              None      DUNCAN
# 821  450.0   FHA             NaN              None     BURNABY
# 822  451.0   FHA             NaN              None     BURNABY
# 823  452.0   FHA             NaN              None  ABBOTSFORD
# 824  453.0   FHA             NaN              None      SURREY
# 825  454.0   FHA             NaN              None      SURREY
#
#     date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 813                           2021-05-14                    2021-06-11
# 814                           2021-05-14                    2021-05-26
# 815                           2021-05-14                    2021-05-31
# 816                           2021-05-15                    2021-06-07
# 817                           2021-05-15                    2021-06-04
# 818                           2021-05-15                    2021-06-03
# 819                           2021-05-15                    2021-05-27
# 820                           2021-05-15                           NaT
# 821                           2021-05-16                    2021-06-02
# 822                           2021-05-17                    2021-05-27
# 823                           2021-05-17                    2021-05-29
# 824                           2021-05-17                    2021-06-03
# 825                           2021-05-17                    2021-06-07
#
#     earliest_reported_cases latest_reported_cases  \
# 813                     NaT                   NaT
# 814                     NaT                   NaT
# 815                     NaT                   NaT
# 816                     NaT                   NaT
# 817                     NaT                   NaT
# 818                     NaT                   NaT
# 819                     NaT                   NaT
# 820              2021-05-14            2021-05-18
# 821                     NaT                   NaT
# 822                     NaT                   NaT
# 823                     NaT                   NaT
# 824                     NaT                   NaT
# 825                     NaT                   NaT
#
#              workplace_classification cases_when_cluster_confirmed  \
# 813                     Transportaton                            7
# 814                            Office                            4
# 815            Manufacturing/Industry                            3
# 816                       Gym/Fitness                            4
# 817                       Gym/Fitness                            5
# 818                       Gym/Fitness                           14
# 819                       Gym/Fitness                            3
# 820                             Other                            0
# 821  Maintainance/Trades/Construction                            8
# 822  Maintainance/Trades/Construction                            6
# 823            Manufacturing/Industry                            4
# 824                     Transportaton                            4
# 825  Maintainance/Trades/Construction                            5
#
#     total_cases                                          workplace_status  \
# 813           7  Not closed: insufficient evidence of recent transmission
# 814           4                                                    Closed
# 815           3                    Open (if open, reason for non-closure)
# 816           4                                                    Closed
# 817           5                                                    Closed
# 818          14                                                    Closed
# 819           3  Not closed: insufficient evidence of recent transmission
# 820           5                                                      Open
# 821           8             Not closed: Public interest in remaining open
# 822           6                    Not closed: Alternate control measures
# 823           4                                                    Closed
# 824           4  Not closed: insufficient evidence of recent transmission
# 825           5                    Not closed: Alternate control measures
#
#     closure_y_n closed_by_order voluntary_closure closure_date  \
# 813          No              No           Unknown          NaT
# 814         Yes             Yes           Unknown   2021-05-14
# 815          No              No                No          NaT
# 816         Yes             Yes           Unknown   2021-05-25
# 817         Yes             Yes           Unknown   2021-05-16
# 818         Yes             Yes           Unknown   2021-05-17
# 819          No              No           Unknown          NaT
# 820          No              No                No          NaT
# 821          No              No           Unknown          NaT
# 822          No              No           Unknown          NaT
# 823         Yes             Yes           Unknown   2021-05-17
# 824          No              No           Unknown          NaT
# 825          No              No           Unknown          NaT
#
#     partially_closed  unknown_closure_type open days_since_last_case  \
# 813               No                   NaN  Yes                 None
# 814               No                   NaN   No                 None
# 815          Unknown                   NaN   No                 None
# 816               No                   NaN   No                 None
# 817               No                   NaN   No                 None
# 818               No                   NaN   No                 None
# 819               No                   NaN  Yes                 None
# 820          Unknown                   NaN  Yes                   49
# 821               No                   NaN  Yes                 None
# 822               No                   NaN  Yes                 None
# 823               No                   NaN   No                 None
# 824               No                   NaN  Yes                 None
# 825               No                   NaN  Yes                 None
#
#     active_clusters cluster_confirmed_epidate  doc_page_number  \
# 813              No                   19-2021               51
# 814              No                   19-2021               51
# 815              No                   19-2021               51
# 816              No                   19-2021               51
# 817              No                   19-2021               51
# 818              No                   19-2021               51
# 819              No                   19-2021               51
# 820              No                   19-2021               51
# 821              No                   20-2021               51
# 822              No                   20-2021               51
# 823              No                   20-2021               51
# 824              No                   20-2021               51
# 825              No                   20-2021               51
#
#     cluster_closed_epidate                        file  flag
# 813                   None  F22-1445 Records_Part2.pdf     1
# 814                19-2021  F22-1445 Records_Part2.pdf     1
# 815                   None  F22-1445 Records_Part2.pdf     1
# 816                21-2021  F22-1445 Records_Part2.pdf     1
# 817                20-2021  F22-1445 Records_Part2.pdf     1
# 818                20-2021  F22-1445 Records_Part2.pdf     1
# 819                   None  F22-1445 Records_Part2.pdf     1
# 820                   None  F22-1445 Records_Part2.pdf     1
# 821                   None  F22-1445 Records_Part2.pdf     1
# 822                   None  F22-1445 Records_Part2.pdf     1
# 823                20-2021  F22-1445 Records_Part2.pdf     1
# 824                   None  F22-1445 Records_Part2.pdf     1
# 825                   None  F22-1445 Records_Part2.pdf     1

# %% [markdown]
# ## Index 8

# %%
index = 8
view_problem_page(index) #pdf p. 57
# Out:
# Implicit index 8: F22-1445 Records_Part2.pdf page 54
# Could not convert to datetime: ['latest_reported_cases', 'closure_date']
# Could not convert to integer: ['total_cases']
# Page columns: ['index', 'HA', 'workplace_name', 'workplace_address', 'city', 'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active', 'earliest_reported_cases', 'latest_reported_cases', 'workplace_classification', 'cases_when_cluster_confirmed', 'total_cases', 'workplace_status', 'closure_y_n', 'closed_by_order', 'voluntary_closure', 'closure_date', 'partially_closed', 'unknown_closure_type', 'open', 'days_since_last_case', 'active_clusters', 'cluster_confirmed_epidate', 'doc_page_number', 'cluster_closed_epidate', 'file', 'flag']
#      index    HA workplace_name workplace_address        city  \
# 854  483.0   FHA            NaN              None           D
# 855  484.0  VIHA            NaN              None     Saanich
# 856  485.0   IHA            NaN              None     Kelowna
# 857  486.0   IHA            NaN              None     Kelowna
# 858  487.0   FHA            NaN              None   COQUITLAM
# 859  488.0   FHA            NaN              None     BURNABY
# 860  489.0   FHA            NaN              None       DELTA
# 861  490.0   FHA            NaN              None     BURNABY
# 862  491.0   FHA            NaN              None     LANGLEY
# 863  492.0   IHA            NaN              None      Vernon
# 864  493.0   IHA            NaN              None     Kelowna
# 865  494.0   IHA            NaN              None      Oliver
# 866  495.0   FHA            NaN              None  CHILLIWACK
# 867  496.0   FHA            NaN              None      SURREY
# 868  497.0   NHA            NaN              None     Unknown
# 869  498.0   IHA            NaN              None     Kelowna
#
#     date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 854                            5/21/2021                      6/5/2021
# 855                            5/21/2021                          None
# 856                            5/23/2021                          None
# 857                            5/23/2021                          None
# 858                            5/24/2021                      6/9/2021
# 859                            5/24/2021                     5/28/2021
# 860                            5/24/2021                      6/5/2021
# 861                            5/24/2021                     5/24/2021
# 862                            5/24/2021                      6/7/2021
# 863                            5/25/2021                          None
# 864                            5/25/2021                          None
# 865                            5/25/2021                          None
# 866                            5/25/2021                      6/6/2021
# 867                            5/25/2021                      6/8/2021
# 868                            5/25/2021                      6/7/2021
# 869                            5/26/2021                          None
#
#     earliest_reported_cases latest_reported_cases workplace_classification  \
# 854                    None           ng/Industry                     None
# 855               4/15/2021          5/22/2021 on                     None
# 856               5/23/2021      5/30/2021 Retail                     None
# 857               5/23/2021  5/25/2021 nstruction                     None
# 858                    None            nstruction                     None
# 859                    None            nstruction                     None
# 860                    None           ng/Industry                     None
# 861                    None                    on                     None
# 862                    None            nstruction                     None
# 863               5/25/2021  6/2/2021 (Acute/LTC)                     None
# 864               5/25/2021  5/31/2021 nstruction                     None
# 865               5/25/2021  5/31/2021 Bar/Lounge                     None
# 866                    None                Retail                     None
# 867                    None                Retail                     None
# 868                    None           ng/Industry                     None
# 869               5/26/2021          5/29/2021 on                     None
#
#     cases_when_cluster_confirmed     total_cases workplace_status closure_y_n  \
# 854                            5  5 transmission             None          No
# 855                            0          3 Open             None          No
# 856                            4    4 Not closed             None          No
# 857                            4        4 Closed             None         Yes
# 858                            5        5 Closed             None         Yes
# 859                            3          3 open             None          No
# 860                            3  3 transmission             None          No
# 861                            3  3 transmission             None          No
# 862                            5      5 measures             None          No
# 863                            3        3 Closed             None         Yes
# 864                            3    3 Not closed             None          No
# 865                            3        3 Closed             None         Yes
# 866                            3        3 Closed             None         Yes
# 867                            3          3 open             None          No
# 868                            3       6 closure             None         Yes
# 869                            3        3 Closed             None         Yes
#
#     closed_by_order voluntary_closure closure_date partially_closed  \
# 854              No           Unknown         None               No
# 855              No                No         None          Unknown
# 856              No                No         None          Unknown
# 857              No               Yes    5/17/2021          Unknown
# 858             Yes           Unknown    5/28/2021               No
# 859              No           Unknown         None               No
# 860              No           Unknown         None               No
# 861              No           Unknown         None               No
# 862              No           Unknown         None               No
# 863              No               Yes    5/20/2021          Unknown
# 864              No                No         None          Unknown
# 865              No               Yes    5/22/2021          Unknown
# 866              No           Unknown    4/28/2021              Yes
# 867              No           Unknown         None               No
# 868              No               Yes    #########          Unknown
# 869             Yes               Yes     6/1/2021          Unknown
#
#     unknown_closure_type open days_since_last_case active_clusters  \
# 854                  NaN  Yes                 None              No
# 855                  NaN  Yes                   45              No
# 856                  NaN  Yes                 None              No
# 857                  NaN   No                 None              No
# 858                  NaN   No                 None              No
# 859                  NaN  Yes                 None              No
# 860                  NaN  Yes                 None              No
# 861                  NaN  Yes                 None              No
# 862                  NaN  Yes                 None              No
# 863                  NaN   No                 None              No
# 864                  NaN  Yes                 None              No
# 865                  NaN   No                 None              No
# 866                  NaN   No                 None              No
# 867                  NaN  Yes                 None              No
# 868                  NaN   No                 None              No
# 869                  NaN   No                 None              No
#
#     cluster_confirmed_epidate cluster_closed_epidate
# 854                   20-2021                   None
# 855                   20-2021                   None
# 856                   21-2021                   None
# 857                   21-2021                20-2021
# 858                   21-2021                21-2021
# 859                   21-2021                   None
# 860                   21-2021                   None
# 861                   21-2021                   None
# 862                   21-2021                   None
# 863                   21-2021                20-2021
# 864                   21-2021                   None
# 865                   21-2021                20-2021
# 866                   21-2021                17-2021
# 867                   21-2021                   None
# 868                   21-2021             13-4441094
# 869                   21-2021                22-2021

# %%
steps_dict_list = [
    ('replace', ('city', 'COQUITLAM', 'PORT COQUITLAM')),
    ('split_column', ('latest_reported_cases', 'latest_reported_cases', 'workplace_classification')),
    ('split_column', ('total_cases', 'total_cases', 'workplace_status')),
    ('convert_date_string_to_datetime_bycolumn', None),
    ('map_values', ('city', 1)),
    # ('split_column', ('days_since_last_case', 'days_since_last_case', 'active_clusters')),
    ('convert_date_string_to_datetime_bycolumn', (None)),
]

# save = False
save = True
fixed_page = processing_chain(index, steps_dict_list, save_to_dict=save)
# Out:
# (0) Function: replace. Arguments: ('city', 'COQUITLAM', 'PORT COQUITLAM'). Save: False
# Problem pages implicit index 8: F22-1445 Records_Part2.pdf page 54
# Applying function replace to F22-1445 Records_Part2.pdf page 54
# 	Function arguments: ('city', 'COQUITLAM', 'PORT COQUITLAM')
# DataFrame columns:  ['index: object', 'HA: object', 'workplace_name: object', 'workplace_address: object', 'city: object', 'date_cluster_confirmed_public_health: object', 'date_cluster_no_longer_active: object', 'earliest_reported_cases: object', 'latest_reported_cases: object', 'workplace_classification: object', 'cases_when_cluster_confirmed: object', 'total_cases: object', 'workplace_status: object', 'closure_y_n: object', 'closed_by_order: object', 'voluntary_closure: object', 'closure_date: object', 'partially_closed: object', 'unknown_closure_type: object', 'open: object', 'days_since_last_case: object', 'active_clusters: object', 'cluster_confirmed_epidate: object', 'doc_page_number: object', 'cluster_closed_epidate: object', 'file: object', 'flag: object']
#
#
# (1) Function: split_column. Arguments: ('latest_reported_cases', 'latest_reported_cases', 'workplace_classification'). Save: False
# Problem pages implicit index 8: F22-1445 Records_Part2.pdf page 54
# Applying function <function split_column at 0x0000028040AAD5E0> to F22-1445 Records_Part2.pdf page 54
# 	Function arguments: ('latest_reported_cases', 'latest_reported_cases', 'workplace_classification')
# Column "latest_reported_cases" split to None and ng/Industry for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 5/22/2021 and on for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 5/30/2021 and Retail for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 5/25/2021 and nstruction for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and nstruction for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and nstruction for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and ng/Industry for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and on for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and nstruction for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 6/2/2021 and (Acute/LTC) for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 5/31/2021 and nstruction for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 5/31/2021 and Bar/Lounge for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Retail for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Retail for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and ng/Industry for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 5/29/2021 and on for columns "latest_reported_cases" and "workplace_classification"
# Map_column: ['ng/Industry', 'on', 'Retail', 'nstruction', 'nstruction', 'nstruction', 'ng/Industry', 'on', 'nstruction', '(Acute/LTC)', 'nstruction', 'Bar/Lounge', 'Retail', 'Retail', 'ng/Industry', 'on']
# Values in workplace_classification mapped to {'Other': 'Other', 'Retail': 'Retail', 'nstruction': 'Maintainance/Trades/Construction', 'Office': 'Office', 'ture': 'Farm/Agriculture', 'Processing': 'Food Processing', 'on': 'Transportaton', 'Bar/Lounge': 'Restaurant/Bar/Lounge', 'Warehouse': 'Warehouse', 'ng/Industry': 'Manufacturing/Industry', 'Gym/Fitness': 'Gym/Fitness', 'Care': 'Personal Care', 'Responder': 'First Responder', '(Acute/LTC)': 'Health Care Facility (Acute/LTC)'}
# DataFrame columns:  ['index: float64', 'HA: object', 'workplace_name: float64', 'workplace_address: object', 'city: object', 'date_cluster_confirmed_public_health: object', 'date_cluster_no_longer_active: object', 'earliest_reported_cases: object', 'latest_reported_cases: object', 'workplace_classification: object', 'cases_when_cluster_confirmed: object', 'total_cases: object', 'workplace_status: object', 'closure_y_n: object', 'closed_by_order: object', 'voluntary_closure: object', 'closure_date: object', 'partially_closed: object', 'unknown_closure_type: float64', 'open: object', 'days_since_last_case: object', 'active_clusters: object', 'cluster_confirmed_epidate: object', 'doc_page_number: int64', 'cluster_closed_epidate: object', 'file: object', 'flag: int64']
#
#
# (2) Function: split_column. Arguments: ('total_cases', 'total_cases', 'workplace_status'). Save: False
# Problem pages implicit index 8: F22-1445 Records_Part2.pdf page 54
# Applying function <function split_column at 0x0000028040AAD5E0> to F22-1445 Records_Part2.pdf page 54
# 	Function arguments: ('total_cases', 'total_cases', 'workplace_status')
# Column "total_cases" split to 5 and transmission for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and Open for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 4 and closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 4 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 5 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and open for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and transmission for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and transmission for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 5 and measures for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and open for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 6 and closure for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and Closed for columns "total_cases" and "workplace_status"
# Map_column: ['transmission', 'Open', 'closed', 'Closed', 'Closed', 'open', 'transmission', 'transmission', 'measures', 'Closed', 'closed', 'Closed', 'Closed', 'open', 'closure', 'Closed']
# Values in workplace_status mapped to {'transmission': 'Not closed: insufficient evidence of recent transmission', 'Closed': 'Closed', 'open': 'Not closed: Public interest in remaining open', 'Open': 'Open', 'closed': 'Not closed', 'measures': 'Not closed: Alternate control measures', 'closed)': 'Managed without closure (not closed)', 'PH': 'Partially closed or widespread isolation by PH', 'order': 'Closed by order', 'non-closure)': 'Open (if open, reason for non-closure)', 'closure': 'Voluntary closure'}
# DataFrame columns:  ['index: float64', 'HA: object', 'workplace_name: float64', 'workplace_address: object', 'city: object', 'date_cluster_confirmed_public_health: object', 'date_cluster_no_longer_active: object', 'earliest_reported_cases: object', 'latest_reported_cases: object', 'workplace_classification: object', 'cases_when_cluster_confirmed: object', 'total_cases: object', 'workplace_status: object', 'closure_y_n: object', 'closed_by_order: object', 'voluntary_closure: object', 'closure_date: object', 'partially_closed: object', 'unknown_closure_type: float64', 'open: object', 'days_since_last_case: object', 'active_clusters: object', 'cluster_confirmed_epidate: object', 'doc_page_number: int64', 'cluster_closed_epidate: object', 'file: object', 'flag: int64']
#
#
# (3) Function: convert_date_string_to_datetime_bycolumn. Arguments: None. Save: False
# Problem pages implicit index 8: F22-1445 Records_Part2.pdf page 54
# Applying function <function convert_date_string_to_datetime_bycolumn at 0x0000028018CE0550> to F22-1445 Records_Part2.pdf page 54
# 	Function arguments: None
# 	Problem with F22-1445 Records_Part2.pdf page 54 column closure_date (row 868: time data '#########' does not match format '%m/%d/%Y' (match))
# DataFrame columns:  ['index: float64', 'HA: object', 'workplace_name: float64', 'workplace_address: object', 'city: object', 'date_cluster_confirmed_public_health: datetime64[ns]', 'date_cluster_no_longer_active: datetime64[ns]', 'earliest_reported_cases: datetime64[ns]', 'latest_reported_cases: datetime64[ns]', 'workplace_classification: object', 'cases_when_cluster_confirmed: object', 'total_cases: object', 'workplace_status: object', 'closure_y_n: object', 'closed_by_order: object', 'voluntary_closure: object', 'closure_date: datetime64[ns]', 'partially_closed: object', 'unknown_closure_type: float64', 'open: object', 'days_since_last_case: object', 'active_clusters: object', 'cluster_confirmed_epidate: object', 'doc_page_number: int64', 'cluster_closed_epidate: object', 'file: object', 'flag: int64']
#
#
# (4) Function: map_values. Arguments: ('city', 1). Save: False
# Problem pages implicit index 8: F22-1445 Records_Part2.pdf page 54
# Applying function <function map_values at 0x0000028040AAD670> to F22-1445 Records_Part2.pdf page 54
# 	Function arguments: ('city', 1)
# Using default mapping...
# DataFrame columns:  ['index: float64', 'HA: object', 'workplace_name: float64', 'workplace_address: object', 'city: object', 'date_cluster_confirmed_public_health: datetime64[ns]', 'date_cluster_no_longer_active: datetime64[ns]', 'earliest_reported_cases: datetime64[ns]', 'latest_reported_cases: datetime64[ns]', 'workplace_classification: object', 'cases_when_cluster_confirmed: object', 'total_cases: object', 'workplace_status: object', 'closure_y_n: object', 'closed_by_order: object', 'voluntary_closure: object', 'closure_date: datetime64[ns]', 'partially_closed: object', 'unknown_closure_type: float64', 'open: object', 'days_since_last_case: object', 'active_clusters: object', 'cluster_confirmed_epidate: object', 'doc_page_number: int64', 'cluster_closed_epidate: object', 'file: object', 'flag: int64']
#
#
# (5) Function: convert_date_string_to_datetime_bycolumn. Arguments: None. Save: True
# Problem pages implicit index 8: F22-1445 Records_Part2.pdf page 54
# Applying function <function convert_date_string_to_datetime_bycolumn at 0x0000028018CE0550> to F22-1445 Records_Part2.pdf page 54
# 	Function arguments: None
# Updated fixed_df_dict keys: ['Part2_page10', 'Part2_page19', 'Part2_page42', 'Part2_page44', 'Part2_page45', 'Part2_page48', 'Part2_page50', 'Part2_page51', 'Part2_page54']
# Date and time completed: 2023-04-25 19:36:37
#
#
# Implicit index 8: F22-1445 Records_Part2.pdf page 54
# Could not convert to datetime: []
# Could not convert to integer: []
# Page columns: ['index', 'HA', 'workplace_name', 'workplace_address', 'city', 'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active', 'earliest_reported_cases', 'latest_reported_cases', 'workplace_classification', 'cases_when_cluster_confirmed', 'total_cases', 'workplace_status', 'closure_y_n', 'closed_by_order', 'voluntary_closure', 'closure_date', 'partially_closed', 'unknown_closure_type', 'open', 'days_since_last_case', 'active_clusters', 'cluster_confirmed_epidate', 'doc_page_number', 'cluster_closed_epidate', 'file', 'flag']
# fixed_df_dict keys: ['Part2_page10', 'Part2_page19', 'Part2_page42', 'Part2_page44', 'Part2_page45', 'Part2_page48', 'Part2_page50', 'Part2_page51', 'Part2_page54']

# %%
fixed_df_dict['Part2_page54']
# Out:
#      index    HA  workplace_name workplace_address              city  \
# 854  483.0   FHA             NaN              None        ABBOTSFORD
# 855  484.0  VIHA             NaN              None  VICTORIA/SAANICH
# 856  485.0   IHA             NaN              None           KELOWNA
# 857  486.0   IHA             NaN              None           KELOWNA
# 858  487.0   FHA             NaN              None    PORT COQUITLAM
# 859  488.0   FHA             NaN              None           BURNABY
# 860  489.0   FHA             NaN              None             DELTA
# 861  490.0   FHA             NaN              None           BURNABY
# 862  491.0   FHA             NaN              None           LANGLEY
# 863  492.0   IHA             NaN              None            VERNON
# 864  493.0   IHA             NaN              None           KELOWNA
# 865  494.0   IHA             NaN              None            OLIVER
# 866  495.0   FHA             NaN              None        CHILLIWACK
# 867  496.0   FHA             NaN              None            SURREY
# 868  497.0   NHA             NaN              None           UNKNOWN
# 869  498.0   IHA             NaN              None           KELOWNA
#
#     date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 854                           2021-05-21                    2021-06-05
# 855                           2021-05-21                           NaT
# 856                           2021-05-23                           NaT
# 857                           2021-05-23                           NaT
# 858                           2021-05-24                    2021-06-09
# 859                           2021-05-24                    2021-05-28
# 860                           2021-05-24                    2021-06-05
# 861                           2021-05-24                    2021-05-24
# 862                           2021-05-24                    2021-06-07
# 863                           2021-05-25                           NaT
# 864                           2021-05-25                           NaT
# 865                           2021-05-25                           NaT
# 866                           2021-05-25                    2021-06-06
# 867                           2021-05-25                    2021-06-08
# 868                           2021-05-25                    2021-06-07
# 869                           2021-05-26                           NaT
#
#     earliest_reported_cases latest_reported_cases  \
# 854                     NaT                   NaT
# 855              2021-04-15            2021-05-22
# 856              2021-05-23            2021-05-30
# 857              2021-05-23            2021-05-25
# 858                     NaT                   NaT
# 859                     NaT                   NaT
# 860                     NaT                   NaT
# 861                     NaT                   NaT
# 862                     NaT                   NaT
# 863              2021-05-25            2021-06-02
# 864              2021-05-25            2021-05-31
# 865              2021-05-25            2021-05-31
# 866                     NaT                   NaT
# 867                     NaT                   NaT
# 868                     NaT                   NaT
# 869              2021-05-26            2021-05-29
#
#              workplace_classification cases_when_cluster_confirmed  \
# 854            Manufacturing/Industry                            5
# 855                     Transportaton                            0
# 856                            Retail                            4
# 857  Maintainance/Trades/Construction                            4
# 858  Maintainance/Trades/Construction                            5
# 859  Maintainance/Trades/Construction                            3
# 860            Manufacturing/Industry                            3
# 861                     Transportaton                            3
# 862  Maintainance/Trades/Construction                            5
# 863  Health Care Facility (Acute/LTC)                            3
# 864  Maintainance/Trades/Construction                            3
# 865             Restaurant/Bar/Lounge                            3
# 866                            Retail                            3
# 867                            Retail                            3
# 868            Manufacturing/Industry                            3
# 869                     Transportaton                            3
#
#     total_cases                                          workplace_status  \
# 854           5  Not closed: insufficient evidence of recent transmission
# 855           3                                                      Open
# 856           4                                                Not closed
# 857           4                                                    Closed
# 858           5                                                    Closed
# 859           3             Not closed: Public interest in remaining open
# 860           3  Not closed: insufficient evidence of recent transmission
# 861           3  Not closed: insufficient evidence of recent transmission
# 862           5                    Not closed: Alternate control measures
# 863           3                                                    Closed
# 864           3                                                Not closed
# 865           3                                                    Closed
# 866           3                                                    Closed
# 867           3             Not closed: Public interest in remaining open
# 868           6                                         Voluntary closure
# 869           3                                                    Closed
#
#     closure_y_n closed_by_order voluntary_closure closure_date  \
# 854          No              No           Unknown          NaT
# 855          No              No                No          NaT
# 856          No              No                No          NaT
# 857         Yes              No               Yes   2021-05-17
# 858         Yes             Yes           Unknown   2021-05-28
# 859          No              No           Unknown          NaT
# 860          No              No           Unknown          NaT
# 861          No              No           Unknown          NaT
# 862          No              No           Unknown          NaT
# 863         Yes              No               Yes   2021-05-20
# 864          No              No                No          NaT
# 865         Yes              No               Yes   2021-05-22
# 866         Yes              No           Unknown   2021-04-28
# 867          No              No           Unknown          NaT
# 868         Yes              No               Yes   1900-01-01
# 869         Yes             Yes               Yes   2021-06-01
#
#     partially_closed  unknown_closure_type open days_since_last_case  \
# 854               No                   NaN  Yes                 None
# 855          Unknown                   NaN  Yes                   45
# 856          Unknown                   NaN  Yes                 None
# 857          Unknown                   NaN   No                 None
# 858               No                   NaN   No                 None
# 859               No                   NaN  Yes                 None
# 860               No                   NaN  Yes                 None
# 861               No                   NaN  Yes                 None
# 862               No                   NaN  Yes                 None
# 863          Unknown                   NaN   No                 None
# 864          Unknown                   NaN  Yes                 None
# 865          Unknown                   NaN   No                 None
# 866              Yes                   NaN   No                 None
# 867               No                   NaN  Yes                 None
# 868          Unknown                   NaN   No                 None
# 869          Unknown                   NaN   No                 None
#
#     active_clusters cluster_confirmed_epidate  doc_page_number  \
# 854              No                   20-2021               54
# 855              No                   20-2021               54
# 856              No                   21-2021               54
# 857              No                   21-2021               54
# 858              No                   21-2021               54
# 859              No                   21-2021               54
# 860              No                   21-2021               54
# 861              No                   21-2021               54
# 862              No                   21-2021               54
# 863              No                   21-2021               54
# 864              No                   21-2021               54
# 865              No                   21-2021               54
# 866              No                   21-2021               54
# 867              No                   21-2021               54
# 868              No                   21-2021               54
# 869              No                   21-2021               54
#
#     cluster_closed_epidate                        file  flag
# 854                   None  F22-1445 Records_Part2.pdf     1
# 855                   None  F22-1445 Records_Part2.pdf     1
# 856                   None  F22-1445 Records_Part2.pdf     1
# 857                20-2021  F22-1445 Records_Part2.pdf     1
# 858                21-2021  F22-1445 Records_Part2.pdf     1
# 859                   None  F22-1445 Records_Part2.pdf     1
# 860                   None  F22-1445 Records_Part2.pdf     1
# 861                   None  F22-1445 Records_Part2.pdf     1
# 862                   None  F22-1445 Records_Part2.pdf     1
# 863                20-2021  F22-1445 Records_Part2.pdf     1
# 864                   None  F22-1445 Records_Part2.pdf     1
# 865                20-2021  F22-1445 Records_Part2.pdf     1
# 866                17-2021  F22-1445 Records_Part2.pdf     1
# 867                   None  F22-1445 Records_Part2.pdf     1
# 868             13-4441094  F22-1445 Records_Part2.pdf     1
# 869                22-2021  F22-1445 Records_Part2.pdf     1

# %% [markdown]
# ## Index 9

# %%
index = 9
view_problem_page(index) #pdf p. 58
# Out:
# Implicit index 9: F22-1445 Records_Part2.pdf page 55
# Could not convert to datetime: ['latest_reported_cases']
# Could not convert to integer: ['total_cases']
# Page columns: ['index', 'HA', 'workplace_name', 'workplace_address', 'city', 'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active', 'earliest_reported_cases', 'latest_reported_cases', 'workplace_classification', 'cases_when_cluster_confirmed', 'total_cases', 'workplace_status', 'closure_y_n', 'closed_by_order', 'voluntary_closure', 'closure_date', 'partially_closed', 'unknown_closure_type', 'open', 'days_since_last_case', 'active_clusters', 'cluster_confirmed_epidate', 'doc_page_number', 'cluster_closed_epidate', 'file', 'flag']
#      index    HA workplace_name workplace_address       city  \
# 870  499.0   FHA            NaN              None  COQUITLAM
# 871  500.0   FHA            NaN              None      MOODY
# 872  501.0   FHA            NaN              None      RIDGE
# 873  502.0  VIHA            NaN              None    Nanaimo
# 874  503.0   IHA            NaN              None    Kelowna
# 875  504.0   IHA            NaN              None    Kelowna
# 876  505.0   IHA            NaN              None    Kelowna
# 877  506.0   FHA            NaN              None          D
# 878  507.0   FHA            NaN              None    LANGLEY
# 879  508.0   FHA            NaN              None    BURNABY
# 880  509.0   FHA            NaN              None  COQUITLAM
# 881  510.0   NHA            NaN              None    Unknown
# 882  511.0   IHA            NaN              None    Kelowna
# 883  512.0   FHA            NaN              None          D
# 884  513.0   FHA            NaN              None          D
# 885  514.0   IHA            NaN              None    Kelowna
# 886  515.0   IHA            NaN              None     Vernon
#
#     date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 870                            5/26/2021                      6/7/2021
# 871                            5/26/2021                      6/7/2021
# 872                            5/26/2021                          None
# 873                            5/26/2021                          None
# 874                            5/27/2021                          None
# 875                            5/27/2021                          None
# 876                            5/27/2021                          None
# 877                            5/27/2021                     6/18/2021
# 878                            5/27/2021                      6/9/2021
# 879                            5/27/2021                     6/18/2021
# 880                            5/27/2021                      6/6/2021
# 881                            5/27/2021                     6/18/2021
# 882                            5/28/2021                          None
# 883                            5/28/2021                      6/5/2021
# 884                            5/30/2021                     6/16/2021
# 885                            5/31/2021                          None
# 886                            5/31/2021                          None
#
#     earliest_reported_cases latest_reported_cases workplace_classification  \
# 870                    None                Office                     None
# 871                    None            Bar/Lounge                     None
# 872                    None                 Other                     None
# 873               5/19/2021      5/26/2021 Retail                     None
# 874               5/27/2021   6/3/2021 Bar/Lounge                     None
# 875               5/27/2021  5/24/2021 Bar/Lounge                     None
# 876               5/27/2021   6/5/2021 Bar/Lounge                     None
# 877                    None                  ture                     None
# 878                    None                Retail                     None
# 879                    None           ng/Industry                     None
# 880                    None                Retail                     None
# 881                    None            nstruction                     None
# 882               5/28/2021         5/3/2021 Care                     None
# 883                    None                Retail                     None
# 884                    None            Bar/Lounge                     None
# 885               5/31/2021  5/31/2021 nstruction                     None
# 886               5/31/2021       6/8/2021 Retail                     None
#
#     cases_when_cluster_confirmed     total_cases workplace_status closure_y_n  \
# 870                            4        4 Closed             None         Yes
# 871                            6        6 Closed             None         Yes
# 872                            4        4 Closed             None         Yes
# 873                            0          4 Open             None          No
# 874                            4    4 Not closed             None          No
# 875                            3    3 Not closed             None          No
# 876                            4        5 Closed             None         Yes
# 877                           21       21 Closed             None         Yes
# 878                            4        4 Closed             None         Yes
# 879                            5      5 measures             None          No
# 880                            3  3 transmission             None          No
# 881                            3       3 closure             None         Yes
# 882                            3    3 Not closed             None          No
# 883                            4      4 measures             None          No
# 884                            4      4 measures             None          No
# 885                            4        4 Closed             None         Yes
# 886                            3        4 Closed             None         Yes
#
#     closed_by_order voluntary_closure closure_date partially_closed  \
# 870             Yes           Unknown    5/27/2021               No
# 871             Yes           Unknown    5/26/2021               No
# 872             Yes           Unknown    5/26/2021               No
# 873              No                No         None          Unknown
# 874              No                No         None          Unknown
# 875              No                No         None          Unknown
# 876              No               Yes    5/26/2021          Unknown
# 877             Yes           Unknown     6/3/2021               No
# 878             Yes           Unknown    5/28/2021               No
# 879              No           Unknown         None               No
# 880              No           Unknown         None               No
# 881              No               Yes         None          Unknown
# 882              No                No         None          Unknown
# 883              No           Unknown         None               No
# 884              No           Unknown         None               No
# 885              No               Yes    5/20/2021          Unknown
# 886              No                No    5/22/2021          Unknown
#
#     unknown_closure_type open days_since_last_case active_clusters  \
# 870                  NaN   No                 None              No
# 871                  NaN   No                 None              No
# 872                  NaN   No                 None             Yes
# 873                  NaN  Yes                   41              No
# 874                  NaN  Yes                 None              No
# 875                  NaN  Yes                 None              No
# 876                  NaN   No                 None              No
# 877                  NaN   No                 None              No
# 878                  NaN   No                 None              No
# 879                  NaN  Yes                 None              No
# 880                  NaN  Yes                 None              No
# 881                  NaN   No                 None              No
# 882                  NaN  Yes                 None              No
# 883                  NaN  Yes                 None              No
# 884                  NaN  Yes                 None              No
# 885                  NaN   No                 None              No
# 886                  NaN   No                 None              No
#
#     cluster_confirmed_epidate cluster_closed_epidate
# 870                   21-2021                21-2021
# 871                   21-2021                21-2021
# 872                   21-2021                21-2021
# 873                   21-2021                   None
# 874                   21-2021                   None
# 875                   21-2021                   None
# 876                   21-2021                21-2021
# 877                   21-2021                22-2021
# 878                   21-2021                21-2021
# 879                   21-2021                   None
# 880                   21-2021                   None
# 881                   21-2021                   None
# 882                   21-2021                   None
# 883                   21-2021                   None
# 884                   22-2021                   None
# 885                   22-2021                20-2021
# 886                   22-2021                20-2021

# %%
steps_dict_list = [
    # ('replace', ('city', 'COQUITLAM', 'PORT COQUITLAM')),
    ('split_column', ('latest_reported_cases', 'latest_reported_cases', 'workplace_classification')),
    ('split_column', ('total_cases', 'total_cases', 'workplace_status')),
    # ('convert_date_string_to_datetime_bycolumn', None),
    ('map_values', ('city', 1)),
    # ('split_column', ('days_since_last_case', 'days_since_last_case', 'active_clusters')),
    # ('convert_date_string_to_datetime_bycolumn', (None)),
]

# save = False
save = True
fixed_page = processing_chain(index, steps_dict_list, save_to_dict=save)
# Out:
# (0) Function: split_column. Arguments: ('latest_reported_cases', 'latest_reported_cases', 'workplace_classification'). Save: False
# Problem pages implicit index 9: F22-1445 Records_Part2.pdf page 55
# Applying function <function split_column at 0x0000028040AA0550> to F22-1445 Records_Part2.pdf page 55
# 	Function arguments: ('latest_reported_cases', 'latest_reported_cases', 'workplace_classification')
# Column "latest_reported_cases" split to None and Office for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Bar/Lounge for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Other for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 5/26/2021 and Retail for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 6/3/2021 and Bar/Lounge for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 5/24/2021 and Bar/Lounge for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 6/5/2021 and Bar/Lounge for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and ture for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Retail for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and ng/Industry for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Retail for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and nstruction for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 5/3/2021 and Care for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Retail for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Bar/Lounge for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 5/31/2021 and nstruction for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 6/8/2021 and Retail for columns "latest_reported_cases" and "workplace_classification"
# Map_column: ['Office', 'Bar/Lounge', 'Other', 'Retail', 'Bar/Lounge', 'Bar/Lounge', 'Bar/Lounge', 'ture', 'Retail', 'ng/Industry', 'Retail', 'nstruction', 'Care', 'Retail', 'Bar/Lounge', 'nstruction', 'Retail']
# Values in workplace_classification mapped to {'Other': 'Other', 'Retail': 'Retail', 'nstruction': 'Maintainance/Trades/Construction', 'Office': 'Office', 'ture': 'Farm/Agriculture', 'Processing': 'Food Processing', 'on': 'Transportaton', 'Bar/Lounge': 'Restaurant/Bar/Lounge', 'Warehouse': 'Warehouse', 'ng/Industry': 'Manufacturing/Industry', 'Gym/Fitness': 'Gym/Fitness', 'Care': 'Personal Care', 'Responder': 'First Responder', '(Acute/LTC)': 'Health Care Facility (Acute/LTC)'}
# DataFrame columns:  ['index: float64', 'HA: object', 'workplace_name: float64', 'workplace_address: object', 'city: object', 'date_cluster_confirmed_public_health: object', 'date_cluster_no_longer_active: object', 'earliest_reported_cases: object', 'latest_reported_cases: object', 'workplace_classification: object', 'cases_when_cluster_confirmed: object', 'total_cases: object', 'workplace_status: object', 'closure_y_n: object', 'closed_by_order: object', 'voluntary_closure: object', 'closure_date: object', 'partially_closed: object', 'unknown_closure_type: float64', 'open: object', 'days_since_last_case: object', 'active_clusters: object', 'cluster_confirmed_epidate: object', 'doc_page_number: int64', 'cluster_closed_epidate: object', 'file: object', 'flag: int64']
#
#
# (1) Function: split_column. Arguments: ('total_cases', 'total_cases', 'workplace_status'). Save: False
# Problem pages implicit index 9: F22-1445 Records_Part2.pdf page 55
# Applying function <function split_column at 0x0000028040AA0550> to F22-1445 Records_Part2.pdf page 55
# 	Function arguments: ('total_cases', 'total_cases', 'workplace_status')
# Column "total_cases" split to 4 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 6 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 4 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 4 and Open for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 4 and closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 5 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 21 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 4 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 5 and measures for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and transmission for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and closure for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 4 and measures for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 4 and measures for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 4 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 4 and Closed for columns "total_cases" and "workplace_status"
# Map_column: ['Closed', 'Closed', 'Closed', 'Open', 'closed', 'closed', 'Closed', 'Closed', 'Closed', 'measures', 'transmission', 'closure', 'closed', 'measures', 'measures', 'Closed', 'Closed']
# Values in workplace_status mapped to {'transmission': 'Not closed: insufficient evidence of recent transmission', 'Closed': 'Closed', 'open': 'Not closed: Public interest in remaining open', 'Open': 'Open', 'closed': 'Not closed', 'measures': 'Not closed: Alternate control measures', 'closed)': 'Managed without closure (not closed)', 'PH': 'Partially closed or widespread isolation by PH', 'order': 'Closed by order', 'non-closure)': 'Open (if open, reason for non-closure)', 'closure': 'Voluntary closure'}
# DataFrame columns:  ['index: float64', 'HA: object', 'workplace_name: float64', 'workplace_address: object', 'city: object', 'date_cluster_confirmed_public_health: object', 'date_cluster_no_longer_active: object', 'earliest_reported_cases: object', 'latest_reported_cases: object', 'workplace_classification: object', 'cases_when_cluster_confirmed: object', 'total_cases: object', 'workplace_status: object', 'closure_y_n: object', 'closed_by_order: object', 'voluntary_closure: object', 'closure_date: object', 'partially_closed: object', 'unknown_closure_type: float64', 'open: object', 'days_since_last_case: object', 'active_clusters: object', 'cluster_confirmed_epidate: object', 'doc_page_number: int64', 'cluster_closed_epidate: object', 'file: object', 'flag: int64']
#
#
# (2) Function: map_values. Arguments: ('city', 1). Save: True
# Problem pages implicit index 9: F22-1445 Records_Part2.pdf page 55
# Applying function <function map_values at 0x0000028018CE0550> to F22-1445 Records_Part2.pdf page 55
# 	Function arguments: ('city', 1)
# Using default mapping...
# Updated fixed_df_dict keys: ['Part2_page10', 'Part2_page19', 'Part2_page42', 'Part2_page44', 'Part2_page45', 'Part2_page48', 'Part2_page50', 'Part2_page51', 'Part2_page54', 'Part2_page55']
# Date and time completed: 2023-04-25 19:42:57
#
#
# Implicit index 9: F22-1445 Records_Part2.pdf page 55
# Could not convert to datetime: []
# Could not convert to integer: []
# Page columns: ['index', 'HA', 'workplace_name', 'workplace_address', 'city', 'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active', 'earliest_reported_cases', 'latest_reported_cases', 'workplace_classification', 'cases_when_cluster_confirmed', 'total_cases', 'workplace_status', 'closure_y_n', 'closed_by_order', 'voluntary_closure', 'closure_date', 'partially_closed', 'unknown_closure_type', 'open', 'days_since_last_case', 'active_clusters', 'cluster_confirmed_epidate', 'doc_page_number', 'cluster_closed_epidate', 'file', 'flag']
# fixed_df_dict keys: ['Part2_page10', 'Part2_page19', 'Part2_page42', 'Part2_page44', 'Part2_page45', 'Part2_page48', 'Part2_page50', 'Part2_page51', 'Part2_page54', 'Part2_page55']

# %%
fixed_page['Part2_page55']
# Out:
#      index    HA  workplace_name workplace_address         city  \
# 870  499.0   FHA             NaN              None    COQUITLAM
# 871  500.0   FHA             NaN              None   PORT MOODY
# 872  501.0   FHA             NaN              None  MAPLE RIDGE
# 873  502.0  VIHA             NaN              None      NANAIMO
# 874  503.0   IHA             NaN              None      KELOWNA
# 875  504.0   IHA             NaN              None      KELOWNA
# 876  505.0   IHA             NaN              None      KELOWNA
# 877  506.0   FHA             NaN              None   ABBOTSFORD
# 878  507.0   FHA             NaN              None      LANGLEY
# 879  508.0   FHA             NaN              None      BURNABY
# 880  509.0   FHA             NaN              None    COQUITLAM
# 881  510.0   NHA             NaN              None      UNKNOWN
# 882  511.0   IHA             NaN              None      KELOWNA
# 883  512.0   FHA             NaN              None   ABBOTSFORD
# 884  513.0   FHA             NaN              None   ABBOTSFORD
# 885  514.0   IHA             NaN              None      KELOWNA
# 886  515.0   IHA             NaN              None       VERNON
#
#     date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 870                            5/26/2021                      6/7/2021
# 871                            5/26/2021                      6/7/2021
# 872                            5/26/2021                          None
# 873                            5/26/2021                          None
# 874                            5/27/2021                          None
# 875                            5/27/2021                          None
# 876                            5/27/2021                          None
# 877                            5/27/2021                     6/18/2021
# 878                            5/27/2021                      6/9/2021
# 879                            5/27/2021                     6/18/2021
# 880                            5/27/2021                      6/6/2021
# 881                            5/27/2021                     6/18/2021
# 882                            5/28/2021                          None
# 883                            5/28/2021                      6/5/2021
# 884                            5/30/2021                     6/16/2021
# 885                            5/31/2021                          None
# 886                            5/31/2021                          None
#
#     earliest_reported_cases latest_reported_cases  \
# 870                    None                  None
# 871                    None                  None
# 872                    None                  None
# 873               5/19/2021             5/26/2021
# 874               5/27/2021              6/3/2021
# 875               5/27/2021             5/24/2021
# 876               5/27/2021              6/5/2021
# 877                    None                  None
# 878                    None                  None
# 879                    None                  None
# 880                    None                  None
# 881                    None                  None
# 882               5/28/2021              5/3/2021
# 883                    None                  None
# 884                    None                  None
# 885               5/31/2021             5/31/2021
# 886               5/31/2021              6/8/2021
#
#              workplace_classification cases_when_cluster_confirmed  \
# 870                            Office                            4
# 871             Restaurant/Bar/Lounge                            6
# 872                             Other                            4
# 873                            Retail                            0
# 874             Restaurant/Bar/Lounge                            4
# 875             Restaurant/Bar/Lounge                            3
# 876             Restaurant/Bar/Lounge                            4
# 877                  Farm/Agriculture                           21
# 878                            Retail                            4
# 879            Manufacturing/Industry                            5
# 880                            Retail                            3
# 881  Maintainance/Trades/Construction                            3
# 882                     Personal Care                            3
# 883                            Retail                            4
# 884             Restaurant/Bar/Lounge                            4
# 885  Maintainance/Trades/Construction                            4
# 886                            Retail                            3
#
#     total_cases                                          workplace_status  \
# 870           4                                                    Closed
# 871           6                                                    Closed
# 872           4                                                    Closed
# 873           4                                                      Open
# 874           4                                                Not closed
# 875           3                                                Not closed
# 876           5                                                    Closed
# 877          21                                                    Closed
# 878           4                                                    Closed
# 879           5                    Not closed: Alternate control measures
# 880           3  Not closed: insufficient evidence of recent transmission
# 881           3                                         Voluntary closure
# 882           3                                                Not closed
# 883           4                    Not closed: Alternate control measures
# 884           4                    Not closed: Alternate control measures
# 885           4                                                    Closed
# 886           4                                                    Closed
#
#     closure_y_n closed_by_order voluntary_closure closure_date  \
# 870         Yes             Yes           Unknown    5/27/2021
# 871         Yes             Yes           Unknown    5/26/2021
# 872         Yes             Yes           Unknown    5/26/2021
# 873          No              No                No         None
# 874          No              No                No         None
# 875          No              No                No         None
# 876         Yes              No               Yes    5/26/2021
# 877         Yes             Yes           Unknown     6/3/2021
# 878         Yes             Yes           Unknown    5/28/2021
# 879          No              No           Unknown         None
# 880          No              No           Unknown         None
# 881         Yes              No               Yes         None
# 882          No              No                No         None
# 883          No              No           Unknown         None
# 884          No              No           Unknown         None
# 885         Yes              No               Yes    5/20/2021
# 886         Yes              No                No    5/22/2021
#
#     partially_closed  unknown_closure_type open days_since_last_case  \
# 870               No                   NaN   No                 None
# 871               No                   NaN   No                 None
# 872               No                   NaN   No                 None
# 873          Unknown                   NaN  Yes                   41
# 874          Unknown                   NaN  Yes                 None
# 875          Unknown                   NaN  Yes                 None
# 876          Unknown                   NaN   No                 None
# 877               No                   NaN   No                 None
# 878               No                   NaN   No                 None
# 879               No                   NaN  Yes                 None
# 880               No                   NaN  Yes                 None
# 881          Unknown                   NaN   No                 None
# 882          Unknown                   NaN  Yes                 None
# 883               No                   NaN  Yes                 None
# 884               No                   NaN  Yes                 None
# 885          Unknown                   NaN   No                 None
# 886          Unknown                   NaN   No                 None
#
#     active_clusters cluster_confirmed_epidate  doc_page_number  \
# 870              No                   21-2021               55
# 871              No                   21-2021               55
# 872             Yes                   21-2021               55
# 873              No                   21-2021               55
# 874              No                   21-2021               55
# 875              No                   21-2021               55
# 876              No                   21-2021               55
# 877              No                   21-2021               55
# 878              No                   21-2021               55
# 879              No                   21-2021               55
# 880              No                   21-2021               55
# 881              No                   21-2021               55
# 882              No                   21-2021               55
# 883              No                   21-2021               55
# 884              No                   22-2021               55
# 885              No                   22-2021               55
# 886              No                   22-2021               55
#
#     cluster_closed_epidate                        file  flag
# 870                21-2021  F22-1445 Records_Part2.pdf     1
# 871                21-2021  F22-1445 Records_Part2.pdf     1
# 872                21-2021  F22-1445 Records_Part2.pdf     1
# 873                   None  F22-1445 Records_Part2.pdf     1
# 874                   None  F22-1445 Records_Part2.pdf     1
# 875                   None  F22-1445 Records_Part2.pdf     1
# 876                21-2021  F22-1445 Records_Part2.pdf     1
# 877                22-2021  F22-1445 Records_Part2.pdf     1
# 878                21-2021  F22-1445 Records_Part2.pdf     1
# 879                   None  F22-1445 Records_Part2.pdf     1
# 880                   None  F22-1445 Records_Part2.pdf     1
# 881                   None  F22-1445 Records_Part2.pdf     1
# 882                   None  F22-1445 Records_Part2.pdf     1
# 883                   None  F22-1445 Records_Part2.pdf     1
# 884                   None  F22-1445 Records_Part2.pdf     1
# 885                20-2021  F22-1445 Records_Part2.pdf     1
# 886                20-2021  F22-1445 Records_Part2.pdf     1

# %% [markdown]
# ## Index 10

# %%
index = 10
view_problem_page(index) #pdf p. 59
# Out:
# Implicit index 10: F22-1445 Records_Part2.pdf page 56
# Could not convert to datetime: ['latest_reported_cases']
# Could not convert to integer: ['total_cases']
# Page columns: ['index', 'HA', 'workplace_name', 'workplace_address', 'city', 'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active', 'earliest_reported_cases', 'latest_reported_cases', 'workplace_classification', 'cases_when_cluster_confirmed', 'total_cases', 'workplace_status', 'closure_y_n', 'closed_by_order', 'voluntary_closure', 'closure_date', 'partially_closed', 'unknown_closure_type', 'open', 'days_since_last_case', 'active_clusters', 'cluster_confirmed_epidate', 'doc_page_number', 'cluster_closed_epidate', 'file', 'flag']
#      index   HA workplace_name workplace_address        city  \
# 887  516.0  IHA            NaN              None     Parsons
# 888  517.0  FHA            NaN              None       DELTA
# 889  518.0  FHA            NaN              None     BURNABY
# 890  519.0  FHA            NaN              None  CHILLIWACK
# 891  520.0  FHA            NaN              None       DELTA
# 892  521.0  IHA            NaN              None      Oliver
# 893  522.0  FHA            NaN              None     BURNABY
# 894  523.0  FHA            NaN              None     LANGLEY
# 895  524.0  FHA            NaN              None           D
# 896  525.0  FHA            NaN              None  CHILLIWACK
# 897  526.0  FHA            NaN              None     LANGLEY
# 898  527.0  IHA            NaN              None     Kelowna
# 899  528.0  IHA            NaN              None    Kamloops
# 900  529.0  IHA            NaN              None      Vernon
# 901  530.0  FHA            NaN              None       RIDGE
#
#     date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 887                            5/31/2021                          None
# 888                            5/31/2021                     6/18/2021
# 889                             6/1/2021                     6/16/2021
# 890                             6/1/2021                     6/10/2021
# 891                             6/2/2021                      7/5/2021
# 892                             6/3/2021                          None
# 893                             6/3/2021                     6/11/2021
# 894                             6/3/2021                      6/4/2021
# 895                             6/3/2021                     6/23/2021
# 896                             6/4/2021                     6/17/2021
# 897                             6/4/2021                     6/18/2021
# 898                             6/5/2021                          None
# 899                             6/5/2021                          None
# 900                             6/6/2021                          None
# 901                             6/6/2021                      6/7/2021
#
#     earliest_reported_cases  latest_reported_cases workplace_classification  \
# 887               5/31/2021  5/10/2021 ng/Industry                     None
# 888                    None             nstruction                     None
# 889                    None            ng/Industry                     None
# 890                    None            Gym/Fitness                     None
# 891                    None            ng/Industry                     None
# 892                6/3/2021   6/13/2021 Bar/Lounge                     None
# 893                    None                     on                     None
# 894                    None                     on                     None
# 895                    None             Processing                     None
# 896                    None             nstruction                     None
# 897                    None                  Other                     None
# 898                6/5/2021   6/18/2021 Bar/Lounge                     None
# 899                6/5/2021       6/12/2021 Retail                     None
# 900                6/6/2021   6/13/2021 nstruction                     None
# 901                    None            Gym/Fitness                     None
#
#     cases_when_cluster_confirmed     total_cases workplace_status closure_y_n  \
# 887                            3        3 Closed             None         Yes
# 888                            4  4 transmission             None          No
# 889                            5        5 Closed             None         Yes
# 890                            3  3 transmission             None          No
# 891                            4        4 Closed             None         Yes
# 892                            1        5 Closed             None         Yes
# 893                            4      4 measures             None          No
# 894                            3          3 open             None          No
# 895                           10         10 open             None          No
# 896                           14     14 measures             None          No
# 897                            3        3 Closed             None         Yes
# 898                            3        5 Closed             None         Yes
# 899                            3    3 Not closed             None          No
# 900                            3    5 Not closed             None          No
# 901                            3  3 transmission             None          No
#
#     closed_by_order voluntary_closure closure_date partially_closed  \
# 887              No               Yes    4/28/2021          Unknown
# 888              No           Unknown         None               No
# 889             Yes           Unknown     6/2/2021               No
# 890              No           Unknown         None               No
# 891             Yes           Unknown     6/3/2021               No
# 892              No               Yes     6/3/2021          Unknown
# 893              No           Unknown         None               No
# 894              No           Unknown         None               No
# 895              No           Unknown         None               No
# 896              No           Unknown         None               No
# 897             Yes           Unknown     6/7/2021               No
# 898              No                No    6/18/2021          Unknown
# 899              No                No         None          Unknown
# 900              No                No         None          Unknown
# 901              No           Unknown         None               No
#
#     unknown_closure_type open days_since_last_case active_clusters  \
# 887                  NaN   No                 None              No
# 888                  NaN  Yes                 None              No
# 889                  NaN   No                 None              No
# 890                  NaN  Yes                 None              No
# 891                  NaN   No                 None              No
# 892                  NaN   No                 None              No
# 893                  NaN  Yes                 None              No
# 894                  NaN  Yes                 None              No
# 895                  NaN  Yes                 None              No
# 896                  NaN  Yes                 None              No
# 897                  NaN   No                 None              No
# 898                  NaN   No                 None              No
# 899                  NaN  Yes                 None              No
# 900                  NaN  Yes                 None              No
# 901                  NaN  Yes                 None              No
#
#     cluster_confirmed_epidate cluster_closed_epidate
# 887                   22-2021                17-2021
# 888                   22-2021                   None
# 889                   22-2021                22-2021
# 890                   22-2021                   None
# 891                   22-2021                22-2021
# 892                   22-2021                22-2021
# 893                   22-2021                   None
# 894                   22-2021                   None
# 895                   22-2021                   None
# 896                   22-2021                   None
# 897                   22-2021                23-2021
# 898                   22-2021                24-2021
# 899                   22-2021                   None
# 900                   23-2021                   None
# 901                   23-2021                   None

# %%
steps_dict_list = [
    # ('replace', ('city', 'COQUITLAM', 'PORT COQUITLAM')),
    ('split_column', ('latest_reported_cases', 'latest_reported_cases', 'workplace_classification')),
    ('split_column', ('total_cases', 'total_cases', 'workplace_status')),
    # ('convert_date_string_to_datetime_bycolumn', None),
    ('map_values', ('city', 1)),
    # ('split_column', ('days_since_last_case', 'days_since_last_case', 'active_clusters')),
    # ('convert_date_string_to_datetime_bycolumn', (None)),
]

# save = False
save = True
fixed_page = processing_chain(index, steps_dict_list, save_to_dict=save)
# Out:
# (0) Function: split_column. Arguments: ('latest_reported_cases', 'latest_reported_cases', 'workplace_classification'). Save: False
# Problem pages implicit index 10: F22-1445 Records_Part2.pdf page 56
# Applying function <function split_column at 0x000002803C5A24C0> to F22-1445 Records_Part2.pdf page 56
# 	Function arguments: ('latest_reported_cases', 'latest_reported_cases', 'workplace_classification')
# Column "latest_reported_cases" split to 5/10/2021 and ng/Industry for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and nstruction for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and ng/Industry for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Gym/Fitness for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and ng/Industry for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 6/13/2021 and Bar/Lounge for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and on for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and on for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Processing for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and nstruction for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Other for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 6/18/2021 and Bar/Lounge for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 6/12/2021 and Retail for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to 6/13/2021 and nstruction for columns "latest_reported_cases" and "workplace_classification"
# Column "latest_reported_cases" split to None and Gym/Fitness for columns "latest_reported_cases" and "workplace_classification"
# Map_column: ['ng/Industry', 'nstruction', 'ng/Industry', 'Gym/Fitness', 'ng/Industry', 'Bar/Lounge', 'on', 'on', 'Processing', 'nstruction', 'Other', 'Bar/Lounge', 'Retail', 'nstruction', 'Gym/Fitness']
# Values in workplace_classification mapped to {'Other': 'Other', 'Retail': 'Retail', 'nstruction': 'Maintainance/Trades/Construction', 'Office': 'Office', 'ture': 'Farm/Agriculture', 'Processing': 'Food Processing', 'on': 'Transportaton', 'Bar/Lounge': 'Restaurant/Bar/Lounge', 'Warehouse': 'Warehouse', 'ng/Industry': 'Manufacturing/Industry', 'Gym/Fitness': 'Gym/Fitness', 'Care': 'Personal Care', 'Responder': 'First Responder', '(Acute/LTC)': 'Health Care Facility (Acute/LTC)'}
# DataFrame columns:  ['index: float64', 'HA: object', 'workplace_name: float64', 'workplace_address: object', 'city: object', 'date_cluster_confirmed_public_health: object', 'date_cluster_no_longer_active: object', 'earliest_reported_cases: object', 'latest_reported_cases: object', 'workplace_classification: object', 'cases_when_cluster_confirmed: object', 'total_cases: object', 'workplace_status: object', 'closure_y_n: object', 'closed_by_order: object', 'voluntary_closure: object', 'closure_date: object', 'partially_closed: object', 'unknown_closure_type: float64', 'open: object', 'days_since_last_case: object', 'active_clusters: object', 'cluster_confirmed_epidate: object', 'doc_page_number: int64', 'cluster_closed_epidate: object', 'file: object', 'flag: int64']
#
#
# (1) Function: split_column. Arguments: ('total_cases', 'total_cases', 'workplace_status'). Save: False
# Problem pages implicit index 10: F22-1445 Records_Part2.pdf page 56
# Applying function <function split_column at 0x000002803C5A24C0> to F22-1445 Records_Part2.pdf page 56
# 	Function arguments: ('total_cases', 'total_cases', 'workplace_status')
# Column "total_cases" split to 3 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 4 and transmission for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 5 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and transmission for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 4 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 5 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 4 and measures for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and open for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 10 and open for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 14 and measures for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 5 and Closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 5 and closed for columns "total_cases" and "workplace_status"
# Column "total_cases" split to 3 and transmission for columns "total_cases" and "workplace_status"
# Map_column: ['Closed', 'transmission', 'Closed', 'transmission', 'Closed', 'Closed', 'measures', 'open', 'open', 'measures', 'Closed', 'Closed', 'closed', 'closed', 'transmission']
# Values in workplace_status mapped to {'transmission': 'Not closed: insufficient evidence of recent transmission', 'Closed': 'Closed', 'open': 'Not closed: Public interest in remaining open', 'Open': 'Open', 'closed': 'Not closed', 'measures': 'Not closed: Alternate control measures', 'closed)': 'Managed without closure (not closed)', 'PH': 'Partially closed or widespread isolation by PH', 'order': 'Closed by order', 'non-closure)': 'Open (if open, reason for non-closure)', 'closure': 'Voluntary closure'}
# DataFrame columns:  ['index: float64', 'HA: object', 'workplace_name: float64', 'workplace_address: object', 'city: object', 'date_cluster_confirmed_public_health: object', 'date_cluster_no_longer_active: object', 'earliest_reported_cases: object', 'latest_reported_cases: object', 'workplace_classification: object', 'cases_when_cluster_confirmed: object', 'total_cases: object', 'workplace_status: object', 'closure_y_n: object', 'closed_by_order: object', 'voluntary_closure: object', 'closure_date: object', 'partially_closed: object', 'unknown_closure_type: float64', 'open: object', 'days_since_last_case: object', 'active_clusters: object', 'cluster_confirmed_epidate: object', 'doc_page_number: int64', 'cluster_closed_epidate: object', 'file: object', 'flag: int64']
#
#
# (2) Function: map_values. Arguments: ('city', 1). Save: True
# Problem pages implicit index 10: F22-1445 Records_Part2.pdf page 56
# Applying function <function map_values at 0x0000028040AA0550> to F22-1445 Records_Part2.pdf page 56
# 	Function arguments: ('city', 1)
# Using default mapping...
# Updated fixed_df_dict keys: ['Part2_page10', 'Part2_page19', 'Part2_page42', 'Part2_page44', 'Part2_page45', 'Part2_page48', 'Part2_page50', 'Part2_page51', 'Part2_page54', 'Part2_page55', 'Part2_page56']
# Date and time completed: 2023-04-25 19:50:46
#
#
# Implicit index 10: F22-1445 Records_Part2.pdf page 56
# Could not convert to datetime: []
# Could not convert to integer: []
# Page columns: ['index', 'HA', 'workplace_name', 'workplace_address', 'city', 'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active', 'earliest_reported_cases', 'latest_reported_cases', 'workplace_classification', 'cases_when_cluster_confirmed', 'total_cases', 'workplace_status', 'closure_y_n', 'closed_by_order', 'voluntary_closure', 'closure_date', 'partially_closed', 'unknown_closure_type', 'open', 'days_since_last_case', 'active_clusters', 'cluster_confirmed_epidate', 'doc_page_number', 'cluster_closed_epidate', 'file', 'flag']
# fixed_df_dict keys: ['Part2_page10', 'Part2_page19', 'Part2_page42', 'Part2_page44', 'Part2_page45', 'Part2_page48', 'Part2_page50', 'Part2_page51', 'Part2_page54', 'Part2_page55', 'Part2_page56']

# %%
fixed_df_dict['Part2_page56']
# Out:
#      index   HA  workplace_name workplace_address         city  \
# 887  516.0  IHA             NaN              None      PARSONS
# 888  517.0  FHA             NaN              None        DELTA
# 889  518.0  FHA             NaN              None      BURNABY
# 890  519.0  FHA             NaN              None   CHILLIWACK
# 891  520.0  FHA             NaN              None        DELTA
# 892  521.0  IHA             NaN              None       OLIVER
# 893  522.0  FHA             NaN              None      BURNABY
# 894  523.0  FHA             NaN              None      LANGLEY
# 895  524.0  FHA             NaN              None   ABBOTSFORD
# 896  525.0  FHA             NaN              None   CHILLIWACK
# 897  526.0  FHA             NaN              None      LANGLEY
# 898  527.0  IHA             NaN              None      KELOWNA
# 899  528.0  IHA             NaN              None     KAMLOOPS
# 900  529.0  IHA             NaN              None       VERNON
# 901  530.0  FHA             NaN              None  MAPLE RIDGE
#
#     date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 887                            5/31/2021                          None
# 888                            5/31/2021                     6/18/2021
# 889                             6/1/2021                     6/16/2021
# 890                             6/1/2021                     6/10/2021
# 891                             6/2/2021                      7/5/2021
# 892                             6/3/2021                          None
# 893                             6/3/2021                     6/11/2021
# 894                             6/3/2021                      6/4/2021
# 895                             6/3/2021                     6/23/2021
# 896                             6/4/2021                     6/17/2021
# 897                             6/4/2021                     6/18/2021
# 898                             6/5/2021                          None
# 899                             6/5/2021                          None
# 900                             6/6/2021                          None
# 901                             6/6/2021                      6/7/2021
#
#     earliest_reported_cases latest_reported_cases  \
# 887               5/31/2021             5/10/2021
# 888                    None                  None
# 889                    None                  None
# 890                    None                  None
# 891                    None                  None
# 892                6/3/2021             6/13/2021
# 893                    None                  None
# 894                    None                  None
# 895                    None                  None
# 896                    None                  None
# 897                    None                  None
# 898                6/5/2021             6/18/2021
# 899                6/5/2021             6/12/2021
# 900                6/6/2021             6/13/2021
# 901                    None                  None
#
#              workplace_classification cases_when_cluster_confirmed  \
# 887            Manufacturing/Industry                            3
# 888  Maintainance/Trades/Construction                            4
# 889            Manufacturing/Industry                            5
# 890                       Gym/Fitness                            3
# 891            Manufacturing/Industry                            4
# 892             Restaurant/Bar/Lounge                            1
# 893                     Transportaton                            4
# 894                     Transportaton                            3
# 895                   Food Processing                           10
# 896  Maintainance/Trades/Construction                           14
# 897                             Other                            3
# 898             Restaurant/Bar/Lounge                            3
# 899                            Retail                            3
# 900  Maintainance/Trades/Construction                            3
# 901                       Gym/Fitness                            3
#
#     total_cases                                          workplace_status  \
# 887           3                                                    Closed
# 888           4  Not closed: insufficient evidence of recent transmission
# 889           5                                                    Closed
# 890           3  Not closed: insufficient evidence of recent transmission
# 891           4                                                    Closed
# 892           5                                                    Closed
# 893           4                    Not closed: Alternate control measures
# 894           3             Not closed: Public interest in remaining open
# 895          10             Not closed: Public interest in remaining open
# 896          14                    Not closed: Alternate control measures
# 897           3                                                    Closed
# 898           5                                                    Closed
# 899           3                                                Not closed
# 900           5                                                Not closed
# 901           3  Not closed: insufficient evidence of recent transmission
#
#     closure_y_n closed_by_order voluntary_closure closure_date  \
# 887         Yes              No               Yes    4/28/2021
# 888          No              No           Unknown         None
# 889         Yes             Yes           Unknown     6/2/2021
# 890          No              No           Unknown         None
# 891         Yes             Yes           Unknown     6/3/2021
# 892         Yes              No               Yes     6/3/2021
# 893          No              No           Unknown         None
# 894          No              No           Unknown         None
# 895          No              No           Unknown         None
# 896          No              No           Unknown         None
# 897         Yes             Yes           Unknown     6/7/2021
# 898         Yes              No                No    6/18/2021
# 899          No              No                No         None
# 900          No              No                No         None
# 901          No              No           Unknown         None
#
#     partially_closed  unknown_closure_type open days_since_last_case  \
# 887          Unknown                   NaN   No                 None
# 888               No                   NaN  Yes                 None
# 889               No                   NaN   No                 None
# 890               No                   NaN  Yes                 None
# 891               No                   NaN   No                 None
# 892          Unknown                   NaN   No                 None
# 893               No                   NaN  Yes                 None
# 894               No                   NaN  Yes                 None
# 895               No                   NaN  Yes                 None
# 896               No                   NaN  Yes                 None
# 897               No                   NaN   No                 None
# 898          Unknown                   NaN   No                 None
# 899          Unknown                   NaN  Yes                 None
# 900          Unknown                   NaN  Yes                 None
# 901               No                   NaN  Yes                 None
#
#     active_clusters cluster_confirmed_epidate  doc_page_number  \
# 887              No                   22-2021               56
# 888              No                   22-2021               56
# 889              No                   22-2021               56
# 890              No                   22-2021               56
# 891              No                   22-2021               56
# 892              No                   22-2021               56
# 893              No                   22-2021               56
# 894              No                   22-2021               56
# 895              No                   22-2021               56
# 896              No                   22-2021               56
# 897              No                   22-2021               56
# 898              No                   22-2021               56
# 899              No                   22-2021               56
# 900              No                   23-2021               56
# 901              No                   23-2021               56
#
#     cluster_closed_epidate                        file  flag
# 887                17-2021  F22-1445 Records_Part2.pdf     1
# 888                   None  F22-1445 Records_Part2.pdf     1
# 889                22-2021  F22-1445 Records_Part2.pdf     1
# 890                   None  F22-1445 Records_Part2.pdf     1
# 891                22-2021  F22-1445 Records_Part2.pdf     1
# 892                22-2021  F22-1445 Records_Part2.pdf     1
# 893                   None  F22-1445 Records_Part2.pdf     1
# 894                   None  F22-1445 Records_Part2.pdf     1
# 895                   None  F22-1445 Records_Part2.pdf     1
# 896                   None  F22-1445 Records_Part2.pdf     1
# 897                23-2021  F22-1445 Records_Part2.pdf     1
# 898                24-2021  F22-1445 Records_Part2.pdf     1
# 899                   None  F22-1445 Records_Part2.pdf     1
# 900                   None  F22-1445 Records_Part2.pdf     1
# 901                   None  F22-1445 Records_Part2.pdf     1

# %% [markdown]
# ### Save output

# %%
save_output(
    fixed_df_dict, description='fixed_df_dict', pickle_path=pickle_path, csv_path=None)
# Out:
# File saved:  C:/Users/silvh/OneDrive/lighthouse/portfolio-projects/BC-Covid-workplace-closures/data/interim/fixed_df_dict_2023-04-25_1953.sav
# Time completed: 2023-04-25 19:53:04.179283
# 	Object saved as pickle

# %% [markdown]
# # *End of Page*
