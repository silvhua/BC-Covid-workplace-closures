# %% [markdown]
# # Title
# []()

# %%
from pandas import json_normalize  
import pandas as pd
import sys
sys.path.append(r"C:\Users\silvh\OneDrive\lighthouse\custom_python")
sys.path.append(r"C:\Users\silvh\OneDrive\lighthouse\portfolio-projects\online-PT-social-media-NLP\src")
from silvhua import *
from datetime import datetime
# import json
# from plotly.subplots import make_subplots
# import requests

# %%
# set the option to wrap text within cells
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
filename = 'pdfs_parsed_2023-04-02.sav'
path = r'C:\Users\silvh\OneDrive\lighthouse\portfolio-projects\BC-Covid-workplace-closures\data\interim'
data = loadpickle(filename, path)
# Out:
# Time completed: 2023-04-22 15:07:11.601113
# Dataframe shape:  (13299, 26)
# DataFrame columns: ['index', 'HA', 'workplace_name', 'workplace_address', 'city', 'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active', 'earliest_reported_cases', 'latest_reported_cases', 'workplace_classification', 'cases_when_cluster_confirmed', 'total_cases', 'workplace_status', 'closure_y_n', 'closed_by_order', 'voluntary_closure', 'closure_date', 'partially_closed', 'unknown_closure_type', 'open', 'days_since_last_case', 'active_clusters', 'cluster_confirmed_epidate', 'doc_page_number', 'cluster_closed_epidate', 'file']

# %% [markdown]
# # Load dataframe from previous notebook

# %%
data
# Out:
#        index   HA workplace_name workplace_address             city  \
# 0      179.0  FHA            NaN              None       ABBOTSFORD
# 1      180.0  FHA            NaN              None            DELTA
# 2      181.0  FHA            NaN              None  PORT\rCOQUITLAM
# 3      182.0  VCH            NaN              None        Vancouver
# 4      183.0  NHA            NaN              None          Unknown
# ...      ...  ...            ...               ...              ...
# 13294  113.0  FHA           None              None           SURREY
# 13295  114.0  FHA           None              None           SURREY
# 13296  115.0  FHA           None              None           SURREY
# 13297  116.0  FHA           None              None           SURREY
# 13298  117.0  VCH           None              None        Vancouver
#
#       date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 0                                4/14/2021                      5/3/2021
# 1                                4/14/2021                      5/9/2021
# 2                                4/14/2021                      5/6/2021
# 3                                4/14/2021                           NaN
# 4                                4/14/2021                     4/29/2021
# ...                                    ...                           ...
# 13294                             4/9/2021                     4/26/2021
# 13295                             4/9/2021                     4/21/2021
# 13296                             4/9/2021                     4/23/2021
# 13297                             4/9/2021                     5/29/2021
# 13298                             4/9/2021                           NaN
#
#       earliest_reported_cases latest_reported_cases  \
# 0                         NaN                   NaN
# 1                         NaN                   NaN
# 2                         NaN                   NaN
# 3                   4/14/2021              5/5/2021
# 4                         NaN                   NaN
# ...                       ...                   ...
# 13294                     NaN                   NaN
# 13295                     NaN                   NaN
# 13296                     NaN                   NaN
# 13297                     NaN                   NaN
# 13298                4/9/2021             4/30/2021
#
#                   workplace_classification cases_when_cluster_confirmed  \
# 0                       Farm/Agricultu\rre                            3
# 1                                   Retail                           11
# 2      Maintenance/T\rrades/Construc\rtion                            5
# 3                 Manufacturing\r/Industry                          NaN
# 4      Maintenance/T\rrades/Construc\rtion                            3
# ...                                    ...                          ...
# 13294                               Retail                            4
# 13295                               Office                            4
# 13296                               Office                            6
# 13297                      Food Processing                           11
# 13298                                Other                          NaN
#
#       total_cases                                    workplace_status  \
# 0               3                                              Closed
# 1              11                                                 NaN
# 2               5                                              Closed
# 3               4  Partially\rclosed or\rwidespread\risolation by\rPH
# 4               4                                  Voluntary\rclosure
# ...           ...                                                 ...
# 13294           4                                                 NaN
# 13295           4                                                 NaN
# 13296           6                                          [1] Closed
# 13297          11                                                 NaN
# 13298           5                                     Not a\rworksite
#
#       closure_y_n closed_by_order voluntary_closure closure_date  \
# 0             Yes             Yes           Unknown    4/15/2021
# 1              No              No           Unknown          NaN
# 2             Yes             Yes           Unknown    4/14/2021
# 3             Yes              No                No          NaN
# 4             Yes              No               Yes          NaN
# ...           ...             ...               ...          ...
# 13294          No              No           Unknown          NaN
# 13295          No              No           Unknown          NaN
# 13296         Yes             Yes           Unknown    4/12/2021
# 13297          No              No           Unknown          NaN
# 13298          No              No                No          NaN
#
#       partially_closed unknown_closure_type open days_since_last_case  \
# 0                   No                  NaN   No                  NaN
# 1                   No                  NaN   No                  NaN
# 2                   No                  NaN   No                  NaN
# 3                  Yes                  NaN   No                  NaN
# 4              Unknown                  NaN   No                  NaN
# ...                ...                  ...  ...                  ...
# 13294               No                   No   No                  NaN
# 13295               No                   No   No                  NaN
# 13296               No                   No  Yes                  NaN
# 13297               No                   No   No                  NaN
# 13298               No                   No  Yes                  NaN
#
#       active_clusters cluster_confirmed_epidate  doc_page_number  \
# 0                  No                   15-2021                1
# 1                  No                   15-2021                1
# 2                  No                   15-2021                1
# 3                  No                   15-2021                1
# 4                  No                   15-2021                1
# ...               ...                       ...              ...
# 13294              No                   14-2021              143
# 13295              No                   14-2021              143
# 13296              No                   14-2021              143
# 13297              No                   14-2021              143
# 13298              No                   14-2021              143
#
#       cluster_closed_epidate                        file
# 0                        NaN  F22-1445 Records_Part2.pdf
# 1                        NaN  F22-1445 Records_Part2.pdf
# 2                        NaN  F22-1445 Records_Part2.pdf
# 3                        NaN  F22-1445 Records_Part2.pdf
# 4                        NaN  F22-1445 Records_Part2.pdf
# ...                      ...                         ...
# 13294                    NaN  F22-1445 Records_Part3.pdf
# 13295                    NaN  F22-1445 Records_Part3.pdf
# 13296                    NaN  F22-1445 Records_Part3.pdf
# 13297                    NaN  F22-1445 Records_Part3.pdf
# 13298                    NaN  F22-1445 Records_Part3.pdf
#
# [13299 rows x 26 columns]

# %% [markdown]
# # Filter

# %%
part_num = 1
page = 1
filter_column1 = 'file'
filter_column2 = 'doc_page_number'
filter = (data[filter_column1].str.contains(f'Part{part_num}')) & (data[filter_column2] == page)
firstpage = data[filter].copy()
firstpage
# Out:
#      index   HA workplace_name workplace_address         city  \
# 9094   1.0  FHA           None              None       SURREY
# 9095   2.0  FHA           None              None      LANGLEY
# 9096   3.0  FHA           None              None       SURREY
# 9097   4.0  FHA           None              None      BURNABY
# 9098   5.0  FHA           None              None      BURNABY
# 9099   6.0  FHA           None              None   CHILLIWACK
# 9100   7.0  FHA           None              None    COQUITLAM
# 9101   8.0  FHA           None              None        DELTA
# 9102   9.0  FHA           None              None      LANGLEY
# 9103  10.0  FHA           None              None      LANGLEY
# 9104  11.0  FHA           None              None  MAPLE RIDGE
# 9105  12.0  FHA           None              None      MISSION
# 9106  13.0  FHA           None              None       SURREY
# 9107  14.0  FHA           None              None       SURREY
# 9108  15.0  FHA           None              None       SURREY
# 9109  16.0  FHA           None              None   ABBOTSFORD
#
#      date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 9094                             4/1/2021                     4/17/2021
# 9095                             4/1/2021                     4/13/2021
# 9096                             4/1/2021                     4/13/2021
# 9097                             4/1/2021                     4/21/2021
# 9098                             4/1/2021                     4/14/2021
# 9099                             4/1/2021                     4/17/2021
# 9100                             4/1/2021                     4/14/2021
# 9101                             4/1/2021                      4/6/2021
# 9102                             4/1/2021                     4/30/2021
# 9103                             4/1/2021                           NaN
# 9104                             4/1/2021                     4/18/2021
# 9105                             4/1/2021                     4/19/2021
# 9106                             4/1/2021                     4/23/2021
# 9107                             4/1/2021                     4/14/2021
# 9108                             4/1/2021                     4/22/2021
# 9109                             4/2/2021                     4/19/2021
#
#      earliest_reported_cases latest_reported_cases  \
# 9094                     NaN                   NaN
# 9095                     NaN                   NaN
# 9096                     NaN                   NaN
# 9097                     NaN                   NaN
# 9098                     NaN                   NaN
# 9099                     NaN                   NaN
# 9100                     NaN                   NaN
# 9101                     NaN                   NaN
# 9102                     NaN                   NaN
# 9103                     NaN                   NaN
# 9104                     NaN                   NaN
# 9105                     NaN                   NaN
# 9106                     NaN                   NaN
# 9107                     NaN                   NaN
# 9108                     NaN                   NaN
# 9109                     NaN                   NaN
#
#                  workplace_classification cases_when_cluster_confirmed  \
# 9094              Restaurant/Bar/L\rounge                            3
# 9095                                Other                            8
# 9096              Restaurant/Bar/L\rounge                            4
# 9097                          Gym/Fitness                           12
# 9098              Restaurant/Bar/L\rounge                            5
# 9099  Maintenance/Tr\rades/Constructio\rn                            4
# 9100                               Office                            4
# 9101                       Transportation                            4
# 9102                     Farm/Agriculture                           50
# 9103                            Warehouse                           26
# 9104              Restaurant/Bar/L\rounge                           16
# 9105              Restaurant/Bar/L\rounge                            4
# 9106                          Gym/Fitness                            7
# 9107                               Office                            3
# 9108              Restaurant/Bar/L\rounge                            9
# 9109                          Gym/Fitness                           12
#
#      total_cases workplace_status closure_y_n closed_by_order  \
# 9094           3              NaN          No              No
# 9095           8              NaN          No              No
# 9096           4           Closed         Yes             Yes
# 9097          12           Closed         Yes             Yes
# 9098           5           Closed         Yes             Yes
# 9099           4              NaN          No              No
# 9100           4              NaN          No              No
# 9101           4              NaN          No              No
# 9102          50              NaN          No              No
# 9103          26              NaN          No              No
# 9104          16           Closed         Yes             Yes
# 9105           4           Closed         Yes             Yes
# 9106           7              NaN          No              No
# 9107           3           Closed         Yes             Yes
# 9108           9           Closed         Yes             Yes
# 9109          12           Closed         Yes             Yes
#
#      voluntary_closure closure_date partially_closed unknown_closure_type  \
# 9094           Unknown          NaN               No                  NaN
# 9095           Unknown          NaN               No                  NaN
# 9096           Unknown     4/4/2021               No                  NaN
# 9097           Unknown     4/7/2021               No                  NaN
# 9098           Unknown     4/5/2021               No                  NaN
# 9099           Unknown          NaN               No                  NaN
# 9100           Unknown          NaN               No                  NaN
# 9101           Unknown          NaN               No                  NaN
# 9102           Unknown          NaN               No                  NaN
# 9103           Unknown          NaN               No                  NaN
# 9104           Unknown     4/6/2021               No                  NaN
# 9105           Unknown     4/1/2021               No                  NaN
# 9106           Unknown          NaN               No                  NaN
# 9107           Unknown     4/3/2021               No                  NaN
# 9108           Unknown    4/12/2021               No                  NaN
# 9109           Unknown     4/3/2021               No                  NaN
#
#      open days_since_last_case active_clusters cluster_confirmed_epidate  \
# 9094   No                  NaN             NaN                   13-2021
# 9095   No                  NaN             NaN                   13-2021
# 9096   No                  NaN             NaN                   13-2021
# 9097   No                  NaN             NaN                   13-2021
# 9098   No                  NaN             NaN                   13-2021
# 9099   No                  NaN             NaN                   13-2021
# 9100   No                  NaN             NaN                   13-2021
# 9101   No                  NaN             NaN                   13-2021
# 9102   No                  NaN             NaN                   13-2021
# 9103   No                  NaN             NaN                   13-2021
# 9104   No                  NaN             NaN                   13-2021
# 9105   No                  NaN             NaN                   13-2021
# 9106   No                  NaN             NaN                   13-2021
# 9107   No                  NaN             NaN                   13-2021
# 9108   No                  NaN             NaN                   13-2021
# 9109   No                  NaN             NaN                   13-2021
#
#       doc_page_number cluster_closed_epidate                        file
# 9094                1                    NaN  F22-1445 Records_Part1.pdf
# 9095                1                    NaN  F22-1445 Records_Part1.pdf
# 9096                1                14-2021  F22-1445 Records_Part1.pdf
# 9097                1                14-2021  F22-1445 Records_Part1.pdf
# 9098                1                14-2021  F22-1445 Records_Part1.pdf
# 9099                1                    NaN  F22-1445 Records_Part1.pdf
# 9100                1                    NaN  F22-1445 Records_Part1.pdf
# 9101                1                    NaN  F22-1445 Records_Part1.pdf
# 9102                1                    NaN  F22-1445 Records_Part1.pdf
# 9103                1                    NaN  F22-1445 Records_Part1.pdf
# 9104                1                14-2021  F22-1445 Records_Part1.pdf
# 9105                1                13-2021  F22-1445 Records_Part1.pdf
# 9106                1                    NaN  F22-1445 Records_Part1.pdf
# 9107                1                13-2021  F22-1445 Records_Part1.pdf
# 9108                1                15-2021  F22-1445 Records_Part1.pdf
# 9109                1                13-2021  F22-1445 Records_Part1.pdf

# %%
firstpage.columns
# Out:
# Index(['index', 'HA', 'workplace_name', 'workplace_address', 'city',
#        'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active',
#        'earliest_reported_cases', 'latest_reported_cases',
#        'workplace_classification', 'cases_when_cluster_confirmed',
#        'total_cases', 'workplace_status', 'closure_y_n', 'closed_by_order',
#        'voluntary_closure', 'closure_date', 'partially_closed',
#        'unknown_closure_type', 'open', 'days_since_last_case',
#        'active_clusters', 'cluster_confirmed_epidate', 'doc_page_number',
#        'cluster_closed_epidate', 'file'],
#       dtype='object')

# %% [markdown]
# # Convert dates; flag if unable

# %%
firstpage.loc[ 9094, 'date_cluster_confirmed_public_health']
# Out:
# '4/1/2021'

# %%
pd.to_datetime(firstpage.loc[ 9094, 'date_cluster_confirmed_public_health'], format='%m/%d/%Y')
# Out:
# Timestamp('2021-04-01 00:00:00')

# %%
def convert_date_strings_to_datetime(df):
    # date_columns = [
    #     'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active',
    #     'earliest_reported_cases', 'latest_reported_cases', 'closure_date',
    #     'cluster_closed_epidate'
    # ]
    date_columns = ['date_cluster_confirmed_public_health']
    df2 = df.copy()
    df2['flag'] = 0
    try:
        # df2[date_columns] = df2[date_columns].apply(lambda x: pd.to_datetime(x, format='%m/%d/%Y'))
        df2[date_columns] = df2[date_columns].apply(pd.to_datetime, format='%m/%d/%Y')
    except:
        df2['flag'] = 1
    print(f'Rows with misaligned columns: {df2["flag"].sum()} out of {df2.shape[0]}')
    print(df2.dtypes)
    return df2

convert_date_strings_to_datetime(firstpage)
# Out:
# Rows with misaligned columns: 0 out of 16
# index                                           object
# HA                                              object
# workplace_name                                  object
# workplace_address                               object
# city                                            object
# date_cluster_confirmed_public_health    datetime64[ns]
# date_cluster_no_longer_active                   object
# earliest_reported_cases                         object
# latest_reported_cases                           object
# workplace_classification                        object
# cases_when_cluster_confirmed                    object
# total_cases                                     object
# workplace_status                                object
# closure_y_n                                     object
# closed_by_order                                 object
# voluntary_closure                               object
# closure_date                                    object
# partially_closed                                object
# unknown_closure_type                            object
# open                                            object
# days_since_last_case                            object
# active_clusters                                 object
# cluster_confirmed_epidate                       object
# doc_page_number                                  int64
# cluster_closed_epidate                          object
# file                                            object
# flag                                             int64
# dtype: object
#      index   HA workplace_name workplace_address         city  \
# 9094   1.0  FHA           None              None       SURREY
# 9095   2.0  FHA           None              None      LANGLEY
# 9096   3.0  FHA           None              None       SURREY
# 9097   4.0  FHA           None              None      BURNABY
# 9098   5.0  FHA           None              None      BURNABY
# 9099   6.0  FHA           None              None   CHILLIWACK
# 9100   7.0  FHA           None              None    COQUITLAM
# 9101   8.0  FHA           None              None        DELTA
# 9102   9.0  FHA           None              None      LANGLEY
# 9103  10.0  FHA           None              None      LANGLEY
# 9104  11.0  FHA           None              None  MAPLE RIDGE
# 9105  12.0  FHA           None              None      MISSION
# 9106  13.0  FHA           None              None       SURREY
# 9107  14.0  FHA           None              None       SURREY
# 9108  15.0  FHA           None              None       SURREY
# 9109  16.0  FHA           None              None   ABBOTSFORD
#
#      date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 9094                           2021-04-01                     4/17/2021
# 9095                           2021-04-01                     4/13/2021
# 9096                           2021-04-01                     4/13/2021
# 9097                           2021-04-01                     4/21/2021
# 9098                           2021-04-01                     4/14/2021
# 9099                           2021-04-01                     4/17/2021
# 9100                           2021-04-01                     4/14/2021
# 9101                           2021-04-01                      4/6/2021
# 9102                           2021-04-01                     4/30/2021
# 9103                           2021-04-01                           NaN
# 9104                           2021-04-01                     4/18/2021
# 9105                           2021-04-01                     4/19/2021
# 9106                           2021-04-01                     4/23/2021
# 9107                           2021-04-01                     4/14/2021
# 9108                           2021-04-01                     4/22/2021
# 9109                           2021-04-02                     4/19/2021
#
#      earliest_reported_cases latest_reported_cases  \
# 9094                     NaN                   NaN
# 9095                     NaN                   NaN
# 9096                     NaN                   NaN
# 9097                     NaN                   NaN
# 9098                     NaN                   NaN
# 9099                     NaN                   NaN
# 9100                     NaN                   NaN
# 9101                     NaN                   NaN
# 9102                     NaN                   NaN
# 9103                     NaN                   NaN
# 9104                     NaN                   NaN
# 9105                     NaN                   NaN
# 9106                     NaN                   NaN
# 9107                     NaN                   NaN
# 9108                     NaN                   NaN
# 9109                     NaN                   NaN
#
#                  workplace_classification cases_when_cluster_confirmed  \
# 9094              Restaurant/Bar/L\rounge                            3
# 9095                                Other                            8
# 9096              Restaurant/Bar/L\rounge                            4
# 9097                          Gym/Fitness                           12
# 9098              Restaurant/Bar/L\rounge                            5
# 9099  Maintenance/Tr\rades/Constructio\rn                            4
# 9100                               Office                            4
# 9101                       Transportation                            4
# 9102                     Farm/Agriculture                           50
# 9103                            Warehouse                           26
# 9104              Restaurant/Bar/L\rounge                           16
# 9105              Restaurant/Bar/L\rounge                            4
# 9106                          Gym/Fitness                            7
# 9107                               Office                            3
# 9108              Restaurant/Bar/L\rounge                            9
# 9109                          Gym/Fitness                           12
#
#      total_cases workplace_status closure_y_n closed_by_order  \
# 9094           3              NaN          No              No
# 9095           8              NaN          No              No
# 9096           4           Closed         Yes             Yes
# 9097          12           Closed         Yes             Yes
# 9098           5           Closed         Yes             Yes
# 9099           4              NaN          No              No
# 9100           4              NaN          No              No
# 9101           4              NaN          No              No
# 9102          50              NaN          No              No
# 9103          26              NaN          No              No
# 9104          16           Closed         Yes             Yes
# 9105           4           Closed         Yes             Yes
# 9106           7              NaN          No              No
# 9107           3           Closed         Yes             Yes
# 9108           9           Closed         Yes             Yes
# 9109          12           Closed         Yes             Yes
#
#      voluntary_closure closure_date partially_closed unknown_closure_type  \
# 9094           Unknown          NaN               No                  NaN
# 9095           Unknown          NaN               No                  NaN
# 9096           Unknown     4/4/2021               No                  NaN
# 9097           Unknown     4/7/2021               No                  NaN
# 9098           Unknown     4/5/2021               No                  NaN
# 9099           Unknown          NaN               No                  NaN
# 9100           Unknown          NaN               No                  NaN
# 9101           Unknown          NaN               No                  NaN
# 9102           Unknown          NaN               No                  NaN
# 9103           Unknown          NaN               No                  NaN
# 9104           Unknown     4/6/2021               No                  NaN
# 9105           Unknown     4/1/2021               No                  NaN
# 9106           Unknown          NaN               No                  NaN
# 9107           Unknown     4/3/2021               No                  NaN
# 9108           Unknown    4/12/2021               No                  NaN
# 9109           Unknown     4/3/2021               No                  NaN
#
#      open days_since_last_case active_clusters cluster_confirmed_epidate  \
# 9094   No                  NaN             NaN                   13-2021
# 9095   No                  NaN             NaN                   13-2021
# 9096   No                  NaN             NaN                   13-2021
# 9097   No                  NaN             NaN                   13-2021
# 9098   No                  NaN             NaN                   13-2021
# 9099   No                  NaN             NaN                   13-2021
# 9100   No                  NaN             NaN                   13-2021
# 9101   No                  NaN             NaN                   13-2021
# 9102   No                  NaN             NaN                   13-2021
# 9103   No                  NaN             NaN                   13-2021
# 9104   No                  NaN             NaN                   13-2021
# 9105   No                  NaN             NaN                   13-2021
# 9106   No                  NaN             NaN                   13-2021
# 9107   No                  NaN             NaN                   13-2021
# 9108   No                  NaN             NaN                   13-2021
# 9109   No                  NaN             NaN                   13-2021
#
#       doc_page_number cluster_closed_epidate                        file  flag
# 9094                1                    NaN  F22-1445 Records_Part1.pdf     0
# 9095                1                    NaN  F22-1445 Records_Part1.pdf     0
# 9096                1                14-2021  F22-1445 Records_Part1.pdf     0
# 9097                1                14-2021  F22-1445 Records_Part1.pdf     0
# 9098                1                14-2021  F22-1445 Records_Part1.pdf     0
# 9099                1                    NaN  F22-1445 Records_Part1.pdf     0
# 9100                1                    NaN  F22-1445 Records_Part1.pdf     0
# 9101                1                    NaN  F22-1445 Records_Part1.pdf     0
# 9102                1                    NaN  F22-1445 Records_Part1.pdf     0
# 9103                1                    NaN  F22-1445 Records_Part1.pdf     0
# 9104                1                14-2021  F22-1445 Records_Part1.pdf     0
# 9105                1                13-2021  F22-1445 Records_Part1.pdf     0
# 9106                1                    NaN  F22-1445 Records_Part1.pdf     0
# 9107                1                13-2021  F22-1445 Records_Part1.pdf     0
# 9108                1                15-2021  F22-1445 Records_Part1.pdf     0
# 9109                1                13-2021  F22-1445 Records_Part1.pdf     0

# %% [markdown]
# ## Iteration 1.1

# %%
def convert_date_strings_to_datetime(df):
    date_columns = [
        'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active',
        'earliest_reported_cases', 'latest_reported_cases', 
        'closure_date',
        # 'cluster_closed_epidate'
    ]
    df2 = df.copy()
    df2['flag'] = ''
    for col in date_columns:
        try:
            df2[col] = pd.to_datetime(df2[col], format='%m/%d/%Y')
        except:
            df2.loc[df2[col].apply(lambda x: isinstance(x, str)), 'flag'] = col
            print('\tProblem with column: ', col)
            continue
    print(f'Rows with misaligned columns: {df2[df2["flag"] != ""]["flag"].count()} out of {df2.shape[0]}')
    print(df2[date_columns].dtypes)
    return df2

convert_date_strings_to_datetime(firstpage)
# Out:
# Rows with misaligned columns: 0 out of 16
# date_cluster_confirmed_public_health    datetime64[ns]
# date_cluster_no_longer_active           datetime64[ns]
# earliest_reported_cases                 datetime64[ns]
# latest_reported_cases                   datetime64[ns]
# closure_date                            datetime64[ns]
# dtype: object
#      index   HA workplace_name workplace_address         city  \
# 9094   1.0  FHA           None              None       SURREY
# 9095   2.0  FHA           None              None      LANGLEY
# 9096   3.0  FHA           None              None       SURREY
# 9097   4.0  FHA           None              None      BURNABY
# 9098   5.0  FHA           None              None      BURNABY
# 9099   6.0  FHA           None              None   CHILLIWACK
# 9100   7.0  FHA           None              None    COQUITLAM
# 9101   8.0  FHA           None              None        DELTA
# 9102   9.0  FHA           None              None      LANGLEY
# 9103  10.0  FHA           None              None      LANGLEY
# 9104  11.0  FHA           None              None  MAPLE RIDGE
# 9105  12.0  FHA           None              None      MISSION
# 9106  13.0  FHA           None              None       SURREY
# 9107  14.0  FHA           None              None       SURREY
# 9108  15.0  FHA           None              None       SURREY
# 9109  16.0  FHA           None              None   ABBOTSFORD
#
#      date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 9094                           2021-04-01                    2021-04-17
# 9095                           2021-04-01                    2021-04-13
# 9096                           2021-04-01                    2021-04-13
# 9097                           2021-04-01                    2021-04-21
# 9098                           2021-04-01                    2021-04-14
# 9099                           2021-04-01                    2021-04-17
# 9100                           2021-04-01                    2021-04-14
# 9101                           2021-04-01                    2021-04-06
# 9102                           2021-04-01                    2021-04-30
# 9103                           2021-04-01                           NaT
# 9104                           2021-04-01                    2021-04-18
# 9105                           2021-04-01                    2021-04-19
# 9106                           2021-04-01                    2021-04-23
# 9107                           2021-04-01                    2021-04-14
# 9108                           2021-04-01                    2021-04-22
# 9109                           2021-04-02                    2021-04-19
#
#      earliest_reported_cases latest_reported_cases  \
# 9094                     NaT                   NaT
# 9095                     NaT                   NaT
# 9096                     NaT                   NaT
# 9097                     NaT                   NaT
# 9098                     NaT                   NaT
# 9099                     NaT                   NaT
# 9100                     NaT                   NaT
# 9101                     NaT                   NaT
# 9102                     NaT                   NaT
# 9103                     NaT                   NaT
# 9104                     NaT                   NaT
# 9105                     NaT                   NaT
# 9106                     NaT                   NaT
# 9107                     NaT                   NaT
# 9108                     NaT                   NaT
# 9109                     NaT                   NaT
#
#                  workplace_classification cases_when_cluster_confirmed  \
# 9094              Restaurant/Bar/L\rounge                            3
# 9095                                Other                            8
# 9096              Restaurant/Bar/L\rounge                            4
# 9097                          Gym/Fitness                           12
# 9098              Restaurant/Bar/L\rounge                            5
# 9099  Maintenance/Tr\rades/Constructio\rn                            4
# 9100                               Office                            4
# 9101                       Transportation                            4
# 9102                     Farm/Agriculture                           50
# 9103                            Warehouse                           26
# 9104              Restaurant/Bar/L\rounge                           16
# 9105              Restaurant/Bar/L\rounge                            4
# 9106                          Gym/Fitness                            7
# 9107                               Office                            3
# 9108              Restaurant/Bar/L\rounge                            9
# 9109                          Gym/Fitness                           12
#
#      total_cases workplace_status closure_y_n closed_by_order  \
# 9094           3              NaN          No              No
# 9095           8              NaN          No              No
# 9096           4           Closed         Yes             Yes
# 9097          12           Closed         Yes             Yes
# 9098           5           Closed         Yes             Yes
# 9099           4              NaN          No              No
# 9100           4              NaN          No              No
# 9101           4              NaN          No              No
# 9102          50              NaN          No              No
# 9103          26              NaN          No              No
# 9104          16           Closed         Yes             Yes
# 9105           4           Closed         Yes             Yes
# 9106           7              NaN          No              No
# 9107           3           Closed         Yes             Yes
# 9108           9           Closed         Yes             Yes
# 9109          12           Closed         Yes             Yes
#
#      voluntary_closure closure_date partially_closed unknown_closure_type  \
# 9094           Unknown          NaT               No                  NaN
# 9095           Unknown          NaT               No                  NaN
# 9096           Unknown   2021-04-04               No                  NaN
# 9097           Unknown   2021-04-07               No                  NaN
# 9098           Unknown   2021-04-05               No                  NaN
# 9099           Unknown          NaT               No                  NaN
# 9100           Unknown          NaT               No                  NaN
# 9101           Unknown          NaT               No                  NaN
# 9102           Unknown          NaT               No                  NaN
# 9103           Unknown          NaT               No                  NaN
# 9104           Unknown   2021-04-06               No                  NaN
# 9105           Unknown   2021-04-01               No                  NaN
# 9106           Unknown          NaT               No                  NaN
# 9107           Unknown   2021-04-03               No                  NaN
# 9108           Unknown   2021-04-12               No                  NaN
# 9109           Unknown   2021-04-03               No                  NaN
#
#      open days_since_last_case active_clusters cluster_confirmed_epidate  \
# 9094   No                  NaN             NaN                   13-2021
# 9095   No                  NaN             NaN                   13-2021
# 9096   No                  NaN             NaN                   13-2021
# 9097   No                  NaN             NaN                   13-2021
# 9098   No                  NaN             NaN                   13-2021
# 9099   No                  NaN             NaN                   13-2021
# 9100   No                  NaN             NaN                   13-2021
# 9101   No                  NaN             NaN                   13-2021
# 9102   No                  NaN             NaN                   13-2021
# 9103   No                  NaN             NaN                   13-2021
# 9104   No                  NaN             NaN                   13-2021
# 9105   No                  NaN             NaN                   13-2021
# 9106   No                  NaN             NaN                   13-2021
# 9107   No                  NaN             NaN                   13-2021
# 9108   No                  NaN             NaN                   13-2021
# 9109   No                  NaN             NaN                   13-2021
#
#       doc_page_number cluster_closed_epidate                        file flag
# 9094                1                    NaN  F22-1445 Records_Part1.pdf
# 9095                1                    NaN  F22-1445 Records_Part1.pdf
# 9096                1                14-2021  F22-1445 Records_Part1.pdf
# 9097                1                14-2021  F22-1445 Records_Part1.pdf
# 9098                1                14-2021  F22-1445 Records_Part1.pdf
# 9099                1                    NaN  F22-1445 Records_Part1.pdf
# 9100                1                    NaN  F22-1445 Records_Part1.pdf
# 9101                1                    NaN  F22-1445 Records_Part1.pdf
# 9102                1                    NaN  F22-1445 Records_Part1.pdf
# 9103                1                    NaN  F22-1445 Records_Part1.pdf
# 9104                1                14-2021  F22-1445 Records_Part1.pdf
# 9105                1                13-2021  F22-1445 Records_Part1.pdf
# 9106                1                    NaN  F22-1445 Records_Part1.pdf
# 9107                1                13-2021  F22-1445 Records_Part1.pdf
# 9108                1                15-2021  F22-1445 Records_Part1.pdf
# 9109                1                13-2021  F22-1445 Records_Part1.pdf

# %% [markdown]
# ## Iteration 1.2 convert_date_string_to_dataframe for entire dataframe

# %%
import traceback
def convert_date_string_to_datetime(df):
    date_columns = [
        'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active',
        'earliest_reported_cases', 'latest_reported_cases', 
        'closure_date',
        # 'cluster_closed_epidate'
    ]
    try:
        df[date_columns] = df[date_columns].apply(pd.to_datetime, format='%m/%d/%Y')
    except Exception as error:
        exc_type, exc_obj, tb = sys.exc_info()
        f = tb.tb_frame
        lineno = tb.tb_lineno
        filename = f.f_code.co_filename
        df['flag'] = 1
        # problem_rows['file'] = df['file']
        # problem_rows['doc_page_number'] = df['doc_page_number']
        print(f'\tProblem with {df["file"]} page {df["doc_page_number"]} (row {df.name}: {error})')
    return df
    # return df, problem_rows


def process_df(
        df, description='pdfs_parsed_2023-04-02', save=False, 
        csv_path=None,
        pickle_path=r'C:\Users\silvh\OneDrive\lighthouse\portfolio-projects\BC-Covid-workplace-closures\data\interim'
        ):
    date_columns = [
        'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active',
        'earliest_reported_cases', 'latest_reported_cases', 
        'closure_date',
        # 'cluster_closed_epidate'
    ]
    df2 = df.copy()
    df2['flag'] = ''
    problem_rows = pd.DataFrame()
    df2 = df2.transpose().apply(lambda x: convert_date_string_to_datetime(x)).transpose()
    problem_rows = df2[df2['flag'] == 1]
    df2 = df2[df2['flag'] != 1]
    problem_pages = problem_rows[['file', 'doc_page_number']].drop_duplicates()
    print(f'Rows with misaligned columns: {df2[df2["flag"] != ""]["flag"].count()} out of {df2.shape[0]}')
    if save:
        try:
            save_output(
                df2, description=description+'_okay_rows', pickle_path=pickle_path, csv_path=csv_path)
            save_output(
                problem_rows, description=description+'_bad_rows', pickle_path=pickle_path, csv_path=csv_path)
            save_output(
                problem_pages, description=description+'_problem_pages', pickle_path=pickle_path, csv_path=csv_path)
        except:
            print('Unable to save outputs')
    return df2, problem_rows, problem_pages

df, problem_rows, problem_pages = process_df(data, save=True)
problem_rows
# Out:
# 	Problem with F22-1445 Records_Part2.pdf page 10 (row 175: time data '#########' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 19 (row 318: time data '#########' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 42 (row 689: time data 'Other' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 42 (row 690: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 42 (row 691: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 42 (row 692: time data 'Office' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 42 (row 693: time data 'ture' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 42 (row 694: time data 'Processing' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 42 (row 695: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 42 (row 696: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 42 (row 697: time data 'Bar/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 42 (row 698: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 42 (row 699: time data 'Warehouse' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 42 (row 700: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part2.pdf page 42 (row 701: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 44 (row 717: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 44 (row 718: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 44 (row 719: time data 'Warehouse' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 44 (row 720: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 44 (row 721: time data 'ture' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 44 (row 722: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 44 (row 723: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part2.pdf page 44 (row 724: unconverted data remains:  nstruction)
# 	Problem with F22-1445 Records_Part2.pdf page 44 (row 725: time data 'ture' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 44 (row 726: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 44 (row 727: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 44 (row 728: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 45 (row 729: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 45 (row 730: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 45 (row 731: unconverted data remains:  Gym/Fitness)
# 	Problem with F22-1445 Records_Part2.pdf page 45 (row 732: time data 'Care' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 45 (row 733: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 45 (row 734: time data 'Bar/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 45 (row 735: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 45 (row 736: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 45 (row 737: time data 'Warehouse' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 45 (row 738: time data 'Care' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 45 (row 739: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 45 (row 740: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 48 (row 768: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 48 (row 769: unconverted data remains:  Office)
# 	Problem with F22-1445 Records_Part2.pdf page 48 (row 770: time data 'Care' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 48 (row 771: time data 'Responder' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 48 (row 772: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 48 (row 773: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 48 (row 774: time data 'Office' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 48 (row 775: unconverted data remains:  ture)
# 	Problem with F22-1445 Records_Part2.pdf page 48 (row 776: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 48 (row 777: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 48 (row 778: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 48 (row 779: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 48 (row 780: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 48 (row 781: time data 'Warehouse' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 48 (row 782: time data '(Acute/LTC)' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 50 (row 801: time data 'Processing' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 50 (row 802: time data 'Processing' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 50 (row 803: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 50 (row 804: unconverted data remains:  Housing)
# 	Problem with F22-1445 Records_Part2.pdf page 50 (row 805: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part2.pdf page 50 (row 806: time data 'Gym/Fitness' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 50 (row 807: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 50 (row 808: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 50 (row 809: time data 'Office' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 50 (row 810: time data 'ture' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 50 (row 811: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 50 (row 812: time data 'Warehouse' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 51 (row 813: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 51 (row 814: time data 'Office' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 51 (row 815: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 51 (row 816: time data 'Gym/Fitness' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 51 (row 817: time data 'Gym/Fitness' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 51 (row 818: time data 'Gym/Fitness' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 51 (row 819: time data 'Gym/Fitness' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 51 (row 820: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part2.pdf page 51 (row 821: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 51 (row 822: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 51 (row 823: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 51 (row 824: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 51 (row 825: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 54 (row 854: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 54 (row 855: unconverted data remains:  on)
# 	Problem with F22-1445 Records_Part2.pdf page 54 (row 856: unconverted data remains:  Retail)
# 	Problem with F22-1445 Records_Part2.pdf page 54 (row 857: unconverted data remains:  nstruction)
# 	Problem with F22-1445 Records_Part2.pdf page 54 (row 858: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 54 (row 859: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 54 (row 860: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 54 (row 861: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 54 (row 862: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 54 (row 863: unconverted data remains:  (Acute/LTC))
# 	Problem with F22-1445 Records_Part2.pdf page 54 (row 864: unconverted data remains:  nstruction)
# 	Problem with F22-1445 Records_Part2.pdf page 54 (row 865: unconverted data remains:  Bar/Lounge)
# 	Problem with F22-1445 Records_Part2.pdf page 54 (row 866: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 54 (row 867: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 54 (row 868: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 54 (row 869: unconverted data remains:  on)
# 	Problem with F22-1445 Records_Part2.pdf page 55 (row 870: time data 'Office' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 55 (row 871: time data 'Bar/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 55 (row 872: time data 'Other' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 55 (row 873: unconverted data remains:  Retail)
# 	Problem with F22-1445 Records_Part2.pdf page 55 (row 874: unconverted data remains:  Bar/Lounge)
# 	Problem with F22-1445 Records_Part2.pdf page 55 (row 875: unconverted data remains:  Bar/Lounge)
# 	Problem with F22-1445 Records_Part2.pdf page 55 (row 876: unconverted data remains:  Bar/Lounge)
# 	Problem with F22-1445 Records_Part2.pdf page 55 (row 877: time data 'ture' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 55 (row 878: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 55 (row 879: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 55 (row 880: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 55 (row 881: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 55 (row 882: unconverted data remains:  Care)
# 	Problem with F22-1445 Records_Part2.pdf page 55 (row 883: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 55 (row 884: time data 'Bar/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 55 (row 885: unconverted data remains:  nstruction)
# 	Problem with F22-1445 Records_Part2.pdf page 55 (row 886: unconverted data remains:  Retail)
# 	Problem with F22-1445 Records_Part2.pdf page 56 (row 887: unconverted data remains:  ng/Industry)
# 	Problem with F22-1445 Records_Part2.pdf page 56 (row 888: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 56 (row 889: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 56 (row 890: time data 'Gym/Fitness' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 56 (row 891: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 56 (row 892: unconverted data remains:  Bar/Lounge)
# 	Problem with F22-1445 Records_Part2.pdf page 56 (row 893: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 56 (row 894: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 56 (row 895: time data 'Processing' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 56 (row 896: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 56 (row 897: time data 'Other' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 56 (row 898: unconverted data remains:  Bar/Lounge)
# 	Problem with F22-1445 Records_Part2.pdf page 56 (row 899: unconverted data remains:  Retail)
# 	Problem with F22-1445 Records_Part2.pdf page 56 (row 900: unconverted data remains:  nstruction)
# 	Problem with F22-1445 Records_Part2.pdf page 56 (row 901: time data 'Gym/Fitness' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 58 (row 919: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part2.pdf page 58 (row 920: unconverted data remains:  Office)
# 	Problem with F22-1445 Records_Part2.pdf page 58 (row 921: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 58 (row 922: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 58 (row 923: unconverted data remains:  ng/Industry)
# 	Problem with F22-1445 Records_Part2.pdf page 58 (row 924: unconverted data remains:  ng/Industry)
# 	Problem with F22-1445 Records_Part2.pdf page 58 (row 925: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 89 (row 1278: time data '########' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 102 (row 1421: time data '########' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 125 (row 1760: unconverted data remains:  on)
# 	Problem with F22-1445 Records_Part2.pdf page 125 (row 1761: time data 'Gym/Fitness' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 125 (row 1762: time data 'Warehouse' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 125 (row 1763: unconverted data remains:  /Lounge)
# 	Problem with F22-1445 Records_Part2.pdf page 125 (row 1764: unconverted data remains:  Office)
# 	Problem with F22-1445 Records_Part2.pdf page 125 (row 1765: unconverted data remains:  School/Daycare)
# 	Problem with F22-1445 Records_Part2.pdf page 125 (row 1766: time data '/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 125 (row 1767: time data 'e' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 125 (row 1768: time data 'Office' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 125 (row 1769: time data 'Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 125 (row 1770: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 125 (row 1771: time data 'Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 125 (row 1772: time data 'Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 125 (row 1773: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 125 (row 1774: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 130 (row 1832: unconverted data remains:  on)
# 	Problem with F22-1445 Records_Part2.pdf page 130 (row 1833: time data 'e' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 130 (row 1834: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 130 (row 1835: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 130 (row 1836: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 130 (row 1837: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 130 (row 1838: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 130 (row 1839: unconverted data remains:  Gym/Fitness)
# 	Problem with F22-1445 Records_Part2.pdf page 130 (row 1840: time data 'Personal Care' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 130 (row 1841: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 130 (row 1842: time data '/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 134 (row 1885: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 134 (row 1886: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 134 (row 1887: time data 'Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 134 (row 1888: time data 'Transportation' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 134 (row 1889: time data 'Warehouse' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 134 (row 1890: time data '(Acute/LTC)' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 134 (row 1891: time data 'Food Processing' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 134 (row 1892: time data '/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 134 (row 1893: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part2.pdf page 134 (row 1894: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part2.pdf page 134 (row 1895: unconverted data remains:  /Lounge)
# 	Problem with F22-1445 Records_Part2.pdf page 134 (row 1896: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part2.pdf page 134 (row 1897: unconverted data remains:  Office)
# 	Problem with F22-1445 Records_Part2.pdf page 134 (row 1898: time data 'ices' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 137 (row 1926: time data 'Gym/Fitness' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 137 (row 1927: time data 'Gym/Fitness' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 137 (row 1928: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part2.pdf page 137 (row 1929: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 137 (row 1930: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 137 (row 1931: time data 'Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 137 (row 1932: time data 'Transportation' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 137 (row 1933: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 137 (row 1934: time data 'Transportation' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 137 (row 1935: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 137 (row 1936: time data 'Office' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 137 (row 1937: time data 'Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 138 (row 1938: time data 'Transportation' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 138 (row 1939: time data 'Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 138 (row 1940: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 138 (row 1941: time data 'Housing' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 138 (row 1942: time data '/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 138 (row 1943: unconverted data remains:  on)
# 	Problem with F22-1445 Records_Part2.pdf page 138 (row 1944: time data 'Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 138 (row 1945: time data 'Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 138 (row 1946: time data 'Other' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 138 (row 1947: time data 'Office' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 138 (row 1948: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 138 (row 1949: time data 'Personal Care' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 138 (row 1950: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part2.pdf page 140 (row 1976: time data '########' does not match format '%m/%d/%Y' (match))
# 5L7;ABBTOSFORD' does not match format '%m/%d/%Y' (match))3: time data '32560 SIMON AVE,
# 	Problem with F22-1445 Records_Part4.pdf page 60 (row 2954: time data '.22(1)' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part4.pdf page 60 (row 2955: time data 'Victoria' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part4.pdf page 60 (row 2956: time data 'Langford' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part4.pdf page 60 (row 2957: time data 'Vancouver' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part4.pdf page 60 (row 2958: time data 'Unknown' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part4.pdf page 60 (row 2959: time data 'LANGLEY' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part4.pdf page 60 (row 2960: time data 'DELTA' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part4.pdf page 60 (row 2961: time data 'ABBOTSFORD' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part4.pdf page 60 (row 2962: time data 'SURREY' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part4.pdf page 60 (row 2963: time data 'LANGLEY' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part4.pdf page 60 (row 2964: time data 'BURNABY' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part4.pdf page 60 (row 2965: time data 'SURREY' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part4.pdf page 60 (row 2966: time data 'CHILLIWACK' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part4.pdf page 60 (row 2967: time data 'ABBOTSFORD' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part4.pdf page 60 (row 2968: time data 'Victoria' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 3 (row 6065: time data 'g/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 3 (row 6066: time data 'g/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 3 (row 6067: time data 'Office' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 3 (row 6068: time data 'Office' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 3 (row 6069: time data 'Other' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 3 (row 6070: time data 'Processing' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 3 (row 6071: time data 'Warehouse' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 3 (row 6072: time data 'Other' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 3 (row 6073: time data 'r/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 3 (row 6074: time data 'r/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 3 (row 6075: time data 'g/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 3 (row 6076: time data 'Office' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 3 (row 6077: time data 'r/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 3 (row 6078: time data 'Office' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 28 (row 6387: time data 'rvices' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 28 (row 6388: time data 'r/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 28 (row 6389: time data 'Personal Care' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 28 (row 6390: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 28 (row 6391: time data 'Personal Care' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 28 (row 6392: time data 'r/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 28 (row 6393: time data 'n' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 28 (row 6394: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 28 (row 6395: time data 'g/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 28 (row 6396: time data 'g/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 28 (row 6397: time data 'Processing' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 49 (row 6667: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 49 (row 6668: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 49 (row 6669: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 49 (row 6670: time data 'Unknown' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 49 (row 6671: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 49 (row 6672: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 49 (row 6673: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 49 (row 6674: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 49 (row 6675: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 49 (row 6676: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 49 (row 6677: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 49 (row 6678: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 49 (row 6679: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 49 (row 6680: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 49 (row 6681: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 49 (row 6682: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 49 (row 6683: time data 'Unknown' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 49 (row 6684: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 49 (row 6685: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 58 (row 6814: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 58 (row 6815: time data 'Unknown' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 58 (row 6816: time data 'Unknown' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 58 (row 6817: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 58 (row 6818: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 58 (row 6819: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 58 (row 6820: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 58 (row 6821: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 58 (row 6822: time data 'Unknown' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 58 (row 6823: time data 'Unknown' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 58 (row 6824: time data 'Unknown' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 58 (row 6825: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 58 (row 6826: time data 'Unknown' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 58 (row 6827: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 58 (row 6828: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part6.pdf page 58 (row 6829: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part1.pdf page 21 (row 9415: time data '#########' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part1.pdf page 30 (row 9548: time data '#########' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part1.pdf page 51 (row 9869: time data '#########' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part1.pdf page 59 (row 10013: time data '#########' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part1.pdf page 76 (row 10359: time data '###########' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part1.pdf page 83 (row 10498: time data '###########' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part1.pdf page 103 (row 10894: time data '#########' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part1.pdf page 115 (row 11037: time data '#########' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 2 (row 11281: unconverted data remains:  Processing)
# 	Problem with F22-1445 Records_Part3.pdf page 2 (row 11282: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 2 (row 11283: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 2 (row 11284: time data 'Responder' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 2 (row 11285: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 2 (row 11286: time data 'lture' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 2 (row 11287: time data 'Office' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 2 (row 11288: time data 'Other' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 2 (row 11289: time data 'Processing' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 2 (row 11290: unconverted data remains:  Gym/Fitness)
# 	Problem with F22-1445 Records_Part3.pdf page 2 (row 11291: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part3.pdf page 2 (row 11292: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part3.pdf page 2 (row 11293: time data 'Gym/Fitness' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 2 (row 11294: time data 'lture' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 2 (row 11295: time data 'Office' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 2 (row 11296: time data 'Bar/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 17 (row 11507: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 17 (row 11508: unconverted data remains:  Office)
# 	Problem with F22-1445 Records_Part3.pdf page 17 (row 11509: unconverted data remains:  Processing)
# 	Problem with F22-1445 Records_Part3.pdf page 17 (row 11510: time data 'Bar/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 17 (row 11511: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 17 (row 11512: time data 'Responder' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 17 (row 11513: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 17 (row 11514: time data 'lture' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 17 (row 11515: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 17 (row 11516: unconverted data remains:  Office)
# 	Problem with F22-1445 Records_Part3.pdf page 17 (row 11517: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part3.pdf page 17 (row 11518: unconverted data remains:  ervices)
# 	Problem with F22-1445 Records_Part3.pdf page 17 (row 11519: unconverted data remains:  Retail)
# 	Problem with F22-1445 Records_Part3.pdf page 17 (row 11520: time data 'Gym/Fitness' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 17 (row 11521: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 20 (row 11553: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 20 (row 11554: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 20 (row 11555: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 20 (row 11556: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 20 (row 11557: time data 'Office' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 20 (row 11558: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 20 (row 11559: time data 'lture' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 20 (row 11560: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 20 (row 11561: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 20 (row 11562: unconverted data remains:  Office)
# 	Problem with F22-1445 Records_Part3.pdf page 20 (row 11563: unconverted data remains:  Retail)
# 	Problem with F22-1445 Records_Part3.pdf page 20 (row 11564: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 20 (row 11565: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 23 (row 11590: time data 'Bar/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 23 (row 11591: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 23 (row 11592: time data 'Processing' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 23 (row 11593: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 23 (row 11594: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part3.pdf page 23 (row 11595: time data 'Office' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 23 (row 11596: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 23 (row 11597: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 23 (row 11598: time data 'Bar/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 23 (row 11599: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part3.pdf page 23 (row 11600: unconverted data remains:  Office)
# 	Problem with F22-1445 Records_Part3.pdf page 25 (row 11612: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 25 (row 11613: time data 'lture' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 25 (row 11614: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 25 (row 11615: time data 'Warehouse' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 25 (row 11616: time data 'lture' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 25 (row 11617: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part3.pdf page 25 (row 11618: unconverted data remains:  nstruction)
# 	Problem with F22-1445 Records_Part3.pdf page 25 (row 11619: time data 'lture' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 25 (row 11620: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 25 (row 11621: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 26 (row 11622: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 26 (row 11623: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 26 (row 11624: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 26 (row 11625: unconverted data remains:  Gym/Fitness)
# 	Problem with F22-1445 Records_Part3.pdf page 26 (row 11626: time data 'Care' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 26 (row 11627: time data 'Bar/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 26 (row 11628: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 26 (row 11629: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 26 (row 11630: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 26 (row 11631: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 29 (row 11654: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 29 (row 11655: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 29 (row 11656: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 29 (row 11657: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 29 (row 11658: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 29 (row 11659: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 29 (row 11660: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 31 (row 11674: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 31 (row 11675: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 31 (row 11676: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 31 (row 11677: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 31 (row 11678: time data 'Processing' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 31 (row 11679: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part3.pdf page 31 (row 11680: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part3.pdf page 31 (row 11681: unconverted data remains:  Bar/Lounge)
# 	Problem with F22-1445 Records_Part3.pdf page 31 (row 11682: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part3.pdf page 31 (row 11683: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part3.pdf page 31 (row 11684: time data 'ervices' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 31 (row 11685: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 31 (row 11686: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 33 (row 11697: time data 'Processing' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 33 (row 11698: unconverted data remains:  Housing)
# 	Problem with F22-1445 Records_Part3.pdf page 33 (row 11699: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part3.pdf page 33 (row 11700: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 33 (row 11701: time data 'Office' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 33 (row 11702: time data 'Gym/Fitness' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 33 (row 11703: time data 'lture' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 33 (row 11704: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 33 (row 11705: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 33 (row 11706: time data 'Office' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 34 (row 11707: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 34 (row 11708: time data 'Warehouse' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 34 (row 11709: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 34 (row 11710: time data 'Gym/Fitness' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 34 (row 11711: time data 'Gym/Fitness' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 34 (row 11712: time data 'Gym/Fitness' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 34 (row 11713: time data 'Gym/Fitness' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 34 (row 11714: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part3.pdf page 34 (row 11715: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 34 (row 11716: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 34 (row 11717: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 35 (row 11718: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 35 (row 11719: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 35 (row 11720: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 35 (row 11721: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 35 (row 11722: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 35 (row 11723: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 35 (row 11724: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 35 (row 11725: time data 'No' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 37 (row 11738: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 37 (row 11739: time data 'Gym/Fitness' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 37 (row 11740: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 37 (row 11741: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 37 (row 11742: unconverted data remains:  Bar/Lounge)
# 	Problem with F22-1445 Records_Part3.pdf page 37 (row 11743: unconverted data remains:  Retail)
# 	Problem with F22-1445 Records_Part3.pdf page 37 (row 11744: unconverted data remains:  Bar/Lounge)
# 	Problem with F22-1445 Records_Part3.pdf page 37 (row 11745: unconverted data remains:  Bar/Lounge)
# 	Problem with F22-1445 Records_Part3.pdf page 37 (row 11746: time data 'Bar/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 37 (row 11747: unconverted data remains:  Retail)
# 	Problem with F22-1445 Records_Part3.pdf page 37 (row 11748: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 37 (row 11749: unconverted data remains:  on)
# 	Problem with F22-1445 Records_Part3.pdf page 37 (row 11750: unconverted data remains:  Retail)
# 	Problem with F22-1445 Records_Part3.pdf page 38 (row 11751: unconverted data remains:  nstruction)
# 	Problem with F22-1445 Records_Part3.pdf page 38 (row 11752: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 38 (row 11753: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 38 (row 11754: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 38 (row 11755: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 38 (row 11756: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 38 (row 11757: unconverted data remains:  (Acute/LTC))
# 	Problem with F22-1445 Records_Part3.pdf page 38 (row 11758: unconverted data remains:  nstruction)
# 	Problem with F22-1445 Records_Part3.pdf page 38 (row 11759: unconverted data remains:  Bar/Lounge)
# 	Problem with F22-1445 Records_Part3.pdf page 38 (row 11760: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 38 (row 11761: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 38 (row 11762: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 39 (row 11763: unconverted data remains:  on)
# 	Problem with F22-1445 Records_Part3.pdf page 39 (row 11764: time data 'Office' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 39 (row 11765: time data 'Other' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 39 (row 11766: time data 'Bar/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 39 (row 11767: unconverted data remains:  Retail)
# 	Problem with F22-1445 Records_Part3.pdf page 39 (row 11768: unconverted data remains:  Bar/Lounge)
# 	Problem with F22-1445 Records_Part3.pdf page 39 (row 11769: unconverted data remains:  Bar/Lounge)
# 	Problem with F22-1445 Records_Part3.pdf page 39 (row 11770: unconverted data remains:  Bar/Lounge)
# 	Problem with F22-1445 Records_Part3.pdf page 39 (row 11771: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 39 (row 11772: time data 'lture' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 39 (row 11773: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 39 (row 11774: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 39 (row 11775: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 39 (row 11776: unconverted data remains:  Care)
# 	Problem with F22-1445 Records_Part3.pdf page 39 (row 11777: time data 'Retail' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 40 (row 11778: time data 'Bar/Lounge' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 40 (row 11779: unconverted data remains:  nstruction)
# 	Problem with F22-1445 Records_Part3.pdf page 40 (row 11780: unconverted data remains:  Retail)
# 	Problem with F22-1445 Records_Part3.pdf page 40 (row 11781: unconverted data remains:  ng/Industry)
# 	Problem with F22-1445 Records_Part3.pdf page 40 (row 11782: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 40 (row 11783: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 40 (row 11784: time data 'Gym/Fitness' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 40 (row 11785: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 40 (row 11786: unconverted data remains:  Bar/Lounge)
# 	Problem with F22-1445 Records_Part3.pdf page 40 (row 11787: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 40 (row 11788: time data 'on' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 40 (row 11789: time data 'Processing' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 42 (row 11804: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 42 (row 11805: time data 'nstruction' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 42 (row 11806: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 42 (row 11807: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part3.pdf page 42 (row 11808: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 42 (row 11809: unconverted data remains:  ng/Industry)
# 	Problem with F22-1445 Records_Part3.pdf page 42 (row 11810: unconverted data remains:  nstruction)
# 	Problem with F22-1445 Records_Part3.pdf page 42 (row 11811: unconverted data remains:  Bar/Lounge)
# 	Problem with F22-1445 Records_Part3.pdf page 42 (row 11812: unconverted data remains:  nstruction)
# 	Problem with F22-1445 Records_Part3.pdf page 42 (row 11813: unconverted data remains:  Other)
# 	Problem with F22-1445 Records_Part3.pdf page 42 (row 11814: unconverted data remains:  Office)
# 	Problem with F22-1445 Records_Part3.pdf page 42 (row 11815: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 42 (row 11816: time data 'ng/Industry' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 42 (row 11817: unconverted data remains:  ng/Industry)
# 	Problem with F22-1445 Records_Part3.pdf page 42 (row 11818: unconverted data remains:  ng/Industry)
# 	Problem with F22-1445 Records_Part3.pdf page 66 (row 12208: time data '#########' does not match format '%m/%d/%Y' (match))
# 	Problem with F22-1445 Records_Part3.pdf page 76 (row 12351: time data '#########' does not match format '%m/%d/%Y' (match))
# Rows with misaligned columns: 0 out of 12820
# File saved:  C:/Users/silvh/OneDrive/lighthouse/portfolio-projects/BC-Covid-workplace-closures/data/interim/pdfs_parsed_2023-04-02_okay_rows_2023-04-22_1513.sav
# Time completed: 2023-04-22 15:13:42.520668
# 	Object saved as pickle
# File saved:  C:/Users/silvh/OneDrive/lighthouse/portfolio-projects/BC-Covid-workplace-closures/data/interim/pdfs_parsed_2023-04-02_bad_rows_2023-04-22_1513.sav
# Time completed: 2023-04-22 15:13:42.525772
# 	Object saved as pickle
# File saved:  C:/Users/silvh/OneDrive/lighthouse/portfolio-projects/BC-Covid-workplace-closures/data/interim/pdfs_parsed_2023-04-02_problem_pages_2023-04-22_1513.sav
# Time completed: 2023-04-22 15:13:42.525772
# 	Object saved as pickle
#        index   HA workplace_name workplace_address       city  \
# 175    354.0  NHA            NaN              None    Unknown
# 318    497.0  NHA            NaN              None    Unknown
# 689    318.0  FHA            NaN              None     SURREY
# 690    319.0  FHA            NaN              None     SURREY
# 691    320.0  FHA            NaN              None     SURREY
# ...      ...  ...            ...               ...        ...
# 11816  551.0  FHA           None              None      DELTA
# 11817  552.0  IHA           None              None    Kelowna
# 11818  553.0  IHA           None              None  Armstrong
# 12208  355.0  NHA           None              None     nknown
# 12351  498.0  NHA           None              None     nknown
#
#       date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 175                               5/3/2021                     6/15/2021
# 318                              5/25/2021                      6/7/2021
# 689                              4/28/2021                      5/6/2021
# 690                              4/28/2021                     5/29/2021
# 691                              4/28/2021                     5/14/2021
# ...                                    ...                           ...
# 11816                            6/27/2021                     7/20/2021
# 11817                            6/29/2021                          None
# 11818                            6/30/2021                          None
# 12208                             5/3/2021                     6/15/2021
# 12351                            5/25/2021                      6/7/2021
#
#       earliest_reported_cases latest_reported_cases  workplace_classification  \
# 175                      None                  None                        re
# 318                      None                  None                 /Industry
# 689                      None                 Other                      None
# 690                      None                Retail                      None
# 691                      None            nstruction                      None
# ...                       ...                   ...                       ...
# 11816                    None           ng/Industry                      None
# 11817               6/29/2021  7/7/2021 ng/Industry                      None
# 11818               6/30/2021  7/4/2021 ng/Industry                      None
# 12208                     NaN                   NaN        Farm/Agricultur\re
# 12351                     NaN                   NaN  Manufacturing/\rIndustry
#
#       cases_when_cluster_confirmed     total_cases    workplace_status  \
# 175                              1              10               order
# 318                              3               6             closure
# 689                              3  3 transmission                None
# 690                              4        4 Closed                None
# 691                              6          6 open                None
# ...                            ...             ...                 ...
# 11816                            3               3            measures
# 11817                            3               3          Not closed
# 11818                            3               3          Not closed
# 12208                          1.0              10    Closed by\rorder
# 12351                            3               6  Voluntary\rclosure
#
#       closure_y_n closed_by_order voluntary_closure closure_date  \
# 175           Yes             Yes                No    #########
# 318           Yes              No               Yes    #########
# 689            No              No           Unknown         None
# 690           Yes             Yes           Unknown    4/29/2021
# 691            No              No           Unknown         None
# ...           ...             ...               ...          ...
# 11816          No      No Unknown                No         None
# 11817          No           No No           Unknown         None
# 11818          No           No No           Unknown         None
# 12208         Yes             Yes                No    #########
# 12351         Yes              No               Yes    #########
#
#       partially_closed unknown_closure_type open days_since_last_case  \
# 175            Unknown                  NaN   No                 None
# 318            Unknown                  NaN   No                 None
# 689                 No                  NaN  Yes                 None
# 690                 No                  NaN   No                 None
# 691                 No                  NaN  Yes                 None
# ...                ...                  ...  ...                  ...
# 11816              Yes                  NaN   No                 None
# 11817              Yes                  NaN   No                 None
# 11818              Yes                  NaN   No                 None
# 12208        Unknow\rn                  NaN   No                  NaN
# 12351        Unknow\rn                  NaN   No                  NaN
#
#       active_clusters cluster_confirmed_epidate doc_page_number  \
# 175                No                   18-2021              10
# 318                No                   21-2021              19
# 689                No                   17-2021              42
# 690                No                   17-2021              42
# 691                No                   17-2021              42
# ...               ...                       ...             ...
# 11816         26-2021                      None              42
# 11817         26-2021                      None              42
# 11818         26-2021                      None              42
# 12208              No                   18-2021              66
# 12351              No                   21-2021              76
#
#       cluster_closed_epidate                        file flag
# 175                  4438965  F22-1445 Records_Part2.pdf    1
# 318                  4441094  F22-1445 Records_Part2.pdf    1
# 689                     None  F22-1445 Records_Part2.pdf    1
# 690                  17-2021  F22-1445 Records_Part2.pdf    1
# 691                     None  F22-1445 Records_Part2.pdf    1
# ...                      ...                         ...  ...
# 11816                    NaN  F22-1445 Records_Part3.pdf    1
# 11817                    NaN  F22-1445 Records_Part3.pdf    1
# 11818                    NaN  F22-1445 Records_Part3.pdf    1
# 12208           13-\r4438965  F22-1445 Records_Part3.pdf    1
# 12351                    NaN  F22-1445 Records_Part3.pdf    1
#
# [479 rows x 27 columns]

# %% [markdown]
# ### ** Problem pages

# %%
print(problem_pages.shape)
problem_pages
# Out:
# (51, 2)
#                              file doc_page_number
# 175    F22-1445 Records_Part2.pdf              10
# 318    F22-1445 Records_Part2.pdf              19
# 689    F22-1445 Records_Part2.pdf              42
# 717    F22-1445 Records_Part2.pdf              44
# 729    F22-1445 Records_Part2.pdf              45
# 768    F22-1445 Records_Part2.pdf              48
# 801    F22-1445 Records_Part2.pdf              50
# 813    F22-1445 Records_Part2.pdf              51
# 854    F22-1445 Records_Part2.pdf              54
# 870    F22-1445 Records_Part2.pdf              55
# 887    F22-1445 Records_Part2.pdf              56
# 919    F22-1445 Records_Part2.pdf              58
# 1278   F22-1445 Records_Part2.pdf              89
# 1421   F22-1445 Records_Part2.pdf             102
# 1760   F22-1445 Records_Part2.pdf             125
# 1832   F22-1445 Records_Part2.pdf             130
# 1885   F22-1445 Records_Part2.pdf             134
# 1926   F22-1445 Records_Part2.pdf             137
# 1938   F22-1445 Records_Part2.pdf             138
# 1976   F22-1445 Records_Part2.pdf             140
# 2953   F22-1445 Records_Part4.pdf              60
# 6065   F22-1445 Records_Part6.pdf               3
# 6387   F22-1445 Records_Part6.pdf              28
# 6667   F22-1445 Records_Part6.pdf              49
# 6814   F22-1445 Records_Part6.pdf              58
# 9415   F22-1445 Records_Part1.pdf              21
# 9548   F22-1445 Records_Part1.pdf              30
# 9869   F22-1445 Records_Part1.pdf              51
# 10013  F22-1445 Records_Part1.pdf              59
# 10359  F22-1445 Records_Part1.pdf              76
# 10498  F22-1445 Records_Part1.pdf              83
# 10894  F22-1445 Records_Part1.pdf             103
# 11037  F22-1445 Records_Part1.pdf             115
# 11281  F22-1445 Records_Part3.pdf               2
# 11507  F22-1445 Records_Part3.pdf              17
# 11553  F22-1445 Records_Part3.pdf              20
# 11590  F22-1445 Records_Part3.pdf              23
# 11612  F22-1445 Records_Part3.pdf              25
# 11622  F22-1445 Records_Part3.pdf              26
# 11654  F22-1445 Records_Part3.pdf              29
# 11674  F22-1445 Records_Part3.pdf              31
# 11697  F22-1445 Records_Part3.pdf              33
# 11707  F22-1445 Records_Part3.pdf              34
# 11718  F22-1445 Records_Part3.pdf              35
# 11738  F22-1445 Records_Part3.pdf              37
# 11751  F22-1445 Records_Part3.pdf              38
# 11763  F22-1445 Records_Part3.pdf              39
# 11778  F22-1445 Records_Part3.pdf              40
# 11804  F22-1445 Records_Part3.pdf              42
# 12208  F22-1445 Records_Part3.pdf              66
# 12351  F22-1445 Records_Part3.pdf              76

# %%
problem_pages_dict = {k: list(v['doc_page_number']) for k, v in problem_pages.groupby('file')}
problem_pages_dict
# Out:
# {'F22-1445 Records_Part1.pdf': [21, 30, 51, 59, 76, 83, 103, 115],
#  'F22-1445 Records_Part2.pdf': [10,
#   19,
#   42,
#   44,
#   45,
#   48,
#   50,
#   51,
#   54,
#   55,
#   56,
#   58,
#   89,
#   102,
#   125,
#   130,
#   134,
#   137,
#   138,
#   140],
#  'F22-1445 Records_Part3.pdf': [2,
#   17,
#   20,
#   23,
#   25,
#   26,
#   29,
#   31,
#   33,
#   34,
#   35,
#   37,
#   38,
#   39,
#   40,
#   42,
#   66,
#   76],
#  'F22-1445 Records_Part4.pdf': [60],
#  'F22-1445 Records_Part6.pdf': [3, 28, 49, 58]}

# %%
df
# Out:
#        index   HA workplace_name workplace_address             city  \
# 0      179.0  FHA            NaN              None       ABBOTSFORD
# 1      180.0  FHA            NaN              None            DELTA
# 2      181.0  FHA            NaN              None  PORT\rCOQUITLAM
# 3      182.0  VCH            NaN              None        Vancouver
# 4      183.0  NHA            NaN              None          Unknown
# ...      ...  ...            ...               ...              ...
# 13294  113.0  FHA           None              None           SURREY
# 13295  114.0  FHA           None              None           SURREY
# 13296  115.0  FHA           None              None           SURREY
# 13297  116.0  FHA           None              None           SURREY
# 13298  117.0  VCH           None              None        Vancouver
#
#       date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 0                      2021-04-14 00:00:00           2021-05-03 00:00:00
# 1                      2021-04-14 00:00:00           2021-05-09 00:00:00
# 2                      2021-04-14 00:00:00           2021-05-06 00:00:00
# 3                      2021-04-14 00:00:00                           NaT
# 4                      2021-04-14 00:00:00           2021-04-29 00:00:00
# ...                                    ...                           ...
# 13294                  2021-04-09 00:00:00           2021-04-26 00:00:00
# 13295                  2021-04-09 00:00:00           2021-04-21 00:00:00
# 13296                  2021-04-09 00:00:00           2021-04-23 00:00:00
# 13297                  2021-04-09 00:00:00           2021-05-29 00:00:00
# 13298                  2021-04-09 00:00:00                           NaT
#
#       earliest_reported_cases latest_reported_cases  \
# 0                         NaT                   NaT
# 1                         NaT                   NaT
# 2                         NaT                   NaT
# 3         2021-04-14 00:00:00   2021-05-05 00:00:00
# 4                         NaT                   NaT
# ...                       ...                   ...
# 13294                     NaT                   NaT
# 13295                     NaT                   NaT
# 13296                     NaT                   NaT
# 13297                     NaT                   NaT
# 13298     2021-04-09 00:00:00   2021-04-30 00:00:00
#
#                   workplace_classification cases_when_cluster_confirmed  \
# 0                       Farm/Agricultu\rre                            3
# 1                                   Retail                           11
# 2      Maintenance/T\rrades/Construc\rtion                            5
# 3                 Manufacturing\r/Industry                          NaN
# 4      Maintenance/T\rrades/Construc\rtion                            3
# ...                                    ...                          ...
# 13294                               Retail                            4
# 13295                               Office                            4
# 13296                               Office                            6
# 13297                      Food Processing                           11
# 13298                                Other                          NaN
#
#       total_cases                                    workplace_status  \
# 0               3                                              Closed
# 1              11                                                 NaN
# 2               5                                              Closed
# 3               4  Partially\rclosed or\rwidespread\risolation by\rPH
# 4               4                                  Voluntary\rclosure
# ...           ...                                                 ...
# 13294           4                                                 NaN
# 13295           4                                                 NaN
# 13296           6                                          [1] Closed
# 13297          11                                                 NaN
# 13298           5                                     Not a\rworksite
#
#       closure_y_n closed_by_order voluntary_closure         closure_date  \
# 0             Yes             Yes           Unknown  2021-04-15 00:00:00
# 1              No              No           Unknown                  NaT
# 2             Yes             Yes           Unknown  2021-04-14 00:00:00
# 3             Yes              No                No                  NaT
# 4             Yes              No               Yes                  NaT
# ...           ...             ...               ...                  ...
# 13294          No              No           Unknown                  NaT
# 13295          No              No           Unknown                  NaT
# 13296         Yes             Yes           Unknown  2021-04-12 00:00:00
# 13297          No              No           Unknown                  NaT
# 13298          No              No                No                  NaT
#
#       partially_closed unknown_closure_type open days_since_last_case  \
# 0                   No                  NaN   No                  NaN
# 1                   No                  NaN   No                  NaN
# 2                   No                  NaN   No                  NaN
# 3                  Yes                  NaN   No                  NaN
# 4              Unknown                  NaN   No                  NaN
# ...                ...                  ...  ...                  ...
# 13294               No                   No   No                  NaN
# 13295               No                   No   No                  NaN
# 13296               No                   No  Yes                  NaN
# 13297               No                   No   No                  NaN
# 13298               No                   No  Yes                  NaN
#
#       active_clusters cluster_confirmed_epidate doc_page_number  \
# 0                  No                   15-2021               1
# 1                  No                   15-2021               1
# 2                  No                   15-2021               1
# 3                  No                   15-2021               1
# 4                  No                   15-2021               1
# ...               ...                       ...             ...
# 13294              No                   14-2021             143
# 13295              No                   14-2021             143
# 13296              No                   14-2021             143
# 13297              No                   14-2021             143
# 13298              No                   14-2021             143
#
#       cluster_closed_epidate                        file flag
# 0                        NaN  F22-1445 Records_Part2.pdf
# 1                        NaN  F22-1445 Records_Part2.pdf
# 2                        NaN  F22-1445 Records_Part2.pdf
# 3                        NaN  F22-1445 Records_Part2.pdf
# 4                        NaN  F22-1445 Records_Part2.pdf
# ...                      ...                         ...  ...
# 13294                    NaN  F22-1445 Records_Part3.pdf
# 13295                    NaN  F22-1445 Records_Part3.pdf
# 13296                    NaN  F22-1445 Records_Part3.pdf
# 13297                    NaN  F22-1445 Records_Part3.pdf
# 13298                    NaN  F22-1445 Records_Part3.pdf
#
# [12820 rows x 27 columns]

# %% [markdown]
# # Create `fixed_df_dict`

# %%
fixed_df_dict = dict()

# %% [markdown]
# ## [outdated] `view_page` function

# %%
def view_page(df, part_num, page_num,
    filter_column1 = 'file', filter_column2 = 'doc_page_number'):
    filter = (df[filter_column1].str.contains(f'Part{part_num}')) & (df[filter_column2] == page_num)
    page = df[filter].copy()
    return page

part_num = 2
page_num = 10

view_page(problem_rows, part_num, page_num)
# Out:
#      index   HA workplace_name workplace_address     city  \
# 175  354.0  NHA            NaN              None  Unknown
#
#     date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 175                             5/3/2021                     6/15/2021
#
#     earliest_reported_cases latest_reported_cases workplace_classification  \
# 175                    None                  None                       re
#
#     cases_when_cluster_confirmed total_cases workplace_status closure_y_n  \
# 175                            1          10            order         Yes
#
#     closed_by_order voluntary_closure closure_date partially_closed  \
# 175             Yes                No    #########          Unknown
#
#     unknown_closure_type open days_since_last_case active_clusters  \
# 175                  NaN   No                 None              No
#
#     cluster_confirmed_epidate doc_page_number cluster_closed_epidate  \
# 175                   18-2021              10                4438965
#
#                            file flag
# 175  F22-1445 Records_Part2.pdf    1

# %% [markdown]
# # `convert_date_string_to_datetime` for select columns

# %% [markdown]
# ## Fixed Part 2 page 10

# %%
import traceback
def convert_date_string_to_datetime_bycolumn(df):
    date_columns = [
        'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active',
        'earliest_reported_cases', 'latest_reported_cases', 
        'closure_date',
    ]
    for column in date_columns:
        try:
            df[column] = pd.to_datetime(df[column], format='%m/%d/%Y')
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            df[column] = datetime(1900, 1, 1, 0, 0)
            print(f'\tProblem with {df["file"]} page {df["doc_page_number"]} column {column} (row {df.name}: {error})')
    return df


def process_hashed_dates(
        df, part_num, page_num, function, fixed_df_dict=fixed_df_dict,
        part_num_column = 'file', page_num_column = 'doc_page_number',
        save=False,
        ):
    filter = (df[part_num_column].str.contains(f'Part{part_num}')) & (df[page_num_column] == page_num)
    page = df[filter].copy()
    processed_page = page.transpose().apply(function).transpose()
    if save:
        fixed_df_dict[f'Part{part_num}_page{page_num}'] = processed_page
        
        return fixed_df_dict
    else:
        print([f'{column}: {dtype}' for column, dtype in processed_page.dtypes.items()])
        return processed_page
    


part_num = 2
page_num = 10
save=True
function = convert_date_string_to_datetime_bycolumn
fixed_page = process_hashed_dates(problem_rows, part_num, page_num, function=function, save=save)
# Out:
# 	Problem with F22-1445 Records_Part2.pdf page 10 column closure_date (row 175: time data '#########' does not match format '%m/%d/%Y' (match))

# %%
fixed_df_dict['Part2_page10']
# Out:
#      index   HA workplace_name workplace_address     city  \
# 175  354.0  NHA            NaN              None  Unknown
#
#     date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 175                           2021-05-03                    2021-06-15
#
#     earliest_reported_cases latest_reported_cases workplace_classification  \
# 175                    None                  None                       re
#
#     cases_when_cluster_confirmed total_cases workplace_status closure_y_n  \
# 175                            1          10            order         Yes
#
#     closed_by_order voluntary_closure closure_date partially_closed  \
# 175             Yes                No   1900-01-01          Unknown
#
#     unknown_closure_type open days_since_last_case active_clusters  \
# 175                  NaN   No                 None              No
#
#     cluster_confirmed_epidate doc_page_number cluster_closed_epidate  \
# 175                   18-2021              10                4438965
#
#                            file flag
# 175  F22-1445 Records_Part2.pdf    1

# %% [markdown]
# # `view_problem_page` function

# %%
def view_problem_page(problem_pages_df, problem_rows_df, index,
    part_num_column = 'file', page_num_column = 'doc_page_number'):
    file = problem_pages_df.iloc[index][part_num_column]
    page_num = problem_pages_df.iloc[index][page_num_column]
    print(f'{file} page {page_num}')
    filter = (problem_rows_df[part_num_column] == file) & (problem_rows_df[page_num_column] == page_num)
    page = problem_rows_df[filter]
    print([column for column in page.columns])
    return page

index=1

view_problem_page(problem_pages, problem_rows, index)
# Out:
# F22-1445 Records_Part2.pdf page 19
# ['index', 'HA', 'workplace_name', 'workplace_address', 'city', 'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active', 'earliest_reported_cases', 'latest_reported_cases', 'workplace_classification', 'cases_when_cluster_confirmed', 'total_cases', 'workplace_status', 'closure_y_n', 'closed_by_order', 'voluntary_closure', 'closure_date', 'partially_closed', 'unknown_closure_type', 'open', 'days_since_last_case', 'active_clusters', 'cluster_confirmed_epidate', 'doc_page_number', 'cluster_closed_epidate', 'file', 'flag']
#      index   HA workplace_name workplace_address     city  \
# 318  497.0  NHA            NaN              None  Unknown
#
#     date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 318                            5/25/2021                      6/7/2021
#
#     earliest_reported_cases latest_reported_cases workplace_classification  \
# 318                    None                  None                /Industry
#
#     cases_when_cluster_confirmed total_cases workplace_status closure_y_n  \
# 318                            3           6          closure         Yes
#
#     closed_by_order voluntary_closure closure_date partially_closed  \
# 318              No               Yes    #########          Unknown
#
#     unknown_closure_type open days_since_last_case active_clusters  \
# 318                  NaN   No                 None              No
#
#     cluster_confirmed_epidate doc_page_number cluster_closed_epidate  \
# 318                   21-2021              19                4441094
#
#                            file flag
# 318  F22-1445 Records_Part2.pdf    1

# %% [markdown]
# # `process_hashed_dates` Iteration 2

# %% [markdown]
# ## Fixed part 2 page 19

# %%
import re
import traceback
def convert_date_string_to_datetime_bycolumn(df):
    date_columns = [
        'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active',
        'earliest_reported_cases', 'latest_reported_cases', 
        'closure_date',
    ]
    for column in date_columns:
        try:
            df[column] = pd.to_datetime(df[column], format='%m/%d/%Y')
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            df[column] = datetime(1900, 1, 1, 0, 0)
            print(f'\tProblem with {df["file"]} page {df["doc_page_number"]} column {column} (row {df.name}: {error})')
    return df


def process_hashed_dates(
        df, index, function, fixed_df_dict=fixed_df_dict,
        problem_pages_df=problem_pages, 
        part_num_column = 'file', page_num_column = 'doc_page_number',
        save=False,
        ):
    file = problem_pages_df.iloc[index][part_num_column]
    page_num = problem_pages_df.iloc[index][page_num_column]
    part_num = re.search(r'Part(\d+)', file).group(0)
    print(f'{file} page {page_num}')
    filter = (df[part_num_column] == file) & (df[page_num_column] == page_num)
    page = df[filter].copy()
    processed_page = page.transpose().apply(function).transpose()
    if save:
        fixed_df_dict[f'{part_num}_page{page_num}'] = processed_page
        print(f'Updated fixed_df_dict keys: {list(fixed_df_dict.keys())}')
        return fixed_df_dict
    else:
        print([f'{column}: {dtype}' for column, dtype in processed_page.dtypes.items()])
        return processed_page
    


index=1
save=True
function = convert_date_string_to_datetime_bycolumn
fixed_page = process_hashed_dates(problem_rows, index=index, function=function, save=save)
index += 1
# Out:
# F22-1445 Records_Part2.pdf page 19
# 	Problem with F22-1445 Records_Part2.pdf page 19 column closure_date (row 318: time data '#########' does not match format '%m/%d/%Y' (match))
# Updated fixed_df_dict keys: ['Part2_page10', 'Part2_page19']

# %%
fixed_df_dict['Part2_page10']
# Out:
#      index   HA workplace_name workplace_address     city  \
# 175  354.0  NHA            NaN              None  Unknown
#
#     date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 175                           2021-05-03                    2021-06-15
#
#     earliest_reported_cases latest_reported_cases workplace_classification  \
# 175                    None                  None                       re
#
#     cases_when_cluster_confirmed total_cases workplace_status closure_y_n  \
# 175                            1          10            order         Yes
#
#     closed_by_order voluntary_closure closure_date partially_closed  \
# 175             Yes                No   1900-01-01          Unknown
#
#     unknown_closure_type open days_since_last_case active_clusters  \
# 175                  NaN   No                 None              No
#
#     cluster_confirmed_epidate doc_page_number cluster_closed_epidate  \
# 175                   18-2021              10                4438965
#
#                            file flag
# 175  F22-1445 Records_Part2.pdf    1

# %%
view_problem_page(problem_pages, problem_rows, index)
# Out:
# F22-1445 Records_Part2.pdf page 42
# ['index', 'HA', 'workplace_name', 'workplace_address', 'city', 'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active', 'earliest_reported_cases', 'latest_reported_cases', 'workplace_classification', 'cases_when_cluster_confirmed', 'total_cases', 'workplace_status', 'closure_y_n', 'closed_by_order', 'voluntary_closure', 'closure_date', 'partially_closed', 'unknown_closure_type', 'open', 'days_since_last_case', 'active_clusters', 'cluster_confirmed_epidate', 'doc_page_number', 'cluster_closed_epidate', 'file', 'flag']
#      index   HA workplace_name workplace_address       city  \
# 689  318.0  FHA            NaN              None     SURREY
# 690  319.0  FHA            NaN              None     SURREY
# 691  320.0  FHA            NaN              None     SURREY
# 692  321.0  FHA            NaN              None     SURREY
# 693  322.0  IHA            NaN              None      emeos
# 694  323.0  FHA            NaN              None    BURNABY
# 695  324.0  FHA            NaN              None      DELTA
# 696  325.0  FHA            NaN              None     SURREY
# 697  326.0  FHA            NaN              None     SURREY
# 698  327.0  FHA            NaN              None     SURREY
# 699  328.0  FHA            NaN              None    LANGLEY
# 700  329.0  VCH            NaN              None  Vancouver
# 701  330.0  FHA            NaN              None    BURNABY
#
#     date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 689                            4/28/2021                      5/6/2021
# 690                            4/28/2021                     5/29/2021
# 691                            4/28/2021                     5/14/2021
# 692                            4/28/2021                      6/2/2021
# 693                            4/29/2021                          None
# 694                            4/29/2021                     5/19/2021
# 695                            4/29/2021                      5/8/2021
# 696                            4/29/2021                      5/9/2021
# 697                            4/29/2021                     5/14/2021
# 698                            4/29/2021                     5/19/2021
# 699                            4/29/2021                     5/14/2021
# 700                            4/29/2021                          None
# 701                            4/30/2021                     4/30/2021
#
#     earliest_reported_cases latest_reported_cases workplace_classification  \
# 689                    None                 Other                     None
# 690                    None                Retail                     None
# 691                    None            nstruction                     None
# 692                    None                Office                     None
# 693               4/29/2021                  ture                     None
# 694                    None            Processing                     None
# 695                    None                    on                     None
# 696                    None            nstruction                     None
# 697                    None            Bar/Lounge                     None
# 698                    None                    on                     None
# 699                    None             Warehouse                     None
# 700               4/29/2021       5/19/2021 Other                     None
# 701                    None           ng/Industry                     None
#
#     cases_when_cluster_confirmed     total_cases workplace_status closure_y_n  \
# 689                            3  3 transmission             None          No
# 690                            4        4 Closed             None         Yes
# 691                            6          6 open             None          No
# 692                            5        5 Closed             None         Yes
# 693                            4    3 Not closed             None          No
# 694                            5      5 measures             None          No
# 695                            7          7 open             None          No
# 696                            5      5 measures             None          No
# 697                            3      3 measures             None          No
# 698                            3  3 transmission             None          No
# 699                            7        7 Closed             None         Yes
# 700                         None       3 closed)             None          No
# 701                            3        3 Closed             None         Yes
#
#     closed_by_order voluntary_closure closure_date partially_closed  \
# 689              No           Unknown         None               No
# 690             Yes           Unknown    4/29/2021               No
# 691              No           Unknown         None               No
# 692             Yes           Unknown    4/29/2021               No
# 693              No                No         None          Unknown
# 694              No           Unknown         None               No
# 695              No           Unknown         None               No
# 696              No           Unknown         None               No
# 697              No           Unknown         None               No
# 698              No           Unknown         None               No
# 699             Yes           Unknown     5/2/2021               No
# 700              No                No         None               No
# 701              No           Unknown     5/2/2021              Yes
#
#     unknown_closure_type open days_since_last_case active_clusters  \
# 689                  NaN  Yes                 None              No
# 690                  NaN   No                 None              No
# 691                  NaN  Yes                 None              No
# 692                  NaN   No                 None              No
# 693                  NaN  Yes                 None              No
# 694                  NaN  Yes                 None              No
# 695                  NaN  Yes                 None              No
# 696                  NaN  Yes                 None              No
# 697                  NaN  Yes                 None              No
# 698                  NaN  Yes                 None              No
# 699                  NaN   No                 None              No
# 700                  NaN  Yes                 None              No
# 701                  NaN   No                 None              No
#
#     cluster_confirmed_epidate doc_page_number cluster_closed_epidate  \
# 689                   17-2021              42                   None
# 690                   17-2021              42                17-2021
# 691                   17-2021              42                   None
# 692                   17-2021              42                17-2021
# 693                   17-2021              42                   None
# 694                   17-2021              42                   None
# 695                   17-2021              42                   None
# 696                   17-2021              42                   None
# 697                   17-2021              42                   None
# 698                   17-2021              42                   None
# 699                   17-2021              42                18-2021
# 700                   17-2021              42                   None
# 701                   17-2021              42                18-2021
#
#                            file flag
# 689  F22-1445 Records_Part2.pdf    1
# 690  F22-1445 Records_Part2.pdf    1
# 691  F22-1445 Records_Part2.pdf    1
# 692  F22-1445 Records_Part2.pdf    1
# 693  F22-1445 Records_Part2.pdf    1
# 694  F22-1445 Records_Part2.pdf    1
# 695  F22-1445 Records_Part2.pdf    1
# 696  F22-1445 Records_Part2.pdf    1
# 697  F22-1445 Records_Part2.pdf    1
# 698  F22-1445 Records_Part2.pdf    1
# 699  F22-1445 Records_Part2.pdf    1
# 700  F22-1445 Records_Part2.pdf    1
# 701  F22-1445 Records_Part2.pdf    1

# %%
view_problem_page(problem_pages, problem_rows, index).iloc[0]['latest_reported_cases']
# Out:
# F22-1445 Records_Part2.pdf page 42
# ['index', 'HA', 'workplace_name', 'workplace_address', 'city', 'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active', 'earliest_reported_cases', 'latest_reported_cases', 'workplace_classification', 'cases_when_cluster_confirmed', 'total_cases', 'workplace_status', 'closure_y_n', 'closed_by_order', 'voluntary_closure', 'closure_date', 'partially_closed', 'unknown_closure_type', 'open', 'days_since_last_case', 'active_clusters', 'cluster_confirmed_epidate', 'doc_page_number', 'cluster_closed_epidate', 'file', 'flag']
# 'Other'

# %% [markdown]
# # split columns

# %%
import re
import traceback
def convert_date_string_to_datetime_bycolumn(df):
    date_columns = [
        'date_cluster_confirmed_public_health', 'date_cluster_no_longer_active',
        'earliest_reported_cases', 'latest_reported_cases', 
        'closure_date',
    ]
    for column in date_columns:
        try:
            df[column] = pd.to_datetime(df[column], format='%m/%d/%Y')
        except Exception as error:
            exc_type, exc_obj, tb = sys.exc_info()
            f = tb.tb_frame
            lineno = tb.tb_lineno
            filename = f.f_code.co_filename
            df[column] = datetime(1900, 1, 1, 0, 0)
            print(f'\tProblem with {df["file"]} page {df["doc_page_number"]} column {column} (row {df.name}: {error})')
    return df

def split_column(df, 
        column_to_split='latest_reported_cases', 
        column1='latest_reported_cases', column2='workplace_classification'):
    split_text = df[column_to_split].split(' ')
    if split_text[0] == split_text[-1]:
        df[column1] = None
        df[column2] = split_text[-1] 
    else:
        df[column1] = split_text[0]
        df[column2] = split_text[-1]

    print(f'Columns split')
    return df

def process_hashed_dates(
        df, index, function, fixed_df_dict=fixed_df_dict,
        problem_pages_df=problem_pages, 
        part_num_column = 'file', page_num_column = 'doc_page_number',
        save=False,
        ):
    file = problem_pages_df.iloc[index][part_num_column]
    page_num = problem_pages_df.iloc[index][page_num_column]
    part_num = re.search(r'Part(\d+)', file).group(0)
    print(f'{file} page {page_num}')
    filter = (df[part_num_column] == file) & (df[page_num_column] == page_num)
    page = df[filter].copy()
    processed_page = page.transpose().apply(function).transpose()
    if save:
        fixed_df_dict[f'{part_num}_page{page_num}'] = processed_page
        print(f'Updated fixed_df_dict keys: {list(fixed_df_dict.keys())}')
        return fixed_df_dict
    else:
        print([f'{column}: {dtype}' for column, dtype in processed_page.dtypes.items()])
        return processed_page
    


# index=1
save=True
function = convert_date_string_to_datetime_bycolumn
function = split_column
fixed_page = process_hashed_dates(problem_rows, index=index, function=function, save=save)
index += 1
# Out:
# F22-1445 Records_Part2.pdf page 42
# Columns split
# Columns split
# Columns split
# Columns split
# Columns split
# Columns split
# Columns split
# Columns split
# Columns split
# Columns split
# Columns split
# Columns split
# Columns split
# Updated fixed_df_dict keys: ['Part2_page10', 'Part2_page19', 'Part2_page42']

# %%
fixed_page
# Out:
#      index   HA workplace_name workplace_address       city  \
# 689  318.0  FHA            NaN              None     SURREY
# 690  319.0  FHA            NaN              None     SURREY
# 691  320.0  FHA            NaN              None     SURREY
# 692  321.0  FHA            NaN              None     SURREY
# 693  322.0  IHA            NaN              None      emeos
# 694  323.0  FHA            NaN              None    BURNABY
# 695  324.0  FHA            NaN              None      DELTA
# 696  325.0  FHA            NaN              None     SURREY
# 697  326.0  FHA            NaN              None     SURREY
# 698  327.0  FHA            NaN              None     SURREY
# 699  328.0  FHA            NaN              None    LANGLEY
# 700  329.0  VCH            NaN              None  Vancouver
# 701  330.0  FHA            NaN              None    BURNABY
#
#     date_cluster_confirmed_public_health date_cluster_no_longer_active  \
# 689                            4/28/2021                      5/6/2021
# 690                            4/28/2021                     5/29/2021
# 691                            4/28/2021                     5/14/2021
# 692                            4/28/2021                      6/2/2021
# 693                            4/29/2021                          None
# 694                            4/29/2021                     5/19/2021
# 695                            4/29/2021                      5/8/2021
# 696                            4/29/2021                      5/9/2021
# 697                            4/29/2021                     5/14/2021
# 698                            4/29/2021                     5/19/2021
# 699                            4/29/2021                     5/14/2021
# 700                            4/29/2021                          None
# 701                            4/30/2021                     4/30/2021
#
#     earliest_reported_cases latest_reported_cases workplace_classification  \
# 689                    None                  None                    Other
# 690                    None                  None                   Retail
# 691                    None                  None               nstruction
# 692                    None                  None                   Office
# 693               4/29/2021                  None                     ture
# 694                    None                  None               Processing
# 695                    None                  None                       on
# 696                    None                  None               nstruction
# 697                    None                  None               Bar/Lounge
# 698                    None                  None                       on
# 699                    None                  None                Warehouse
# 700               4/29/2021             5/19/2021                    Other
# 701                    None                  None              ng/Industry
#
#     cases_when_cluster_confirmed     total_cases workplace_status closure_y_n  \
# 689                            3  3 transmission             None          No
# 690                            4        4 Closed             None         Yes
# 691                            6          6 open             None          No
# 692                            5        5 Closed             None         Yes
# 693                            4    3 Not closed             None          No
# 694                            5      5 measures             None          No
# 695                            7          7 open             None          No
# 696                            5      5 measures             None          No
# 697                            3      3 measures             None          No
# 698                            3  3 transmission             None          No
# 699                            7        7 Closed             None         Yes
# 700                         None       3 closed)             None          No
# 701                            3        3 Closed             None         Yes
#
#     closed_by_order voluntary_closure closure_date partially_closed  \
# 689              No           Unknown         None               No
# 690             Yes           Unknown    4/29/2021               No
# 691              No           Unknown         None               No
# 692             Yes           Unknown    4/29/2021               No
# 693              No                No         None          Unknown
# 694              No           Unknown         None               No
# 695              No           Unknown         None               No
# 696              No           Unknown         None               No
# 697              No           Unknown         None               No
# 698              No           Unknown         None               No
# 699             Yes           Unknown     5/2/2021               No
# 700              No                No         None               No
# 701              No           Unknown     5/2/2021              Yes
#
#     unknown_closure_type open days_since_last_case active_clusters  \
# 689                  NaN  Yes                 None              No
# 690                  NaN   No                 None              No
# 691                  NaN  Yes                 None              No
# 692                  NaN   No                 None              No
# 693                  NaN  Yes                 None              No
# 694                  NaN  Yes                 None              No
# 695                  NaN  Yes                 None              No
# 696                  NaN  Yes                 None              No
# 697                  NaN  Yes                 None              No
# 698                  NaN  Yes                 None              No
# 699                  NaN   No                 None              No
# 700                  NaN  Yes                 None              No
# 701                  NaN   No                 None              No
#
#     cluster_confirmed_epidate doc_page_number cluster_closed_epidate  \
# 689                   17-2021              42                   None
# 690                   17-2021              42                17-2021
# 691                   17-2021              42                   None
# 692                   17-2021              42                17-2021
# 693                   17-2021              42                   None
# 694                   17-2021              42                   None
# 695                   17-2021              42                   None
# 696                   17-2021              42                   None
# 697                   17-2021              42                   None
# 698                   17-2021              42                   None
# 699                   17-2021              42                18-2021
# 700                   17-2021              42                   None
# 701                   17-2021              42                18-2021
#
#                            file flag
# 689  F22-1445 Records_Part2.pdf    1
# 690  F22-1445 Records_Part2.pdf    1
# 691  F22-1445 Records_Part2.pdf    1
# 692  F22-1445 Records_Part2.pdf    1
# 693  F22-1445 Records_Part2.pdf    1
# 694  F22-1445 Records_Part2.pdf    1
# 695  F22-1445 Records_Part2.pdf    1
# 696  F22-1445 Records_Part2.pdf    1
# 697  F22-1445 Records_Part2.pdf    1
# 698  F22-1445 Records_Part2.pdf    1
# 699  F22-1445 Records_Part2.pdf    1
# 700  F22-1445 Records_Part2.pdf    1
# 701  F22-1445 Records_Part2.pdf    1

# %%
pickle_path = r'C:\Users\silvh\OneDrive\lighthouse\portfolio-projects\BC-Covid-workplace-closures\data\interim'
save_output(fixed_df_dict, description='fixed_df_dict', pickle_path=pickle_path, csv_path=None)
# Out:
# File saved:  C:/Users/silvh/OneDrive/lighthouse/portfolio-projects/BC-Covid-workplace-closures/data/interim/fixed_df_dict_2023-04-22_1705.sav
# Time completed: 2023-04-22 17:05:34.765202
# 	Object saved as pickle

# %% [markdown]
# # *End of Page*
